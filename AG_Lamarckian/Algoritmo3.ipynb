# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
import numpy as np
import random
from multiprocessing import Pool

# Lectura de datos
data = np.loadtxt('/content/drive/MyDrive/MÁSTER/IC/P2/data/tai256c.dat', skiprows=1)
flow = np.int32(data[:256])
distances = np.int32(data[256:])

seed = 2024
random.seed(seed)
np.random.seed(seed)

# %%
# Generación de la población inicial
def generate_population(population_size, n=256):
    return np.array([np.random.permutation(np.arange(n)) for _ in range(population_size)])

def fitness_pop(population, flow, distances):
    return np.sum(flow[np.newaxis, :, :] * distances[population[:, :, np.newaxis], population[:, np.newaxis, :]],
                  axis=(1, 2))

# %%
# Función de selección por torneo
def tournament_selection(population, fitness_vals, tournament_size=5):
    selected = []
    for _ in range(len(population)):
        tournament = random.sample(range(len(population)), tournament_size)
        winner = tournament[np.argmin([fitness_vals[i] for i in tournament])]
        selected.append(population[winner])
    return np.array(selected)

# %%
# Operador de cruce por orden (OX)
def ox_crossover(parent1, parent2):
    size = len(parent1)
    start, end = sorted(np.random.choice(range(size), 2, replace=False))
    child = -np.ones(size, dtype=int)
    child[start:end+1] = parent1[start:end+1]
    idx = 0
    for i in range(size):
        if child[i] == -1:
            while parent2[idx] in child:
                idx += 1
            child[i] = parent2[idx]
    return child

# %%
# Mutación por intercambio (Swap)
def swap_mutation(individual, mutation_prob=0.05):
    if random.random() < mutation_prob:
        i, j = np.random.choice(range(len(individual)), 2, replace=False)
        individual[i], individual[j] = individual[j], individual[i]
    return individual

# %%
def hill_climbing_optimized(individual, flow, distances, max_iterations=100):
    current = individual.copy()
    current_fitness = fitness_pop(np.array([current]), flow, distances)[0]
    for _ in range(max_iterations):
        i, j = np.random.choice(range(len(current)), 2, replace=False)
        neighbor = current.copy()
        neighbor[i], neighbor[j] = neighbor[j], neighbor[i]
        # Cálculo delta:
        delta_fitness = calculate_fitness_delta(current, i, j, flow, distances)
        if delta_fitness < 0: # Para aceptar solo mejoras
            current = neighbor
            current_fitness += delta_fitness
    return current, current_fitness

def calculate_fitness_delta(individual, i, j, flow, distances):
    n = len(individual)
    delta = 0
    for k in range(n):
        if k != i and k != j:
            delta += (flow[i, k] + flow[k, i]) * (distances[individual[j], individual[k]] - distances[individual[i], individual[k]])
            delta += (flow[j, k] + flow[k, j]) * (distances[individual[i], individual[k]] - distances[individual[j], individual[k]])
    return delta

# %%
# Algoritmo genético con variante lamarckiana
def lamarckian_genetic_algorithm(flow, distances, population_size=500, generations=200, crossover_prob=0.9, mutation_prob=0.05, tournament_size=5):
    population = generate_population(population_size)

    for generation in range(generations):
        fitness_vals = fitness_pop(population, flow, distances)

        # Aplicar hill climbing a toda la población (herencia directa)
        improved_population = []
        for ind in population:
            improved_ind, improved_fitness = hill_climbing_optimized(ind, flow, distances)
            improved_population.append(improved_ind)
        population = np.array(improved_population)

        # Selección
        fitness_vals = fitness_pop(population, flow, distances)
        selected_population = tournament_selection(population, fitness_vals, tournament_size)

        # Cruzamiento
        offspring = []
        for i in range(0, population_size, 2):
            if random.random() < crossover_prob:
                child1 = ox_crossover(selected_population[i], selected_population[i+1])
                child2 = ox_crossover(selected_population[i+1], selected_population[i])
            else:
                child1, child2 = selected_population[i], selected_population[i+1]
            offspring.append(child1)
            offspring.append(child2)

        # Mutación
        population = np.array([swap_mutation(ind, mutation_prob) for ind in offspring])

        # Imprimir mejor costo
        best_idx = np.argmin(fitness_vals)
        print(f"Generación {generation+1}: Mejor coste = {fitness_vals[best_idx]}")

    fitness_vals = fitness_pop(population, flow, distances)
    best_idx = np.argmin(fitness_vals)
    return population[best_idx], fitness_vals[best_idx]

# %%
# Ejecución del algoritmo
best_solution_lamarck, best_cost_lamarck = lamarckian_genetic_algorithm(flow, distances)

print("\nMejor solución encontrada (Lamarckiano):", best_solution_lamarck)
print("Coste asociado a la mejor solución (Lamarckiano):", best_cost_lamarck)
# Out:
# Generación 1: Mejor coste = 48163922
# Generación 2: Mejor coste = 47660068
# Generación 3: Mejor coste = 47171664
# Generación 4: Mejor coste = 46948284
# Generación 5: Mejor coste = 46635566
# Generación 6: Mejor coste = 46557608
# Generación 7: Mejor coste = 46343906
# Generación 8: Mejor coste = 46540884
# Generación 9: Mejor coste = 46444958
# Generación 10: Mejor coste = 46141070
# Generación 11: Mejor coste = 46118736
# Generación 12: Mejor coste = 45942584
# Generación 13: Mejor coste = 45942584
# Generación 14: Mejor coste = 45993464
# Generación 15: Mejor coste = 45886050
# Generación 16: Mejor coste = 45847436
# Generación 17: Mejor coste = 45796578
# Generación 18: Mejor coste = 45522336
# Generación 19: Mejor coste = 45508876
# Generación 20: Mejor coste = 45508876
# Generación 21: Mejor coste = 45679576
# Generación 22: Mejor coste = 45693516
# Generación 23: Mejor coste = 45619302
# Generación 24: Mejor coste = 45626616
# Generación 25: Mejor coste = 45604022
# Generación 26: Mejor coste = 45552748
# Generación 27: Mejor coste = 45513702
# Generación 28: Mejor coste = 45460798
# Generación 29: Mejor coste = 45415456
# Generación 30: Mejor coste = 45396622
# Generación 31: Mejor coste = 45331244
# Generación 32: Mejor coste = 45294226
# Generación 33: Mejor coste = 45265602
# Generación 34: Mejor coste = 45289456
# Generación 35: Mejor coste = 45198662
# Generación 36: Mejor coste = 45205482
# Generación 37: Mejor coste = 45205482
# Generación 38: Mejor coste = 45115864
# Generación 39: Mejor coste = 45057248
# Generación 40: Mejor coste = 45057248
# Generación 41: Mejor coste = 45047112
# Generación 42: Mejor coste = 45046962
# Generación 43: Mejor coste = 45035962
# Generación 44: Mejor coste = 44990984
# Generación 45: Mejor coste = 44990984
# Generación 46: Mejor coste = 44989122
# Generación 47: Mejor coste = 44975812
# Generación 48: Mejor coste = 44945014
# Generación 49: Mejor coste = 44945014
# Generación 50: Mejor coste = 44945014
# Generación 51: Mejor coste = 44945014
# Generación 52: Mejor coste = 44945014
# Generación 53: Mejor coste = 44931920
# Generación 54: Mejor coste = 44931920
# Generación 55: Mejor coste = 44931920
# Generación 56: Mejor coste = 44931920
# Generación 57: Mejor coste = 44925938
# Generación 58: Mejor coste = 44922660
# Generación 59: Mejor coste = 44922660
# Generación 60: Mejor coste = 44916718
# Generación 61: Mejor coste = 44916718
# Generación 62: Mejor coste = 44916718
# Generación 63: Mejor coste = 44915306
# Generación 64: Mejor coste = 44913754
# Generación 65: Mejor coste = 44913754
# Generación 66: Mejor coste = 44911734
# Generación 67: Mejor coste = 44911734
# Generación 68: Mejor coste = 44911734
# Generación 69: Mejor coste = 44911362
# Generación 70: Mejor coste = 44909448
# Generación 71: Mejor coste = 44909448
# Generación 72: Mejor coste = 44909448
# Generación 73: Mejor coste = 44902222
# Generación 74: Mejor coste = 44902222
# Generación 75: Mejor coste = 44902222
# Generación 76: Mejor coste = 44901164
# Generación 77: Mejor coste = 44901164
# Generación 78: Mejor coste = 44901164
# Generación 79: Mejor coste = 44901164
# Generación 80: Mejor coste = 44901164
# Generación 81: Mejor coste = 44901164
# Generación 82: Mejor coste = 44901164
# Generación 83: Mejor coste = 44901164
# Generación 84: Mejor coste = 44901164
# Generación 85: Mejor coste = 44901164
# Generación 86: Mejor coste = 44901164
# Generación 87: Mejor coste = 44901164
# Generación 88: Mejor coste = 44901164
# Generación 89: Mejor coste = 44901164
# Generación 90: Mejor coste = 44901164
# Generación 91: Mejor coste = 44901164
# Generación 92: Mejor coste = 44901164
# Generación 93: Mejor coste = 44901164
# Generación 94: Mejor coste = 44901164
# Generación 95: Mejor coste = 44901164
# Generación 96: Mejor coste = 44901164
# Generación 97: Mejor coste = 44901164
# Generación 98: Mejor coste = 44901164
# Generación 99: Mejor coste = 44901164
# Generación 100: Mejor coste = 44901164
# Generación 101: Mejor coste = 44901164
# Generación 102: Mejor coste = 44901164
# Generación 103: Mejor coste = 44901164
# Generación 104: Mejor coste = 44901164
# Generación 105: Mejor coste = 44901164
# Generación 106: Mejor coste = 44901164
# Generación 107: Mejor coste = 44901164
# Generación 108: Mejor coste = 44901164
# Generación 109: Mejor coste = 44901164
# Generación 110: Mejor coste = 44901164
# Generación 111: Mejor coste = 44901164
# Generación 112: Mejor coste = 44901164
# Generación 113: Mejor coste = 44901164
# Generación 114: Mejor coste = 44901164
# Generación 115: Mejor coste = 44901164
# Generación 116: Mejor coste = 44901164
# Generación 117: Mejor coste = 44901164
# Generación 118: Mejor coste = 44901164
# Generación 119: Mejor coste = 44901164
# Generación 120: Mejor coste = 44901164
# Generación 121: Mejor coste = 44901164
# Generación 122: Mejor coste = 44901164
# Generación 123: Mejor coste = 44901164
# Generación 124: Mejor coste = 44901164
# Generación 125: Mejor coste = 44901164
# Generación 126: Mejor coste = 44901164
# Generación 127: Mejor coste = 44901164
# Generación 128: Mejor coste = 44901164
# Generación 129: Mejor coste = 44901164
# Generación 130: Mejor coste = 44901164
# Generación 131: Mejor coste = 44901164
# Generación 132: Mejor coste = 44901164
# Generación 133: Mejor coste = 44901164
# Generación 134: Mejor coste = 44901164
# Generación 135: Mejor coste = 44901164
# Generación 136: Mejor coste = 44901164
# Generación 137: Mejor coste = 44901164
# Generación 138: Mejor coste = 44901164
# Generación 139: Mejor coste = 44901164
# Generación 140: Mejor coste = 44901164
# Generación 141: Mejor coste = 44901164
# Generación 142: Mejor coste = 44901164
# Generación 143: Mejor coste = 44901164
# Generación 144: Mejor coste = 44901164
# Generación 145: Mejor coste = 44901164
# Generación 146: Mejor coste = 44901164
# Generación 147: Mejor coste = 44901164
# Generación 148: Mejor coste = 44901164
# Generación 149: Mejor coste = 44901164
# Generación 150: Mejor coste = 44901164
# Generación 151: Mejor coste = 44901164
# Generación 152: Mejor coste = 44901164
# Generación 153: Mejor coste = 44901164
# Generación 154: Mejor coste = 44901164
# Generación 155: Mejor coste = 44901164
# Generación 156: Mejor coste = 44901164
# Generación 157: Mejor coste = 44901164
# Generación 158: Mejor coste = 44901164
# Generación 159: Mejor coste = 44901164
# Generación 160: Mejor coste = 44901164
# Generación 161: Mejor coste = 44901164
# Generación 162: Mejor coste = 44901164
# Generación 163: Mejor coste = 44901164
# Generación 164: Mejor coste = 44901164
# Generación 165: Mejor coste = 44901164
# Generación 166: Mejor coste = 44901164
# Generación 167: Mejor coste = 44901164
# Generación 168: Mejor coste = 44901164
# Generación 169: Mejor coste = 44901164
# Generación 170: Mejor coste = 44901164
# Generación 171: Mejor coste = 44901164
# Generación 172: Mejor coste = 44901164
# Generación 173: Mejor coste = 44901164
# Generación 174: Mejor coste = 44901164
# Generación 175: Mejor coste = 44901164
# Generación 176: Mejor coste = 44901164
# Generación 177: Mejor coste = 44901164
# Generación 178: Mejor coste = 44901164
# Generación 179: Mejor coste = 44901164
# Generación 180: Mejor coste = 44901164
# Generación 181: Mejor coste = 44901164
# Generación 182: Mejor coste = 44901164
# Generación 183: Mejor coste = 44901164
# Generación 184: Mejor coste = 44901164
# Generación 185: Mejor coste = 44901164
# Generación 186: Mejor coste = 44901164
# Generación 187: Mejor coste = 44901164
# Generación 188: Mejor coste = 44901164
# Generación 189: Mejor coste = 44901164
# Generación 190: Mejor coste = 44901164
# Generación 191: Mejor coste = 44901164
# Generación 192: Mejor coste = 44901164
# Generación 193: Mejor coste = 44901164
# Generación 194: Mejor coste = 44901164
# Generación 195: Mejor coste = 44901164
# Generación 196: Mejor coste = 44901164
# Generación 197: Mejor coste = 44901164
# Generación 198: Mejor coste = 44901164
# Generación 199: Mejor coste = 44901164
# Generación 200: Mejor coste = 44901164
#
# Mejor solución encontrada (Lamarckiano): [ 22  83 239  90  39 110 181 219 141  20 236 139 158  54 188 212  18  98
#  146  62 254 227  13 127 231  24 195  52 193 222 144  66  77 137 169 178
#  225  16  71  15  64   9  86  69  58 120  49  35 190 248 199 205 156 250
#   73  11 124  30 151 134 163   5 131 171 175 113 186 208 100 166 201 233
#   96   1 184  60  92 246  28 214 242 148 107  95  43 105  41  47 117 103
#  244 176 132 207 183  94 220 170  48  81  25 142 240 173   4 149 115 125
#  119 229  93  14   0 118 192  44  76 182 252 161  56   3 216  85  88 202
#  123 249 235 185 104 108 191   2  57 198 101  45 243 154  80   6 102 221
#   82 234 209 116 203  74 218  26 172 129 122 155  99  37 128 135  87 167
#  111  29  72  10 200 247 145 147  70  46 140 133  31 130 160  53 189  61
#  150 114  40 204 245 226 238 255  84 228 177 168 211  36  19  97 143 179
#    7  17 197 109 153 138 106 232  68  33  67 187 174   8 112  50 224  63
#   79  12  65 217  91 196 223  42  23 251  78 253  55  27  34 164 215 162
#   21  51 206 210 230  75 157  32 159 126 152 165  59 237 121 213  38 136
#   89 194 180 241]
# Coste asociado a la mejor solución (Lamarckiano): 44901164

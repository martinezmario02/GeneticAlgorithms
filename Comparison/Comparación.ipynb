# %% [markdown]
# # Lectura de datos

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
import os
import numpy as np
import random
import time
import matplotlib.pyplot as plt

# Ruta de la carpeta de datos y resultados
data_folder = '/content/drive/MyDrive/MÁSTER/IC/P2/data/'
results_folder = '/content/drive/MyDrive/MÁSTER/IC/P2/resultados/'

# Establecer la semilla
seed = 2024
random.seed(seed)
np.random.seed(seed)

# Función para cargar los datos desde los archivos
def load_data(file_path):
    with open(file_path, 'r') as f:
        lines = f.readlines()

    # Eliminar líneas vacías y espacios en blanco
    lines = [line.strip() for line in lines if line.strip()]

    # Extraer dimensiones
    n = int(lines[0])

    # Inicializar listas para flujo y distancias
    all_numbers = []

    # Leer todos los números
    for line in lines[1:]:
        all_numbers.extend(list(map(int, line.split())))

    # Dividir los números en las matrices de flujo y distancia
    total_numbers = len(all_numbers)
    if total_numbers != 2 * n * n:
        raise ValueError(f"El número de elementos ({total_numbers}) no coincide con el esperado para dos matrices {n}x{n} ({2*n*n}).")

    flow = np.array(all_numbers[:n*n]).reshape(n, n)
    distances = np.array(all_numbers[n*n:]).reshape(n, n)

    return flow, distances

# %% [markdown]
# # Algoritmo genético básico

# %%
def fitness_pop(population, flow, distances):
    return np.sum(flow[np.newaxis, :, :] * distances[population[:,:,np.newaxis], population[:, np.newaxis, :]], axis=(1, 2))

def tournament_selection(population, fitness_vals, tournament_size=5):
    selected = []
    for _ in range(len(population)):
        tournament = random.sample(range(len(population)), tournament_size)
        tournament_fitness = [fitness_vals[i] for i in tournament]
        winner = tournament[tournament_fitness.index(min(tournament_fitness))]
        selected.append(population[winner])
    return np.array(selected)

def ox_crossover(parent1, parent2):
    size = len(parent1)
    start, end = sorted(np.random.choice(range(size), 2, replace=False))

    child = -np.ones(size, dtype=int)
    child[start:end+1] = parent1[start:end+1]

    idx = 0
    for i in range(size):
        if child[i] == -1:
            while parent2[idx] in child:
                idx += 1
            child[i] = parent2[idx]
    return child

def swap_mutation(individual, mutation_prob=0.05):
    if random.random() < mutation_prob:
        i, j = np.random.choice(range(len(individual)), 2, replace=False)
        individual[i], individual[j] = individual[j], individual[i]
    return individual

def genetic_algorithm(flow, distances, population_size=1000, generations=500, crossover_prob=0.9, mutation_prob=0.05, tournament_size=5):
    num_cities = flow.shape[0]
    population = np.array([np.random.permutation(np.arange(num_cities)) for _ in range(population_size)])

    # Evaluación inicial de la población
    fitness_vals = fitness_pop(population, flow, distances)

    # Variables para control de generaciones sin mejora
    best_fitness = float('inf')
    generations_without_improvement = 0

    # Ciclo de generaciones
    for generation in range(generations):
        # Selección por torneo
        selected_population = tournament_selection(population, fitness_vals, tournament_size)

        # Cruzamiento (crossover)
        offspring = []
        for i in range(0, population_size, 2):
            if random.random() < crossover_prob:
                child1 = ox_crossover(selected_population[i], selected_population[i + 1])
                child2 = ox_crossover(selected_population[i + 1], selected_population[i])
            else:
                child1, child2 = selected_population[i], selected_population[i + 1]
            offspring.append(child1)
            offspring.append(child2)

        # Mutación
        population = np.array([swap_mutation(individual, mutation_prob) for individual in offspring])

        # Evaluación de la nueva población
        fitness_vals = fitness_pop(population, flow, distances)

        # Mejor individuo de esta generación
        current_best_fitness = np.min(fitness_vals)
        if current_best_fitness < best_fitness:
            best_fitness = current_best_fitness
            generations_without_improvement = 0
        else:
            generations_without_improvement += 1

        print(f"Generación {generation + 1}: Mejor coste = {current_best_fitness}")

        # Detener si no hay mejora en 15 generaciones consecutivas
        if generations_without_improvement >= 15:
            print(f"Terminando en la generación {generation + 1} por falta de mejora.")
            break

    # Resultados finales: Mejor solución y su coste
    best_idx = np.argmin(fitness_vals)
    return population[best_idx], fitness_vals[best_idx]

# %% [markdown]
# # Algoritmo Baldwiniano

# %%
def baldwinian_genetic_algorithm(flow, distances, population_size=1000, generations=500, crossover_prob=0.9, mutation_prob=0.05, tournament_size=5):
    def hill_climbing_optimized(individual):
        current = individual.copy()
        current_fitness = fitness_pop(np.array([current]), flow, distances)[0]
        for _ in range(100):
            i, j = np.random.choice(range(len(current)), 2, replace=False)
            neighbor = current.copy()
            neighbor[i], neighbor[j] = neighbor[j], neighbor[i]
            delta_fitness = calculate_fitness_delta(current, i, j)
            if delta_fitness < 0:
                current = neighbor
                current_fitness += delta_fitness
        return current

    def calculate_fitness_delta(individual, i, j):
        delta = 0
        for k in range(len(individual)):
            if k != i and k != j:
                delta += (flow[i, k] - flow[j, k]) * (distances[individual[j], individual[k]] - distances[individual[i], individual[k]])
                delta += (flow[k, i] - flow[k, j]) * (distances[individual[k], individual[j]] - distances[individual[k], individual[i]])
        return delta

    population = np.array([np.random.permutation(np.arange(flow.shape[0])) for _ in range(population_size)])
    best_fitness = float('inf')
    generations_without_improvement = 0

    for generation in range(generations):
        fitness_vals = fitness_pop(population, flow, distances)

        # Mejora con Hill Climbing Baldwiniano
        top_individuals = population[np.argsort(fitness_vals)[:int(0.1 * population_size)]]
        improved_population = [hill_climbing_optimized(ind) for ind in top_individuals]

        # Reemplazar parte de la población con los mejores mejorados
        population[:len(improved_population)] = improved_population

        current_best_fitness = np.min(fitness_vals)

        if current_best_fitness < best_fitness:
            best_fitness = current_best_fitness
            generations_without_improvement = 0
        else:
            generations_without_improvement += 1

        print(f"Generación {generation + 1}: Mejor coste = {current_best_fitness}")

        if generations_without_improvement >= 15:
            print(f"Terminando en la generación {generation + 1} por falta de mejora.")
            break

    best_idx = np.argmin(fitness_vals)
    return population[best_idx], fitness_vals[best_idx]

# %% [markdown]
# # Algoritmo Lamarckiano

# %%
def lamarckian_genetic_algorithm(flow, distances, population_size=500, generations=200, crossover_prob=0.9, mutation_prob=0.05):
    def hill_climbing_optimized(individual):
        current = individual.copy()
        current_fitness = fitness_pop(np.array([current]), flow, distances)[0]
        for _ in range(100):
            i, j = np.random.choice(range(len(current)), 2, replace=False)
            neighbor = current.copy()
            neighbor[i], neighbor[j] = neighbor[j], neighbor[i]
            delta_fitness = calculate_fitness_delta(current, i, j)
            if delta_fitness < 0:
                current = neighbor
                current_fitness += delta_fitness
        return current

    def calculate_fitness_delta(individual, i, j):
        delta = 0
        for k in range(len(individual)):
            if k != i and k != j:
                delta += (flow[i, k] - flow[j, k]) * (distances[individual[j], individual[k]] - distances[individual[i], individual[k]])
                delta += (flow[k, i] - flow[k, j]) * (distances[individual[k], individual[j]] - distances[individual[k], individual[i]])
        return delta

    population = np.array([np.random.permutation(np.arange(flow.shape[0])) for _ in range(population_size)])
    best_fitness = float('inf')
    generations_without_improvement = 0

    for generation in range(generations):
        # Aplicar Hill Climbing Lamarckiano a toda la población
        improved_population = [hill_climbing_optimized(ind) for ind in population]

        # Actualizar población con individuos optimizados
        population[:] = improved_population

        fitness_vals = fitness_pop(population, flow, distances)

        current_best_fitness = np.min(fitness_vals)

        if current_best_fitness < best_fitness:
            best_fitness = current_best_fitness
            generations_without_improvement = 0
        else:
            generations_without_improvement += 1

        print(f"Generación {generation + 1}: Mejor coste = {current_best_fitness}")

        if generations_without_improvement >= 15:
            print(f"Terminando en la generación {generation + 1} por falta de mejora.")
            break

    best_idx = np.argmin(fitness_vals)
    return population[best_idx], fitness_vals[best_idx]

# %% [markdown]
# # Ejecución del algoritmos (de golpe)

# %%
# Función principal para ejecutar los experimentos
def run_experiments(folder_path):
    results = {}
    files = [f for f in os.listdir(folder_path) if f.endswith('.dat')]
    folder_path = os.path.abspath(folder_path)

    for file in files:
        print(f"Procesando archivo: {file}")
        file_path = os.path.join(folder_path, file)
        flow, distances = load_data(file_path)

        # Inicializar almacenamiento de resultados por fichero
        results[file] = {
            "standard": {"fitness": [], "time": 0},
            "baldwinian": {"fitness": [], "time": 0},
            "lamarckian": {"fitness": [], "time": 0}
        }

        # Ejecutar algoritmo estándar
        start_time = time.time()
        best_standard, fitness_standard = genetic_algorithm(flow, distances)
        results[file]["standard"]["time"] = time.time() - start_time
        results[file]["standard"]["fitness"] = fitness_standard

        # Ejecutar algoritmo baldwiniano
        start_time = time.time()
        best_baldwinian, fitness_baldwinian = baldwinian_genetic_algorithm(flow, distances)
        results[file]["baldwinian"]["time"] = time.time() - start_time
        results[file]["baldwinian"]["fitness"] = fitness_baldwinian

        # Ejecutar algoritmo lamarckiano
        start_time = time.time()
        best_lamarckian, fitness_lamarckian = lamarckian_genetic_algorithm(flow, distances)
        results[file]["lamarckian"]["time"] = time.time() - start_time
        results[file]["lamarckian"]["fitness"] = fitness_lamarckian

    # Comparar y visualizar resultados
    visualize_results(results)

def visualize_results(results):
    for file, data in results.items():
        print(f"Generando gráficos para: {file}")

        # Graficar evolución del fitness
        plt.figure(figsize=(12, 6))
        plt.plot(data["standard"]["fitness"], label="Estándar")
        plt.plot(data["baldwinian"]["fitness"], label="Baldwiniana")
        plt.plot(data["lamarckian"]["fitness"], label="Lamarckiana")
        plt.xlabel("Generación")
        plt.ylabel("Fitness (Mejor Solución)")
        plt.title(f"Evolución del Fitness - {file}")
        plt.legend()
        plt.grid()
        plt.savefig(os.path.join(results_folder, f"fitness_evolution_{file}.png"))
        plt.show()

        # Comparar tiempos de ejecución
        times = [
            data["standard"]["time"],
            data["baldwinian"]["time"],
            data["lamarckian"]["time"]
        ]
        algorithms = ["Estándar", "Baldwiniana", "Lamarckiana"]

        plt.figure(figsize=(8, 5))
        plt.bar(algorithms, times, color=["blue", "orange", "green"])
        plt.ylabel("Tiempo de Ejecución (s)")
        plt.title(f"Tiempos de Ejecución - {file}")
        plt.grid(axis="y")
        plt.savefig(os.path.join(results_folder, f"execution_times_{file}.png"))
        plt.show()

# Ejecutar experimentos
run_experiments(data_folder)
# Out:
# Procesando archivo: bur26a.dat
# Generación 1: Mejor coste = 5600885
# Generación 2: Mejor coste = 5579223
# Generación 3: Mejor coste = 5579223
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-6-15f566a6b82a>", line 74, in <cell line: 0>
#     run_experiments(data_folder)
#   File "<ipython-input-6-15f566a6b82a>", line 21, in run_experiments
#     best_standard, fitness_standard = genetic_algorithm(flow, distances)
#                                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<ipython-input-3-aaee0981d08f>", line 54, in genetic_algorithm
#     child1 = ox_crossover(selected_population[i], selected_population[i + 1])
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<ipython-input-3-aaee0981d08f>", line None, in ox_crossover
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
#           ^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#                                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/inspect.py", line 1739, in getinnerframes
#     traceback_info = getframeinfo(tb, context)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/inspect.py", line 1686, in getframeinfo
#     start = lineno - 1 - context//2
#             ~~~~~~~^~~
# TypeError: unsupported operand type(s) for -: 'NoneType' and 'int'
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-6-15f566a6b82a>", line 74, in <cell line: 0>
#     run_experiments(data_folder)
#   File "<ipython-input-6-15f566a6b82a>", line 21, in run_experiments
#     best_standard, fitness_standard = genetic_algorithm(flow, distances)
#                                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<ipython-input-3-aaee0981d08f>", line 54, in genetic_algorithm
#     child1 = ox_crossover(selected_population[i], selected_population[i + 1])
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<ipython-input-3-aaee0981d08f>", line None, in ox_crossover
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
#           ^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3473, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3575, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 2101, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/ultratb.py", line 1124, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#                                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
#            ^^^^^^^^^^^^
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
#           ^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#                                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/inspect.py", line 1739, in getinnerframes
#     traceback_info = getframeinfo(tb, context)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/inspect.py", line 1686, in getframeinfo
#     start = lineno - 1 - context//2
#             ~~~~~~~^~~
# TypeError: unsupported operand type(s) for -: 'NoneType' and 'int'
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-6-15f566a6b82a>", line 74, in <cell line: 0>
#     run_experiments(data_folder)
#   File "<ipython-input-6-15f566a6b82a>", line 21, in run_experiments
#     best_standard, fitness_standard = genetic_algorithm(flow, distances)
#                                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<ipython-input-3-aaee0981d08f>", line 54, in genetic_algorithm
#     child1 = ox_crossover(selected_population[i], selected_population[i + 1])
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<ipython-input-3-aaee0981d08f>", line None, in ox_crossover
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
#           ^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3473, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3575, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 2101, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/ultratb.py", line 1124, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#                                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
#            ^^^^^^^^^^^^
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
#           ^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3030, in _run_cell
#     return runner(coro)
#            ^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/async_helpers.py", line 78, in _pseudo_sync_runner
#     coro.send(None)
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3257, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3492, in run_ast_nodes
#     self.showtraceback()
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 2101, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/ultratb.py", line 1142, in structured_traceback
#     formatted_exceptions += self.format_exception_as_a_whole(etype, evalue, etb, lines_of_context,
#                             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#                                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
#            ^^^^^^^^^^^^
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
#           ^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#                                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/inspect.py", line 1739, in getinnerframes
#     traceback_info = getframeinfo(tb, context)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/inspect.py", line 1686, in getframeinfo
#     start = lineno - 1 - context//2
#             ~~~~~~~^~~
# TypeError: unsupported operand type(s) for -: 'NoneType' and 'int'

# %% [markdown]
# # Ejecución de algoritmos (dividida)

# %%
import pickle
import os

def run_experiments_part(folder_path, start_index, end_index, results_file):
    results = {}
    files = [f for f in os.listdir(folder_path) if f.endswith('.dat')]
    folder_path = os.path.abspath(folder_path)

    for file in files[start_index:end_index]:
        print(f"Procesando archivo: {file}")
        file_path = os.path.join(folder_path, file)
        flow, distances = load_data(file_path)

        results[file] = {
            "standard": {"fitness": [], "time": 0},
            "baldwinian": {"fitness": [], "time": 0},
            "lamarckian": {"fitness": [], "time": 0}
        }

        for algorithm in ["standard", "baldwinian", "lamarckian"]:
            start_time = time.time()
            if algorithm == "standard":
                best, fitness = genetic_algorithm(flow, distances)
            elif algorithm == "baldwinian":
                best, fitness = baldwinian_genetic_algorithm(flow, distances)
            else:
                best, fitness = lamarckian_genetic_algorithm(flow, distances)

            results[file][algorithm]["time"] = time.time() - start_time
            results[file][algorithm]["fitness"] = fitness

    # Guardar resultados en el archivo
    with open(results_file, 'wb') as f:
        pickle.dump(results, f)

def load_results(results_file):
    with open(results_file, 'rb') as f:
        return pickle.load(f)

# %%
# Define files before using it
files = [f for f in os.listdir(data_folder) if f.endswith('.dat')]

# Ejecutar la primera parte
run_experiments_part(data_folder, 0, len(files)//2, 'results_part1.pkl')
# Out:
# Procesando archivo: bur26a.dat
# Generación 1: Mejor coste = 5600885
# Generación 2: Mejor coste = 5579223
# Generación 3: Mejor coste = 5579223
# Generación 4: Mejor coste = 5578942
# Generación 5: Mejor coste = 5570937
# Generación 6: Mejor coste = 5530176
# Generación 7: Mejor coste = 5550886
# Generación 8: Mejor coste = 5548569
# Generación 9: Mejor coste = 5520836
# Generación 10: Mejor coste = 5500683
# Generación 11: Mejor coste = 5522543
# Generación 12: Mejor coste = 5498450
# Generación 13: Mejor coste = 5498450
# Generación 14: Mejor coste = 5483913
# Generación 15: Mejor coste = 5493484
# Generación 16: Mejor coste = 5488926
# Generación 17: Mejor coste = 5487993
# Generación 18: Mejor coste = 5481470
# Generación 19: Mejor coste = 5481470
# Generación 20: Mejor coste = 5476795
# Generación 21: Mejor coste = 5471024
# Generación 22: Mejor coste = 5468365
# Generación 23: Mejor coste = 5468365
# Generación 24: Mejor coste = 5468743
# Generación 25: Mejor coste = 5467296
# Generación 26: Mejor coste = 5467211
# Generación 27: Mejor coste = 5466787
# Generación 28: Mejor coste = 5466787
# Generación 29: Mejor coste = 5466752
# Generación 30: Mejor coste = 5463799
# Generación 31: Mejor coste = 5452467
# Generación 32: Mejor coste = 5452467
# Generación 33: Mejor coste = 5451794
# Generación 34: Mejor coste = 5451794
# Generación 35: Mejor coste = 5447329
# Generación 36: Mejor coste = 5447292
# Generación 37: Mejor coste = 5446933
# Generación 38: Mejor coste = 5445919
# Generación 39: Mejor coste = 5441893
# Generación 40: Mejor coste = 5440569
# Generación 41: Mejor coste = 5440569
# Generación 42: Mejor coste = 5440569
# Generación 43: Mejor coste = 5440569
# Generación 44: Mejor coste = 5440536
# Generación 45: Mejor coste = 5440536
# Generación 46: Mejor coste = 5440536
# Generación 47: Mejor coste = 5439426
# Generación 48: Mejor coste = 5439426
# Generación 49: Mejor coste = 5439426
# Generación 50: Mejor coste = 5439426
# Generación 51: Mejor coste = 5439393
# Generación 52: Mejor coste = 5439393
# Generación 53: Mejor coste = 5439393
# Generación 54: Mejor coste = 5439393
# Generación 55: Mejor coste = 5439393
# Generación 56: Mejor coste = 5439393
# Generación 57: Mejor coste = 5439393
# Generación 58: Mejor coste = 5439393
# Generación 59: Mejor coste = 5439267
# Generación 60: Mejor coste = 5439267
# Generación 61: Mejor coste = 5439267
# Generación 62: Mejor coste = 5439267
# Generación 63: Mejor coste = 5439169
# Generación 64: Mejor coste = 5439169
# Generación 65: Mejor coste = 5439169
# Generación 66: Mejor coste = 5439043
# Generación 67: Mejor coste = 5439043
# Generación 68: Mejor coste = 5439043
# Generación 69: Mejor coste = 5439043
# Generación 70: Mejor coste = 5439043
# Generación 71: Mejor coste = 5439043
# Generación 72: Mejor coste = 5439043
# Generación 73: Mejor coste = 5439043
# Generación 74: Mejor coste = 5439043
# Generación 75: Mejor coste = 5439043
# Generación 76: Mejor coste = 5439043
# Generación 77: Mejor coste = 5439043
# Generación 78: Mejor coste = 5439043
# Generación 79: Mejor coste = 5439043
# Generación 80: Mejor coste = 5439043
# Generación 81: Mejor coste = 5439043
# Terminando en la generación 81 por falta de mejora.
# Generación 1: Mejor coste = 5600041
# Generación 2: Mejor coste = 5472048
# Generación 3: Mejor coste = 5444573
# Generación 4: Mejor coste = 5443602
# Generación 5: Mejor coste = 5435748
# Generación 6: Mejor coste = 5432692
# Generación 7: Mejor coste = 5432582
# Generación 8: Mejor coste = 5432582
# Generación 9: Mejor coste = 5431784
# Generación 10: Mejor coste = 5431784
# Generación 11: Mejor coste = 5431784
# Generación 12: Mejor coste = 5430570
# Generación 13: Mejor coste = 5430570
# Generación 14: Mejor coste = 5429990
# Generación 15: Mejor coste = 5429296
# Generación 16: Mejor coste = 5428321
# Generación 17: Mejor coste = 5427851
# Generación 18: Mejor coste = 5426670
# Generación 19: Mejor coste = 5426670
# Generación 20: Mejor coste = 5426670
# Generación 21: Mejor coste = 5426670
# Generación 22: Mejor coste = 5426670
# Generación 23: Mejor coste = 5426670
# Generación 24: Mejor coste = 5426670
# Generación 25: Mejor coste = 5426670
# Generación 26: Mejor coste = 5426670
# Generación 27: Mejor coste = 5426670
# Generación 28: Mejor coste = 5426670
# Generación 29: Mejor coste = 5426670
# Generación 30: Mejor coste = 5426670
# Generación 31: Mejor coste = 5426670
# Generación 32: Mejor coste = 5426670
# Generación 33: Mejor coste = 5426670
# Terminando en la generación 33 por falta de mejora.
# Generación 1: Mejor coste = 5465978
# Generación 2: Mejor coste = 5446749
# Generación 3: Mejor coste = 5436296
# Generación 4: Mejor coste = 5436296
# Generación 5: Mejor coste = 5432739
# Generación 6: Mejor coste = 5430954
# Generación 7: Mejor coste = 5429690
# Generación 8: Mejor coste = 5429431
# Generación 9: Mejor coste = 5429431
# Generación 10: Mejor coste = 5428706
# Generación 11: Mejor coste = 5428121
# Generación 12: Mejor coste = 5428121
# Generación 13: Mejor coste = 5427110
# Generación 14: Mejor coste = 5426670
# Generación 15: Mejor coste = 5426670
# Generación 16: Mejor coste = 5426670
# Generación 17: Mejor coste = 5426670
# Generación 18: Mejor coste = 5426670
# Generación 19: Mejor coste = 5426670
# Generación 20: Mejor coste = 5426670
# Generación 21: Mejor coste = 5426670
# Generación 22: Mejor coste = 5426670
# Generación 23: Mejor coste = 5426670
# Generación 24: Mejor coste = 5426670
# Generación 25: Mejor coste = 5426670
# Generación 26: Mejor coste = 5426670
# Generación 27: Mejor coste = 5426670
# Generación 28: Mejor coste = 5426670
# Generación 29: Mejor coste = 5426670
# Terminando en la generación 29 por falta de mejora.
# Procesando archivo: bur26b.dat
# Generación 1: Mejor coste = 3926265
# Generación 2: Mejor coste = 3931245
# Generación 3: Mejor coste = 3932511
# Generación 4: Mejor coste = 3932511
# Generación 5: Mejor coste = 3924948
# Generación 6: Mejor coste = 3906346
# Generación 7: Mejor coste = 3914757
# Generación 8: Mejor coste = 3904182
# Generación 9: Mejor coste = 3890706
# Generación 10: Mejor coste = 3898477
# Generación 11: Mejor coste = 3888227
# Generación 12: Mejor coste = 3872836
# Generación 13: Mejor coste = 3872836
# Generación 14: Mejor coste = 3877883
# Generación 15: Mejor coste = 3872939
# Generación 16: Mejor coste = 3877746
# Generación 17: Mejor coste = 3869563
# Generación 18: Mejor coste = 3865913
# Generación 19: Mejor coste = 3867539
# Generación 20: Mejor coste = 3865112
# Generación 21: Mejor coste = 3862421
# Generación 22: Mejor coste = 3864230
# Generación 23: Mejor coste = 3851937
# Generación 24: Mejor coste = 3852205
# Generación 25: Mejor coste = 3852324
# Generación 26: Mejor coste = 3852324
# Generación 27: Mejor coste = 3845689
# Generación 28: Mejor coste = 3843705
# Generación 29: Mejor coste = 3838211
# Generación 30: Mejor coste = 3837457
# Generación 31: Mejor coste = 3837457
# Generación 32: Mejor coste = 3833589
# Generación 33: Mejor coste = 3832606
# Generación 34: Mejor coste = 3832305
# Generación 35: Mejor coste = 3832545
# Generación 36: Mejor coste = 3832481
# Generación 37: Mejor coste = 3831526
# Generación 38: Mejor coste = 3829539
# Generación 39: Mejor coste = 3828608
# Generación 40: Mejor coste = 3828608
# Generación 41: Mejor coste = 3827700
# Generación 42: Mejor coste = 3827700
# Generación 43: Mejor coste = 3827700
# Generación 44: Mejor coste = 3827602
# Generación 45: Mejor coste = 3827297
# Generación 46: Mejor coste = 3826638
# Generación 47: Mejor coste = 3826638
# Generación 48: Mejor coste = 3826560
# Generación 49: Mejor coste = 3826560
# Generación 50: Mejor coste = 3826319
# Generación 51: Mejor coste = 3826241
# Generación 52: Mejor coste = 3826241
# Generación 53: Mejor coste = 3826241
# Generación 54: Mejor coste = 3826241
# Generación 55: Mejor coste = 3826085
# Generación 56: Mejor coste = 3826085
# Generación 57: Mejor coste = 3826085
# Generación 58: Mejor coste = 3826085
# Generación 59: Mejor coste = 3826050
# Generación 60: Mejor coste = 3826050
# Generación 61: Mejor coste = 3826050
# Generación 62: Mejor coste = 3826050
# Generación 63: Mejor coste = 3826050
# Generación 64: Mejor coste = 3825924
# Generación 65: Mejor coste = 3826050
# Generación 66: Mejor coste = 3826050
# Generación 67: Mejor coste = 3826050
# Generación 68: Mejor coste = 3825924
# Generación 69: Mejor coste = 3826050
# Generación 70: Mejor coste = 3826015
# Generación 71: Mejor coste = 3826015
# Generación 72: Mejor coste = 3825924
# Generación 73: Mejor coste = 3825924
# Generación 74: Mejor coste = 3825924
# Generación 75: Mejor coste = 3825924
# Generación 76: Mejor coste = 3825924
# Generación 77: Mejor coste = 3825924
# Generación 78: Mejor coste = 3825924
# Generación 79: Mejor coste = 3825924
# Terminando en la generación 79 por falta de mejora.
# Generación 1: Mejor coste = 3969496
# Generación 2: Mejor coste = 3841408
# Generación 3: Mejor coste = 3835220
# Generación 4: Mejor coste = 3827288
# Generación 5: Mejor coste = 3827192
# Generación 6: Mejor coste = 3826068
# Generación 7: Mejor coste = 3825599
# Generación 8: Mejor coste = 3825599
# Generación 9: Mejor coste = 3825374
# Generación 10: Mejor coste = 3825171
# Generación 11: Mejor coste = 3825066
# Generación 12: Mejor coste = 3825031
# Generación 13: Mejor coste = 3823622
# Generación 14: Mejor coste = 3823163
# Generación 15: Mejor coste = 3822348
# Generación 16: Mejor coste = 3821084
# Generación 17: Mejor coste = 3821084
# Generación 18: Mejor coste = 3820999
# Generación 19: Mejor coste = 3817952
# Generación 20: Mejor coste = 3817952
# Generación 21: Mejor coste = 3817952
# Generación 22: Mejor coste = 3817952
# Generación 23: Mejor coste = 3817952
# Generación 24: Mejor coste = 3817952
# Generación 25: Mejor coste = 3817952
# Generación 26: Mejor coste = 3817952
# Generación 27: Mejor coste = 3817952
# Generación 28: Mejor coste = 3817952
# Generación 29: Mejor coste = 3817952
# Generación 30: Mejor coste = 3817952
# Generación 31: Mejor coste = 3817952
# Generación 32: Mejor coste = 3817952
# Generación 33: Mejor coste = 3817952
# Generación 34: Mejor coste = 3817952
# Terminando en la generación 34 por falta de mejora.
# Generación 1: Mejor coste = 3848485
# Generación 2: Mejor coste = 3824680
# Generación 3: Mejor coste = 3822888
# Generación 4: Mejor coste = 3819401
# Generación 5: Mejor coste = 3819401
# Generación 6: Mejor coste = 3819247
# Generación 7: Mejor coste = 3819184
# Generación 8: Mejor coste = 3818734
# Generación 9: Mejor coste = 3818734
# Generación 10: Mejor coste = 3818734
# Generación 11: Mejor coste = 3818734
# Generación 12: Mejor coste = 3818707
# Generación 13: Mejor coste = 3818707
# Generación 14: Mejor coste = 3818583
# Generación 15: Mejor coste = 3818505
# Generación 16: Mejor coste = 3818505
# Generación 17: Mejor coste = 3818372
# Generación 18: Mejor coste = 3818372
# Generación 19: Mejor coste = 3818372
# Generación 20: Mejor coste = 3818032
# Generación 21: Mejor coste = 3817948
# Generación 22: Mejor coste = 3817948
# Generación 23: Mejor coste = 3817948
# Generación 24: Mejor coste = 3817948
# Generación 25: Mejor coste = 3817948
# Generación 26: Mejor coste = 3817948
# Generación 27: Mejor coste = 3817948
# Generación 28: Mejor coste = 3817948
# Generación 29: Mejor coste = 3817948
# Generación 30: Mejor coste = 3817948
# Generación 31: Mejor coste = 3817948
# Generación 32: Mejor coste = 3817948
# Generación 33: Mejor coste = 3817948
# Generación 34: Mejor coste = 3817948
# Generación 35: Mejor coste = 3817948
# Generación 36: Mejor coste = 3817948
# Terminando en la generación 36 por falta de mejora.
# Procesando archivo: bur26c.dat
# Generación 1: Mejor coste = 5616723
# Generación 2: Mejor coste = 5616723
# Generación 3: Mejor coste = 5603934
# Generación 4: Mejor coste = 5610042
# Generación 5: Mejor coste = 5568311
# Generación 6: Mejor coste = 5580167
# Generación 7: Mejor coste = 5558578
# Generación 8: Mejor coste = 5538688
# Generación 9: Mejor coste = 5528530
# Generación 10: Mejor coste = 5528530
# Generación 11: Mejor coste = 5525404
# Generación 12: Mejor coste = 5523655
# Generación 13: Mejor coste = 5525404
# Generación 14: Mejor coste = 5523358
# Generación 15: Mejor coste = 5522627
# Generación 16: Mejor coste = 5503057
# Generación 17: Mejor coste = 5512910
# Generación 18: Mejor coste = 5488216
# Generación 19: Mejor coste = 5489795
# Generación 20: Mejor coste = 5488794
# Generación 21: Mejor coste = 5481782
# Generación 22: Mejor coste = 5481782
# Generación 23: Mejor coste = 5468761
# Generación 24: Mejor coste = 5466978
# Generación 25: Mejor coste = 5465415
# Generación 26: Mejor coste = 5458028
# Generación 27: Mejor coste = 5458028
# Generación 28: Mejor coste = 5460021
# Generación 29: Mejor coste = 5454561
# Generación 30: Mejor coste = 5452827
# Generación 31: Mejor coste = 5451145
# Generación 32: Mejor coste = 5450300
# Generación 33: Mejor coste = 5448255
# Generación 34: Mejor coste = 5448220
# Generación 35: Mejor coste = 5445818
# Generación 36: Mejor coste = 5445375
# Generación 37: Mejor coste = 5445375
# Generación 38: Mejor coste = 5445375
# Generación 39: Mejor coste = 5445237
# Generación 40: Mejor coste = 5445237
# Generación 41: Mejor coste = 5445237
# Generación 42: Mejor coste = 5444625
# Generación 43: Mejor coste = 5444081
# Generación 44: Mejor coste = 5444081
# Generación 45: Mejor coste = 5443565
# Generación 46: Mejor coste = 5443518
# Generación 47: Mejor coste = 5443518
# Generación 48: Mejor coste = 5441462
# Generación 49: Mejor coste = 5441462
# Generación 50: Mejor coste = 5441462
# Generación 51: Mejor coste = 5441462
# Generación 52: Mejor coste = 5441462
# Generación 53: Mejor coste = 5441462
# Generación 54: Mejor coste = 5441462
# Generación 55: Mejor coste = 5441462
# Generación 56: Mejor coste = 5441114
# Generación 57: Mejor coste = 5440363
# Generación 58: Mejor coste = 5440363
# Generación 59: Mejor coste = 5440363
# Generación 60: Mejor coste = 5440363
# Generación 61: Mejor coste = 5440363
# Generación 62: Mejor coste = 5440363
# Generación 63: Mejor coste = 5439590
# Generación 64: Mejor coste = 5438325
# Generación 65: Mejor coste = 5438325
# Generación 66: Mejor coste = 5438325
# Generación 67: Mejor coste = 5435675
# Generación 68: Mejor coste = 5435675
# Generación 69: Mejor coste = 5435675
# Generación 70: Mejor coste = 5434640
# Generación 71: Mejor coste = 5434640
# Generación 72: Mejor coste = 5434640
# Generación 73: Mejor coste = 5434640
# Generación 74: Mejor coste = 5433539
# Generación 75: Mejor coste = 5433431
# Generación 76: Mejor coste = 5433431
# Generación 77: Mejor coste = 5433021
# Generación 78: Mejor coste = 5432316
# Generación 79: Mejor coste = 5432009
# Generación 80: Mejor coste = 5431693
# Generación 81: Mejor coste = 5431153
# Generación 82: Mejor coste = 5431153
# Generación 83: Mejor coste = 5431153
# Generación 84: Mejor coste = 5430502
# Generación 85: Mejor coste = 5430502
# Generación 86: Mejor coste = 5430502
# Generación 87: Mejor coste = 5430502
# Generación 88: Mejor coste = 5429961
# Generación 89: Mejor coste = 5429961
# Generación 90: Mejor coste = 5429961
# Generación 91: Mejor coste = 5429884
# Generación 92: Mejor coste = 5429884
# Generación 93: Mejor coste = 5429884
# Generación 94: Mejor coste = 5429961
# Generación 95: Mejor coste = 5429862
# Generación 96: Mejor coste = 5429780
# Generación 97: Mejor coste = 5429780
# Generación 98: Mejor coste = 5429780
# Generación 99: Mejor coste = 5429780
# Generación 100: Mejor coste = 5429780
# Generación 101: Mejor coste = 5429780
# Generación 102: Mejor coste = 5429780
# Generación 103: Mejor coste = 5429780
# Generación 104: Mejor coste = 5429560
# Generación 105: Mejor coste = 5429560
# Generación 106: Mejor coste = 5429560
# Generación 107: Mejor coste = 5429560
# Generación 108: Mejor coste = 5429560
# Generación 109: Mejor coste = 5429494
# Generación 110: Mejor coste = 5429494
# Generación 111: Mejor coste = 5429494
# Generación 112: Mejor coste = 5429494
# Generación 113: Mejor coste = 5429494
# Generación 114: Mejor coste = 5429494
# Generación 115: Mejor coste = 5429494
# Generación 116: Mejor coste = 5429494
# Generación 117: Mejor coste = 5429494
# Generación 118: Mejor coste = 5429494
# Generación 119: Mejor coste = 5429494
# Generación 120: Mejor coste = 5429494
# Generación 121: Mejor coste = 5429494
# Generación 122: Mejor coste = 5429408
# Generación 123: Mejor coste = 5429408
# Generación 124: Mejor coste = 5429408
# Generación 125: Mejor coste = 5429408
# Generación 126: Mejor coste = 5429408
# Generación 127: Mejor coste = 5429408
# Generación 128: Mejor coste = 5429408
# Generación 129: Mejor coste = 5429408
# Generación 130: Mejor coste = 5429408
# Generación 131: Mejor coste = 5429408
# Generación 132: Mejor coste = 5429408
# Generación 133: Mejor coste = 5429408
# Generación 134: Mejor coste = 5429408
# Generación 135: Mejor coste = 5429408
# Generación 136: Mejor coste = 5429408
# Generación 137: Mejor coste = 5429408
# Terminando en la generación 137 por falta de mejora.
# Generación 1: Mejor coste = 5665963
# Generación 2: Mejor coste = 5471532
# Generación 3: Mejor coste = 5441202
# Generación 4: Mejor coste = 5438159
# Generación 5: Mejor coste = 5432200
# Generación 6: Mejor coste = 5429957
# Generación 7: Mejor coste = 5429475
# Generación 8: Mejor coste = 5428428
# Generación 9: Mejor coste = 5427561
# Generación 10: Mejor coste = 5427561
# Generación 11: Mejor coste = 5427322
# Generación 12: Mejor coste = 5427322
# Generación 13: Mejor coste = 5427322
# Generación 14: Mejor coste = 5427322
# Generación 15: Mejor coste = 5427322
# Generación 16: Mejor coste = 5427030
# Generación 17: Mejor coste = 5427030
# Generación 18: Mejor coste = 5427030
# Generación 19: Mejor coste = 5427030
# Generación 20: Mejor coste = 5427030
# Generación 21: Mejor coste = 5427030
# Generación 22: Mejor coste = 5427030
# Generación 23: Mejor coste = 5427030
# Generación 24: Mejor coste = 5427030
# Generación 25: Mejor coste = 5426795
# Generación 26: Mejor coste = 5426795
# Generación 27: Mejor coste = 5426795
# Generación 28: Mejor coste = 5426795
# Generación 29: Mejor coste = 5426795
# Generación 30: Mejor coste = 5426795
# Generación 31: Mejor coste = 5426795
# Generación 32: Mejor coste = 5426795
# Generación 33: Mejor coste = 5426795
# Generación 34: Mejor coste = 5426795
# Generación 35: Mejor coste = 5426795
# Generación 36: Mejor coste = 5426795
# Generación 37: Mejor coste = 5426795
# Generación 38: Mejor coste = 5426795
# Generación 39: Mejor coste = 5426795
# Generación 40: Mejor coste = 5426795
# Terminando en la generación 40 por falta de mejora.
# Generación 1: Mejor coste = 5476842
# Generación 2: Mejor coste = 5446303
# Generación 3: Mejor coste = 5436524
# Generación 4: Mejor coste = 5431800
# Generación 5: Mejor coste = 5430452
# Generación 6: Mejor coste = 5427550
# Generación 7: Mejor coste = 5427550
# Generación 8: Mejor coste = 5427550
# Generación 9: Mejor coste = 5427542
# Generación 10: Mejor coste = 5427542
# Generación 11: Mejor coste = 5426801
# Generación 12: Mejor coste = 5426801
# Generación 13: Mejor coste = 5426801
# Generación 14: Mejor coste = 5426801
# Generación 15: Mejor coste = 5426795
# Generación 16: Mejor coste = 5426795
# Generación 17: Mejor coste = 5426795
# Generación 18: Mejor coste = 5426795
# Generación 19: Mejor coste = 5426795
# Generación 20: Mejor coste = 5426795
# Generación 21: Mejor coste = 5426795
# Generación 22: Mejor coste = 5426795
# Generación 23: Mejor coste = 5426795
# Generación 24: Mejor coste = 5426795
# Generación 25: Mejor coste = 5426795
# Generación 26: Mejor coste = 5426795
# Generación 27: Mejor coste = 5426795
# Generación 28: Mejor coste = 5426795
# Generación 29: Mejor coste = 5426795
# Generación 30: Mejor coste = 5426795
# Terminando en la generación 30 por falta de mejora.
# Procesando archivo: bur26d.dat
# Generación 1: Mejor coste = 3959271
# Generación 2: Mejor coste = 3956016
# Generación 3: Mejor coste = 3943361
# Generación 4: Mejor coste = 3943361
# Generación 5: Mejor coste = 3931387
# Generación 6: Mejor coste = 3905632
# Generación 7: Mejor coste = 3905215
# Generación 8: Mejor coste = 3899050
# Generación 9: Mejor coste = 3899050
# Generación 10: Mejor coste = 3903066
# Generación 11: Mejor coste = 3895559
# Generación 12: Mejor coste = 3888858
# Generación 13: Mejor coste = 3888858
# Generación 14: Mejor coste = 3886033
# Generación 15: Mejor coste = 3885602
# Generación 16: Mejor coste = 3874453
# Generación 17: Mejor coste = 3878587
# Generación 18: Mejor coste = 3873462
# Generación 19: Mejor coste = 3860381
# Generación 20: Mejor coste = 3860381
# Generación 21: Mejor coste = 3858626
# Generación 22: Mejor coste = 3852815
# Generación 23: Mejor coste = 3852815
# Generación 24: Mejor coste = 3852815
# Generación 25: Mejor coste = 3852815
# Generación 26: Mejor coste = 3852175
# Generación 27: Mejor coste = 3852175
# Generación 28: Mejor coste = 3851000
# Generación 29: Mejor coste = 3846599
# Generación 30: Mejor coste = 3846599
# Generación 31: Mejor coste = 3844378
# Generación 32: Mejor coste = 3844378
# Generación 33: Mejor coste = 3842811
# Generación 34: Mejor coste = 3842937
# Generación 35: Mejor coste = 3842937
# Generación 36: Mejor coste = 3841645
# Generación 37: Mejor coste = 3840653
# Generación 38: Mejor coste = 3840116
# Generación 39: Mejor coste = 3840116
# Generación 40: Mejor coste = 3838727
# Generación 41: Mejor coste = 3838727
# Generación 42: Mejor coste = 3838727
# Generación 43: Mejor coste = 3838307
# Generación 44: Mejor coste = 3836073
# Generación 45: Mejor coste = 3836073
# Generación 46: Mejor coste = 3835948
# Generación 47: Mejor coste = 3835265
# Generación 48: Mejor coste = 3834843
# Generación 49: Mejor coste = 3834509
# Generación 50: Mejor coste = 3834843
# Generación 51: Mejor coste = 3834509
# Generación 52: Mejor coste = 3834212
# Generación 53: Mejor coste = 3834509
# Generación 54: Mejor coste = 3834212
# Generación 55: Mejor coste = 3834212
# Generación 56: Mejor coste = 3834212
# Generación 57: Mejor coste = 3834212
# Generación 58: Mejor coste = 3834212
# Generación 59: Mejor coste = 3834212
# Generación 60: Mejor coste = 3834212
# Generación 61: Mejor coste = 3834212
# Generación 62: Mejor coste = 3832605
# Generación 63: Mejor coste = 3832605
# Generación 64: Mejor coste = 3832605
# Generación 65: Mejor coste = 3832605
# Generación 66: Mejor coste = 3832605
# Generación 67: Mejor coste = 3831726
# Generación 68: Mejor coste = 3831726
# Generación 69: Mejor coste = 3831726
# Generación 70: Mejor coste = 3831708
# Generación 71: Mejor coste = 3831708
# Generación 72: Mejor coste = 3831708
# Generación 73: Mejor coste = 3830927
# Generación 74: Mejor coste = 3830927
# Generación 75: Mejor coste = 3830909
# Generación 76: Mejor coste = 3830909
# Generación 77: Mejor coste = 3830909
# Generación 78: Mejor coste = 3830885
# Generación 79: Mejor coste = 3830766
# Generación 80: Mejor coste = 3830462
# Generación 81: Mejor coste = 3830462
# Generación 82: Mejor coste = 3830304
# Generación 83: Mejor coste = 3830304
# Generación 84: Mejor coste = 3830304
# Generación 85: Mejor coste = 3830304
# Generación 86: Mejor coste = 3830304
# Generación 87: Mejor coste = 3830262
# Generación 88: Mejor coste = 3830262
# Generación 89: Mejor coste = 3830262
# Generación 90: Mejor coste = 3830262
# Generación 91: Mejor coste = 3830262
# Generación 92: Mejor coste = 3830262
# Generación 93: Mejor coste = 3830262
# Generación 94: Mejor coste = 3830262
# Generación 95: Mejor coste = 3830262
# Generación 96: Mejor coste = 3830262
# Generación 97: Mejor coste = 3830262
# Generación 98: Mejor coste = 3830262
# Generación 99: Mejor coste = 3830262
# Generación 100: Mejor coste = 3830262
# Generación 101: Mejor coste = 3830262
# Generación 102: Mejor coste = 3830262
# Terminando en la generación 102 por falta de mejora.
# Generación 1: Mejor coste = 3995494
# Generación 2: Mejor coste = 3851904
# Generación 3: Mejor coste = 3832173
# Generación 4: Mejor coste = 3823279
# Generación 5: Mejor coste = 3822321
# Generación 6: Mejor coste = 3822215
# Generación 7: Mejor coste = 3821969
# Generación 8: Mejor coste = 3821781
# Generación 9: Mejor coste = 3821755
# Generación 10: Mejor coste = 3821755
# Generación 11: Mejor coste = 3821755
# Generación 12: Mejor coste = 3821755
# Generación 13: Mejor coste = 3821606
# Generación 14: Mejor coste = 3821606
# Generación 15: Mejor coste = 3821526
# Generación 16: Mejor coste = 3821414
# Generación 17: Mejor coste = 3821414
# Generación 18: Mejor coste = 3821414
# Generación 19: Mejor coste = 3821232
# Generación 20: Mejor coste = 3821232
# Generación 21: Mejor coste = 3821232
# Generación 22: Mejor coste = 3821232
# Generación 23: Mejor coste = 3821225
# Generación 24: Mejor coste = 3821225
# Generación 25: Mejor coste = 3821225
# Generación 26: Mejor coste = 3821225
# Generación 27: Mejor coste = 3821225
# Generación 28: Mejor coste = 3821225
# Generación 29: Mejor coste = 3821225
# Generación 30: Mejor coste = 3821225
# Generación 31: Mejor coste = 3821225
# Generación 32: Mejor coste = 3821225
# Generación 33: Mejor coste = 3821225
# Generación 34: Mejor coste = 3821225
# Generación 35: Mejor coste = 3821225
# Generación 36: Mejor coste = 3821225
# Generación 37: Mejor coste = 3821225
# Generación 38: Mejor coste = 3821225
# Terminando en la generación 38 por falta de mejora.
# Generación 1: Mejor coste = 3831657
# Generación 2: Mejor coste = 3829173
# Generación 3: Mejor coste = 3826275
# Generación 4: Mejor coste = 3824061
# Generación 5: Mejor coste = 3823825
# Generación 6: Mejor coste = 3822211
# Generación 7: Mejor coste = 3822211
# Generación 8: Mejor coste = 3821306
# Generación 9: Mejor coste = 3821306
# Generación 10: Mejor coste = 3821299
# Generación 11: Mejor coste = 3821239
# Generación 12: Mejor coste = 3821239
# Generación 13: Mejor coste = 3821239
# Generación 14: Mejor coste = 3821239
# Generación 15: Mejor coste = 3821239
# Generación 16: Mejor coste = 3821239
# Generación 17: Mejor coste = 3821225
# Generación 18: Mejor coste = 3821225
# Generación 19: Mejor coste = 3821225
# Generación 20: Mejor coste = 3821225
# Generación 21: Mejor coste = 3821225
# Generación 22: Mejor coste = 3821225
# Generación 23: Mejor coste = 3821225
# Generación 24: Mejor coste = 3821225
# Generación 25: Mejor coste = 3821225
# Generación 26: Mejor coste = 3821225
# Generación 27: Mejor coste = 3821225
# Generación 28: Mejor coste = 3821225
# Generación 29: Mejor coste = 3821225
# Generación 30: Mejor coste = 3821225
# Generación 31: Mejor coste = 3821225
# Generación 32: Mejor coste = 3821225
# Terminando en la generación 32 por falta de mejora.
# Procesando archivo: bur26e.dat
# Generación 1: Mejor coste = 5593929
# Generación 2: Mejor coste = 5560351
# Generación 3: Mejor coste = 5565978
# Generación 4: Mejor coste = 5529212
# Generación 5: Mejor coste = 5509174
# Generación 6: Mejor coste = 5539541
# Generación 7: Mejor coste = 5520088
# Generación 8: Mejor coste = 5493170
# Generación 9: Mejor coste = 5499937
# Generación 10: Mejor coste = 5499937
# Generación 11: Mejor coste = 5497002
# Generación 12: Mejor coste = 5487377
# Generación 13: Mejor coste = 5499937
# Generación 14: Mejor coste = 5491247
# Generación 15: Mejor coste = 5475073
# Generación 16: Mejor coste = 5466445
# Generación 17: Mejor coste = 5458848
# Generación 18: Mejor coste = 5457779
# Generación 19: Mejor coste = 5457779
# Generación 20: Mejor coste = 5457779
# Generación 21: Mejor coste = 5444350
# Generación 22: Mejor coste = 5444350
# Generación 23: Mejor coste = 5444350
# Generación 24: Mejor coste = 5443678
# Generación 25: Mejor coste = 5435408
# Generación 26: Mejor coste = 5425877
# Generación 27: Mejor coste = 5425528
# Generación 28: Mejor coste = 5422461
# Generación 29: Mejor coste = 5420475
# Generación 30: Mejor coste = 5420475
# Generación 31: Mejor coste = 5420475
# Generación 32: Mejor coste = 5417336
# Generación 33: Mejor coste = 5414806
# Generación 34: Mejor coste = 5414857
# Generación 35: Mejor coste = 5414135
# Generación 36: Mejor coste = 5415361
# Generación 37: Mejor coste = 5412122
# Generación 38: Mejor coste = 5412122
# Generación 39: Mejor coste = 5412122
# Generación 40: Mejor coste = 5412071
# Generación 41: Mejor coste = 5408881
# Generación 42: Mejor coste = 5408185
# Generación 43: Mejor coste = 5408185
# Generación 44: Mejor coste = 5408185
# Generación 45: Mejor coste = 5406854
# Generación 46: Mejor coste = 5406854
# Generación 47: Mejor coste = 5406854
# Generación 48: Mejor coste = 5406854
# Generación 49: Mejor coste = 5406440
# Generación 50: Mejor coste = 5406440
# Generación 51: Mejor coste = 5405188
# Generación 52: Mejor coste = 5405188
# Generación 53: Mejor coste = 5405188
# Generación 54: Mejor coste = 5405188
# Generación 55: Mejor coste = 5405048
# Generación 56: Mejor coste = 5403945
# Generación 57: Mejor coste = 5403945
# Generación 58: Mejor coste = 5403355
# Generación 59: Mejor coste = 5403355
# Generación 60: Mejor coste = 5403215
# Generación 61: Mejor coste = 5403056
# Generación 62: Mejor coste = 5402916
# Generación 63: Mejor coste = 5401530
# Generación 64: Mejor coste = 5401530
# Generación 65: Mejor coste = 5401530
# Generación 66: Mejor coste = 5401530
# Generación 67: Mejor coste = 5401530
# Generación 68: Mejor coste = 5401530
# Generación 69: Mejor coste = 5400798
# Generación 70: Mejor coste = 5400798
# Generación 71: Mejor coste = 5400798
# Generación 72: Mejor coste = 5400798
# Generación 73: Mejor coste = 5400469
# Generación 74: Mejor coste = 5400469
# Generación 75: Mejor coste = 5400469
# Generación 76: Mejor coste = 5400469
# Generación 77: Mejor coste = 5400469
# Generación 78: Mejor coste = 5400449
# Generación 79: Mejor coste = 5400449
# Generación 80: Mejor coste = 5400449
# Generación 81: Mejor coste = 5400449
# Generación 82: Mejor coste = 5400449
# Generación 83: Mejor coste = 5400449
# Generación 84: Mejor coste = 5400449
# Generación 85: Mejor coste = 5400449
# Generación 86: Mejor coste = 5400449
# Generación 87: Mejor coste = 5400449
# Generación 88: Mejor coste = 5400449
# Generación 89: Mejor coste = 5400449
# Generación 90: Mejor coste = 5400449
# Generación 91: Mejor coste = 5400449
# Generación 92: Mejor coste = 5400449
# Generación 93: Mejor coste = 5400449
# Terminando en la generación 93 por falta de mejora.
# Generación 1: Mejor coste = 5593738
# Generación 2: Mejor coste = 5441260
# Generación 3: Mejor coste = 5398647
# Generación 4: Mejor coste = 5394708
# Generación 5: Mejor coste = 5390720
# Generación 6: Mejor coste = 5389371
# Generación 7: Mejor coste = 5388113
# Generación 8: Mejor coste = 5387936
# Generación 9: Mejor coste = 5387936
# Generación 10: Mejor coste = 5387936
# Generación 11: Mejor coste = 5387808
# Generación 12: Mejor coste = 5387808
# Generación 13: Mejor coste = 5387808
# Generación 14: Mejor coste = 5387800
# Generación 15: Mejor coste = 5387800
# Generación 16: Mejor coste = 5387800
# Generación 17: Mejor coste = 5387800
# Generación 18: Mejor coste = 5387800
# Generación 19: Mejor coste = 5387800
# Generación 20: Mejor coste = 5387800
# Generación 21: Mejor coste = 5387800
# Generación 22: Mejor coste = 5387800
# Generación 23: Mejor coste = 5387800
# Generación 24: Mejor coste = 5387800
# Generación 25: Mejor coste = 5387661
# Generación 26: Mejor coste = 5387661
# Generación 27: Mejor coste = 5387576
# Generación 28: Mejor coste = 5387576
# Generación 29: Mejor coste = 5387576
# Generación 30: Mejor coste = 5387576
# Generación 31: Mejor coste = 5387576
# Generación 32: Mejor coste = 5387576
# Generación 33: Mejor coste = 5387576
# Generación 34: Mejor coste = 5387576
# Generación 35: Mejor coste = 5387576
# Generación 36: Mejor coste = 5387576
# Generación 37: Mejor coste = 5387576
# Generación 38: Mejor coste = 5387576
# Generación 39: Mejor coste = 5387576
# Generación 40: Mejor coste = 5387576
# Generación 41: Mejor coste = 5387576
# Generación 42: Mejor coste = 5387576
# Terminando en la generación 42 por falta de mejora.
# Generación 1: Mejor coste = 5428799
# Generación 2: Mejor coste = 5397749
# Generación 3: Mejor coste = 5393279
# Generación 4: Mejor coste = 5390479
# Generación 5: Mejor coste = 5389206
# Generación 6: Mejor coste = 5389063
# Generación 7: Mejor coste = 5388012
# Generación 8: Mejor coste = 5387905
# Generación 9: Mejor coste = 5387764
# Generación 10: Mejor coste = 5387579
# Generación 11: Mejor coste = 5387579
# Generación 12: Mejor coste = 5387579
# Generación 13: Mejor coste = 5387133
# Generación 14: Mejor coste = 5387133
# Generación 15: Mejor coste = 5387133
# Generación 16: Mejor coste = 5387133
# Generación 17: Mejor coste = 5387133
# Generación 18: Mejor coste = 5387133
# Generación 19: Mejor coste = 5386879
# Generación 20: Mejor coste = 5386879
# Generación 21: Mejor coste = 5386879
# Generación 22: Mejor coste = 5386879
# Generación 23: Mejor coste = 5386879
# Generación 24: Mejor coste = 5386879
# Generación 25: Mejor coste = 5386879
# Generación 26: Mejor coste = 5386879
# Generación 27: Mejor coste = 5386879
# Generación 28: Mejor coste = 5386879
# Generación 29: Mejor coste = 5386879
# Generación 30: Mejor coste = 5386879
# Generación 31: Mejor coste = 5386879
# Generación 32: Mejor coste = 5386879
# Generación 33: Mejor coste = 5386879
# Generación 34: Mejor coste = 5386879
# Terminando en la generación 34 por falta de mejora.
# Procesando archivo: bur26g.dat
# Generación 1: Mejor coste = 10424490
# Generación 2: Mejor coste = 10387002
# Generación 3: Mejor coste = 10383508
# Generación 4: Mejor coste = 10353341
# Generación 5: Mejor coste = 10397389
# Generación 6: Mejor coste = 10363786
# Generación 7: Mejor coste = 10348336
# Generación 8: Mejor coste = 10334445
# Generación 9: Mejor coste = 10334445
# Generación 10: Mejor coste = 10337353
# Generación 11: Mejor coste = 10330550
# Generación 12: Mejor coste = 10307724
# Generación 13: Mejor coste = 10278431
# Generación 14: Mejor coste = 10264862
# Generación 15: Mejor coste = 10265023
# Generación 16: Mejor coste = 10256868
# Generación 17: Mejor coste = 10241269
# Generación 18: Mejor coste = 10245482
# Generación 19: Mejor coste = 10226251
# Generación 20: Mejor coste = 10218583
# Generación 21: Mejor coste = 10203740
# Generación 22: Mejor coste = 10190154
# Generación 23: Mejor coste = 10190154
# Generación 24: Mejor coste = 10170941
# Generación 25: Mejor coste = 10167071
# Generación 26: Mejor coste = 10167071
# Generación 27: Mejor coste = 10173309
# Generación 28: Mejor coste = 10169655
# Generación 29: Mejor coste = 10155497
# Generación 30: Mejor coste = 10151737
# Generación 31: Mejor coste = 10140145
# Generación 32: Mejor coste = 10139623
# Generación 33: Mejor coste = 10135355
# Generación 34: Mejor coste = 10135355
# Generación 35: Mejor coste = 10136418
# Generación 36: Mejor coste = 10130675
# Generación 37: Mejor coste = 10130040
# Generación 38: Mejor coste = 10130040
# Generación 39: Mejor coste = 10129283
# Generación 40: Mejor coste = 10127831
# Generación 41: Mejor coste = 10127831
# Generación 42: Mejor coste = 10127831
# Generación 43: Mejor coste = 10127831
# Generación 44: Mejor coste = 10127378
# Generación 45: Mejor coste = 10126502
# Generación 46: Mejor coste = 10126038
# Generación 47: Mejor coste = 10126038
# Generación 48: Mejor coste = 10126038
# Generación 49: Mejor coste = 10125796
# Generación 50: Mejor coste = 10124688
# Generación 51: Mejor coste = 10122799
# Generación 52: Mejor coste = 10122799
# Generación 53: Mejor coste = 10122799
# Generación 54: Mejor coste = 10122684
# Generación 55: Mejor coste = 10122684
# Generación 56: Mejor coste = 10121164
# Generación 57: Mejor coste = 10120769
# Generación 58: Mejor coste = 10119249
# Generación 59: Mejor coste = 10119249
# Generación 60: Mejor coste = 10119249
# Generación 61: Mejor coste = 10119249
# Generación 62: Mejor coste = 10119249
# Generación 63: Mejor coste = 10118600
# Generación 64: Mejor coste = 10118600
# Generación 65: Mejor coste = 10118600
# Generación 66: Mejor coste = 10118600
# Generación 67: Mejor coste = 10118600
# Generación 68: Mejor coste = 10118600
# Generación 69: Mejor coste = 10118597
# Generación 70: Mejor coste = 10118597
# Generación 71: Mejor coste = 10118597
# Generación 72: Mejor coste = 10118545
# Generación 73: Mejor coste = 10118545
# Generación 74: Mejor coste = 10118545
# Generación 75: Mejor coste = 10118542
# Generación 76: Mejor coste = 10118542
# Generación 77: Mejor coste = 10118542
# Generación 78: Mejor coste = 10118542
# Generación 79: Mejor coste = 10118542
# Generación 80: Mejor coste = 10118542
# Generación 81: Mejor coste = 10118542
# Generación 82: Mejor coste = 10118542
# Generación 83: Mejor coste = 10118542
# Generación 84: Mejor coste = 10118542
# Generación 85: Mejor coste = 10118542
# Generación 86: Mejor coste = 10118542
# Generación 87: Mejor coste = 10118542
# Generación 88: Mejor coste = 10118542
# Generación 89: Mejor coste = 10118542
# Generación 90: Mejor coste = 10118542
# Terminando en la generación 90 por falta de mejora.
# Generación 1: Mejor coste = 10595072
# Generación 2: Mejor coste = 10183342
# Generación 3: Mejor coste = 10125403
# Generación 4: Mejor coste = 10123883
# Generación 5: Mejor coste = 10123421
# Generación 6: Mejor coste = 10121683
# Generación 7: Mejor coste = 10121683
# Generación 8: Mejor coste = 10121382
# Generación 9: Mejor coste = 10120066
# Generación 10: Mejor coste = 10119751
# Generación 11: Mejor coste = 10119751
# Generación 12: Mejor coste = 10119751
# Generación 13: Mejor coste = 10117641
# Generación 14: Mejor coste = 10117641
# Generación 15: Mejor coste = 10117573
# Generación 16: Mejor coste = 10117172
# Generación 17: Mejor coste = 10117172
# Generación 18: Mejor coste = 10117172
# Generación 19: Mejor coste = 10117172
# Generación 20: Mejor coste = 10117172
# Generación 21: Mejor coste = 10117172
# Generación 22: Mejor coste = 10117172
# Generación 23: Mejor coste = 10117172
# Generación 24: Mejor coste = 10117172
# Generación 25: Mejor coste = 10117172
# Generación 26: Mejor coste = 10117172
# Generación 27: Mejor coste = 10117172
# Generación 28: Mejor coste = 10117172
# Generación 29: Mejor coste = 10117172
# Generación 30: Mejor coste = 10117172
# Generación 31: Mejor coste = 10117172
# Terminando en la generación 31 por falta de mejora.
# Generación 1: Mejor coste = 10195140
# Generación 2: Mejor coste = 10148838
# Generación 3: Mejor coste = 10131864
# Generación 4: Mejor coste = 10125187
# Generación 5: Mejor coste = 10119557
# Generación 6: Mejor coste = 10119557
# Generación 7: Mejor coste = 10118970
# Generación 8: Mejor coste = 10118542
# Generación 9: Mejor coste = 10118542
# Generación 10: Mejor coste = 10118448
# Generación 11: Mejor coste = 10118259
# Generación 12: Mejor coste = 10117573
# Generación 13: Mejor coste = 10117573
# Generación 14: Mejor coste = 10117573
# Generación 15: Mejor coste = 10117573
# Generación 16: Mejor coste = 10117172
# Generación 17: Mejor coste = 10117172
# Generación 18: Mejor coste = 10117172
# Generación 19: Mejor coste = 10117172
# Generación 20: Mejor coste = 10117172
# Generación 21: Mejor coste = 10117172
# Generación 22: Mejor coste = 10117172
# Generación 23: Mejor coste = 10117172
# Generación 24: Mejor coste = 10117172
# Generación 25: Mejor coste = 10117172
# Generación 26: Mejor coste = 10117172
# Generación 27: Mejor coste = 10117172
# Generación 28: Mejor coste = 10117172
# Generación 29: Mejor coste = 10117172
# Generación 30: Mejor coste = 10117172
# Generación 31: Mejor coste = 10117172
# Terminando en la generación 31 por falta de mejora.
# Procesando archivo: bur26f.dat
# Generación 1: Mejor coste = 3947987
# Generación 2: Mejor coste = 3947650
# Generación 3: Mejor coste = 3925942
# Generación 4: Mejor coste = 3921021
# Generación 5: Mejor coste = 3915155
# Generación 6: Mejor coste = 3924033
# Generación 7: Mejor coste = 3896969
# Generación 8: Mejor coste = 3896969
# Generación 9: Mejor coste = 3897985
# Generación 10: Mejor coste = 3895129
# Generación 11: Mejor coste = 3866802
# Generación 12: Mejor coste = 3866802
# Generación 13: Mejor coste = 3857391
# Generación 14: Mejor coste = 3855416
# Generación 15: Mejor coste = 3855416
# Generación 16: Mejor coste = 3858959
# Generación 17: Mejor coste = 3858959
# Generación 18: Mejor coste = 3863299
# Generación 19: Mejor coste = 3851769
# Generación 20: Mejor coste = 3854829
# Generación 21: Mejor coste = 3849474
# Generación 22: Mejor coste = 3849474
# Generación 23: Mejor coste = 3848219
# Generación 24: Mejor coste = 3842653
# Generación 25: Mejor coste = 3842653
# Generación 26: Mejor coste = 3841971
# Generación 27: Mejor coste = 3843404
# Generación 28: Mejor coste = 3837032
# Generación 29: Mejor coste = 3840061
# Generación 30: Mejor coste = 3835911
# Generación 31: Mejor coste = 3835911
# Generación 32: Mejor coste = 3835487
# Generación 33: Mejor coste = 3830150
# Generación 34: Mejor coste = 3830667
# Generación 35: Mejor coste = 3832253
# Generación 36: Mejor coste = 3829584
# Generación 37: Mejor coste = 3829584
# Generación 38: Mejor coste = 3829584
# Generación 39: Mejor coste = 3829584
# Generación 40: Mejor coste = 3826278
# Generación 41: Mejor coste = 3826315
# Generación 42: Mejor coste = 3826054
# Generación 43: Mejor coste = 3825945
# Generación 44: Mejor coste = 3824256
# Generación 45: Mejor coste = 3824256
# Generación 46: Mejor coste = 3824013
# Generación 47: Mejor coste = 3823561
# Generación 48: Mejor coste = 3823429
# Generación 49: Mejor coste = 3823429
# Generación 50: Mejor coste = 3823318
# Generación 51: Mejor coste = 3823124
# Generación 52: Mejor coste = 3822350
# Generación 53: Mejor coste = 3822297
# Generación 54: Mejor coste = 3822260
# Generación 55: Mejor coste = 3822243
# Generación 56: Mejor coste = 3822243
# Generación 57: Mejor coste = 3821127
# Generación 58: Mejor coste = 3821127
# Generación 59: Mejor coste = 3821104
# Generación 60: Mejor coste = 3821073
# Generación 61: Mejor coste = 3820207
# Generación 62: Mejor coste = 3821073
# Generación 63: Mejor coste = 3820402
# Generación 64: Mejor coste = 3820402
# Generación 65: Mejor coste = 3820402
# Generación 66: Mejor coste = 3820401
# Generación 67: Mejor coste = 3820401
# Generación 68: Mejor coste = 3820375
# Generación 69: Mejor coste = 3813912
# Generación 70: Mejor coste = 3807012
# Generación 71: Mejor coste = 3806309
# Generación 72: Mejor coste = 3806297
# Generación 73: Mejor coste = 3806283
# Generación 74: Mejor coste = 3805997
# Generación 75: Mejor coste = 3800637
# Generación 76: Mejor coste = 3804635
# Generación 77: Mejor coste = 3804635
# Generación 78: Mejor coste = 3804635
# Generación 79: Mejor coste = 3804635
# Generación 80: Mejor coste = 3804635
# Generación 81: Mejor coste = 3804635
# Generación 82: Mejor coste = 3804628
# Generación 83: Mejor coste = 3804628
# Generación 84: Mejor coste = 3804628
# Generación 85: Mejor coste = 3803987
# Generación 86: Mejor coste = 3803987
# Generación 87: Mejor coste = 3800553
# Generación 88: Mejor coste = 3800553
# Generación 89: Mejor coste = 3799746
# Generación 90: Mejor coste = 3800553
# Generación 91: Mejor coste = 3800553
# Generación 92: Mejor coste = 3800553
# Generación 93: Mejor coste = 3800553
# Generación 94: Mejor coste = 3800553
# Generación 95: Mejor coste = 3800518
# Generación 96: Mejor coste = 3800231
# Generación 97: Mejor coste = 3800168
# Generación 98: Mejor coste = 3800168
# Generación 99: Mejor coste = 3800013
# Generación 100: Mejor coste = 3800013
# Generación 101: Mejor coste = 3800013
# Generación 102: Mejor coste = 3799774
# Generación 103: Mejor coste = 3799487
# Generación 104: Mejor coste = 3799487
# Generación 105: Mejor coste = 3799487
# Generación 106: Mejor coste = 3798154
# Generación 107: Mejor coste = 3797887
# Generación 108: Mejor coste = 3797628
# Generación 109: Mejor coste = 3797199
# Generación 110: Mejor coste = 3797199
# Generación 111: Mejor coste = 3797199
# Generación 112: Mejor coste = 3797199
# Generación 113: Mejor coste = 3797199
# Generación 114: Mejor coste = 3797199
# Generación 115: Mejor coste = 3797179
# Generación 116: Mejor coste = 3797179
# Generación 117: Mejor coste = 3797179
# Generación 118: Mejor coste = 3796967
# Generación 119: Mejor coste = 3796967
# Generación 120: Mejor coste = 3796967
# Generación 121: Mejor coste = 3796967
# Generación 122: Mejor coste = 3796967
# Generación 123: Mejor coste = 3796967
# Generación 124: Mejor coste = 3796939
# Generación 125: Mejor coste = 3796939
# Generación 126: Mejor coste = 3796939
# Generación 127: Mejor coste = 3796939
# Generación 128: Mejor coste = 3796939
# Generación 129: Mejor coste = 3796939
# Generación 130: Mejor coste = 3796939
# Generación 131: Mejor coste = 3796939
# Generación 132: Mejor coste = 3796939
# Generación 133: Mejor coste = 3796919
# Generación 134: Mejor coste = 3796919
# Generación 135: Mejor coste = 3796919
# Generación 136: Mejor coste = 3796919
# Generación 137: Mejor coste = 3796919
# Generación 138: Mejor coste = 3796919
# Generación 139: Mejor coste = 3796919
# Generación 140: Mejor coste = 3796919
# Generación 141: Mejor coste = 3796919
# Generación 142: Mejor coste = 3796919
# Generación 143: Mejor coste = 3796919
# Generación 144: Mejor coste = 3796919
# Generación 145: Mejor coste = 3796919
# Generación 146: Mejor coste = 3796919
# Generación 147: Mejor coste = 3796919
# Generación 148: Mejor coste = 3796919
# Terminando en la generación 148 por falta de mejora.
# Generación 1: Mejor coste = 3954967
# Generación 2: Mejor coste = 3818796
# Generación 3: Mejor coste = 3793066
# Generación 4: Mejor coste = 3789817
# Generación 5: Mejor coste = 3783064
# Generación 6: Mejor coste = 3783064
# Generación 7: Mejor coste = 3782908
# Generación 8: Mejor coste = 3782725
# Generación 9: Mejor coste = 3782718
# Generación 10: Mejor coste = 3782718
# Generación 11: Mejor coste = 3782718
# Generación 12: Mejor coste = 3782718
# Generación 13: Mejor coste = 3782718
# Generación 14: Mejor coste = 3782718
# Generación 15: Mejor coste = 3782718
# Generación 16: Mejor coste = 3782718
# Generación 17: Mejor coste = 3782250
# Generación 18: Mejor coste = 3782250
# Generación 19: Mejor coste = 3782250
# Generación 20: Mejor coste = 3782250
# Generación 21: Mejor coste = 3782250
# Generación 22: Mejor coste = 3782250
# Generación 23: Mejor coste = 3782250
# Generación 24: Mejor coste = 3782250
# Generación 25: Mejor coste = 3782250
# Generación 26: Mejor coste = 3782250
# Generación 27: Mejor coste = 3782250
# Generación 28: Mejor coste = 3782250
# Generación 29: Mejor coste = 3782250
# Generación 30: Mejor coste = 3782250
# Generación 31: Mejor coste = 3782250
# Generación 32: Mejor coste = 3782250
# Terminando en la generación 32 por falta de mejora.
# Generación 1: Mejor coste = 3816783
# Generación 2: Mejor coste = 3793635
# Generación 3: Mejor coste = 3784150
# Generación 4: Mejor coste = 3783783
# Generación 5: Mejor coste = 3783465
# Generación 6: Mejor coste = 3782857
# Generación 7: Mejor coste = 3782761
# Generación 8: Mejor coste = 3782699
# Generación 9: Mejor coste = 3782368
# Generación 10: Mejor coste = 3782296
# Generación 11: Mejor coste = 3782219
# Generación 12: Mejor coste = 3782075
# Generación 13: Mejor coste = 3782075
# Generación 14: Mejor coste = 3782044
# Generación 15: Mejor coste = 3782044
# Generación 16: Mejor coste = 3782044
# Generación 17: Mejor coste = 3782044
# Generación 18: Mejor coste = 3782044
# Generación 19: Mejor coste = 3782044
# Generación 20: Mejor coste = 3782044
# Generación 21: Mejor coste = 3782044
# Generación 22: Mejor coste = 3782044
# Generación 23: Mejor coste = 3782044
# Generación 24: Mejor coste = 3782044
# Generación 25: Mejor coste = 3782044
# Generación 26: Mejor coste = 3782044
# Generación 27: Mejor coste = 3782044
# Generación 28: Mejor coste = 3782044
# Generación 29: Mejor coste = 3782044
# Terminando en la generación 29 por falta de mejora.
# Procesando archivo: bur26h.dat
# Generación 1: Mejor coste = 7396452
# Generación 2: Mejor coste = 7353038
# Generación 3: Mejor coste = 7326051
# Generación 4: Mejor coste = 7279844
# Generación 5: Mejor coste = 7282425
# Generación 6: Mejor coste = 7277442
# Generación 7: Mejor coste = 7240812
# Generación 8: Mejor coste = 7251876
# Generación 9: Mejor coste = 7226178
# Generación 10: Mejor coste = 7226178
# Generación 11: Mejor coste = 7206094
# Generación 12: Mejor coste = 7179689
# Generación 13: Mejor coste = 7179689
# Generación 14: Mejor coste = 7179689
# Generación 15: Mejor coste = 7175812
# Generación 16: Mejor coste = 7174632
# Generación 17: Mejor coste = 7153652
# Generación 18: Mejor coste = 7164090
# Generación 19: Mejor coste = 7141213
# Generación 20: Mejor coste = 7143103
# Generación 21: Mejor coste = 7138326
# Generación 22: Mejor coste = 7138326
# Generación 23: Mejor coste = 7137114
# Generación 24: Mejor coste = 7136026
# Generación 25: Mejor coste = 7137114
# Generación 26: Mejor coste = 7137114
# Generación 27: Mejor coste = 7130770
# Generación 28: Mejor coste = 7122935
# Generación 29: Mejor coste = 7127832
# Generación 30: Mejor coste = 7127832
# Generación 31: Mejor coste = 7111700
# Generación 32: Mejor coste = 7111700
# Generación 33: Mejor coste = 7111700
# Generación 34: Mejor coste = 7111124
# Generación 35: Mejor coste = 7107758
# Generación 36: Mejor coste = 7106123
# Generación 37: Mejor coste = 7105457
# Generación 38: Mejor coste = 7105457
# Generación 39: Mejor coste = 7104235
# Generación 40: Mejor coste = 7104852
# Generación 41: Mejor coste = 7104263
# Generación 42: Mejor coste = 7104263
# Generación 43: Mejor coste = 7104235
# Generación 44: Mejor coste = 7104263
# Generación 45: Mejor coste = 7103740
# Generación 46: Mejor coste = 7103740
# Generación 47: Mejor coste = 7103712
# Generación 48: Mejor coste = 7103617
# Generación 49: Mejor coste = 7103617
# Generación 50: Mejor coste = 7103348
# Generación 51: Mejor coste = 7102825
# Generación 52: Mejor coste = 7102825
# Generación 53: Mejor coste = 7102825
# Generación 54: Mejor coste = 7102825
# Generación 55: Mejor coste = 7102825
# Generación 56: Mejor coste = 7102825
# Generación 57: Mejor coste = 7102825
# Generación 58: Mejor coste = 7102825
# ...
# Generación 37: Mejor coste = 1674
# Generación 38: Mejor coste = 1674
# Generación 39: Mejor coste = 1674
# Generación 40: Mejor coste = 1674
# Generación 41: Mejor coste = 1674
# Generación 42: Mejor coste = 1674
# Generación 43: Mejor coste = 1674
# Generación 44: Mejor coste = 1674
# Generación 45: Mejor coste = 1674
# Generación 46: Mejor coste = 1674
# Generación 47: Mejor coste = 1674
# Terminando en la generación 47 por falta de mejora.
# Generación 1: Mejor coste = 1868
# Generación 2: Mejor coste = 1682
# Generación 3: Mejor coste = 1638
# Generación 4: Mejor coste = 1622
# Generación 5: Mejor coste = 1622
# Generación 6: Mejor coste = 1622
# Generación 7: Mejor coste = 1622
# Generación 8: Mejor coste = 1622
# Generación 9: Mejor coste = 1622
# Generación 10: Mejor coste = 1622
# Generación 11: Mejor coste = 1622
# Generación 12: Mejor coste = 1622
# Generación 13: Mejor coste = 1622
# Generación 14: Mejor coste = 1622
# Generación 15: Mejor coste = 1622
# Generación 16: Mejor coste = 1622
# Generación 17: Mejor coste = 1622
# Generación 18: Mejor coste = 1622
# Generación 19: Mejor coste = 1622
# Terminando en la generación 19 por falta de mejora.
# Generación 1: Mejor coste = 1672
# Generación 2: Mejor coste = 1640
# Generación 3: Mejor coste = 1610
# Generación 4: Mejor coste = 1610
# Generación 5: Mejor coste = 1610
# Generación 6: Mejor coste = 1610
# Generación 7: Mejor coste = 1610
# Generación 8: Mejor coste = 1610
# Generación 9: Mejor coste = 1610
# Generación 10: Mejor coste = 1610
# Generación 11: Mejor coste = 1610
# Generación 12: Mejor coste = 1610
# Generación 13: Mejor coste = 1610
# Generación 14: Mejor coste = 1610
# Generación 15: Mejor coste = 1610
# Generación 16: Mejor coste = 1610
# Generación 17: Mejor coste = 1610
# Generación 18: Mejor coste = 1610
# Terminando en la generación 18 por falta de mejora.
# Procesando archivo: nug17.dat
# Generación 1: Mejor coste = 2026
# Generación 2: Mejor coste = 1946
# Generación 3: Mejor coste = 1946
# Generación 4: Mejor coste = 1946
# Generación 5: Mejor coste = 1902
# Generación 6: Mejor coste = 1902
# Generación 7: Mejor coste = 1896
# Generación 8: Mejor coste = 1896
# Generación 9: Mejor coste = 1882
# Generación 10: Mejor coste = 1856
# Generación 11: Mejor coste = 1856
# Generación 12: Mejor coste = 1846
# Generación 13: Mejor coste = 1846
# Generación 14: Mejor coste = 1826
# Generación 15: Mejor coste = 1794
# Generación 16: Mejor coste = 1784
# Generación 17: Mejor coste = 1784
# Generación 18: Mejor coste = 1766
# Generación 19: Mejor coste = 1766
# Generación 20: Mejor coste = 1766
# Generación 21: Mejor coste = 1766
# Generación 22: Mejor coste = 1766
# Generación 23: Mejor coste = 1766
# Generación 24: Mejor coste = 1766
# Generación 25: Mejor coste = 1766
# Generación 26: Mejor coste = 1766
# Generación 27: Mejor coste = 1766
# Generación 28: Mejor coste = 1766
# Generación 29: Mejor coste = 1766
# Generación 30: Mejor coste = 1766
# Generación 31: Mejor coste = 1766
# Generación 32: Mejor coste = 1766
# Generación 33: Mejor coste = 1766
# Terminando en la generación 33 por falta de mejora.
# Generación 1: Mejor coste = 1962
# Generación 2: Mejor coste = 1786
# Generación 3: Mejor coste = 1776
# Generación 4: Mejor coste = 1760
# Generación 5: Mejor coste = 1754
# Generación 6: Mejor coste = 1754
# Generación 7: Mejor coste = 1750
# Generación 8: Mejor coste = 1750
# Generación 9: Mejor coste = 1750
# Generación 10: Mejor coste = 1746
# Generación 11: Mejor coste = 1746
# Generación 12: Mejor coste = 1746
# Generación 13: Mejor coste = 1746
# Generación 14: Mejor coste = 1746
# Generación 15: Mejor coste = 1746
# Generación 16: Mejor coste = 1746
# Generación 17: Mejor coste = 1746
# Generación 18: Mejor coste = 1746
# Generación 19: Mejor coste = 1746
# Generación 20: Mejor coste = 1746
# Generación 21: Mejor coste = 1746
# Generación 22: Mejor coste = 1746
# Generación 23: Mejor coste = 1746
# Generación 24: Mejor coste = 1746
# Generación 25: Mejor coste = 1746
# Terminando en la generación 25 por falta de mejora.
# Generación 1: Mejor coste = 1796
# Generación 2: Mejor coste = 1758
# Generación 3: Mejor coste = 1734
# Generación 4: Mejor coste = 1734
# Generación 5: Mejor coste = 1732
# Generación 6: Mejor coste = 1732
# Generación 7: Mejor coste = 1732
# Generación 8: Mejor coste = 1732
# Generación 9: Mejor coste = 1732
# Generación 10: Mejor coste = 1732
# Generación 11: Mejor coste = 1732
# Generación 12: Mejor coste = 1732
# Generación 13: Mejor coste = 1732
# Generación 14: Mejor coste = 1732
# Generación 15: Mejor coste = 1732
# Generación 16: Mejor coste = 1732
# Generación 17: Mejor coste = 1732
# Generación 18: Mejor coste = 1732
# Generación 19: Mejor coste = 1732
# Generación 20: Mejor coste = 1732
# Terminando en la generación 20 por falta de mejora.
# Procesando archivo: nug20.dat
# Generación 1: Mejor coste = 3010
# Generación 2: Mejor coste = 2928
# Generación 3: Mejor coste = 2928
# Generación 4: Mejor coste = 2928
# Generación 5: Mejor coste = 2848
# Generación 6: Mejor coste = 2912
# Generación 7: Mejor coste = 2838
# Generación 8: Mejor coste = 2850
# Generación 9: Mejor coste = 2850
# Generación 10: Mejor coste = 2870
# Generación 11: Mejor coste = 2870
# Generación 12: Mejor coste = 2848
# Generación 13: Mejor coste = 2848
# Generación 14: Mejor coste = 2850
# Generación 15: Mejor coste = 2850
# Generación 16: Mejor coste = 2850
# Generación 17: Mejor coste = 2890
# Generación 18: Mejor coste = 2850
# Generación 19: Mejor coste = 2850
# Generación 20: Mejor coste = 2850
# Generación 21: Mejor coste = 2816
# Generación 22: Mejor coste = 2816
# Generación 23: Mejor coste = 2816
# Generación 24: Mejor coste = 2796
# Generación 25: Mejor coste = 2796
# Generación 26: Mejor coste = 2796
# Generación 27: Mejor coste = 2788
# Generación 28: Mejor coste = 2772
# Generación 29: Mejor coste = 2772
# Generación 30: Mejor coste = 2772
# Generación 31: Mejor coste = 2772
# Generación 32: Mejor coste = 2772
# Generación 33: Mejor coste = 2772
# Generación 34: Mejor coste = 2772
# Generación 35: Mejor coste = 2772
# Generación 36: Mejor coste = 2764
# Generación 37: Mejor coste = 2764
# Generación 38: Mejor coste = 2744
# Generación 39: Mejor coste = 2744
# Generación 40: Mejor coste = 2744
# Generación 41: Mejor coste = 2722
# Generación 42: Mejor coste = 2722
# Generación 43: Mejor coste = 2722
# Generación 44: Mejor coste = 2718
# Generación 45: Mejor coste = 2714
# Generación 46: Mejor coste = 2714
# Generación 47: Mejor coste = 2710
# Generación 48: Mejor coste = 2702
# Generación 49: Mejor coste = 2702
# Generación 50: Mejor coste = 2702
# Generación 51: Mejor coste = 2702
# Generación 52: Mejor coste = 2702
# Generación 53: Mejor coste = 2702
# Generación 54: Mejor coste = 2702
# Generación 55: Mejor coste = 2702
# Generación 56: Mejor coste = 2702
# Generación 57: Mejor coste = 2702
# Generación 58: Mejor coste = 2702
# Generación 59: Mejor coste = 2702
# Generación 60: Mejor coste = 2702
# Generación 61: Mejor coste = 2702
# Generación 62: Mejor coste = 2702
# Generación 63: Mejor coste = 2702
# Terminando en la generación 63 por falta de mejora.
# Generación 1: Mejor coste = 3042
# Generación 2: Mejor coste = 2712
# Generación 3: Mejor coste = 2674
# Generación 4: Mejor coste = 2634
# Generación 5: Mejor coste = 2624
# Generación 6: Mejor coste = 2596
# Generación 7: Mejor coste = 2588
# Generación 8: Mejor coste = 2584
# Generación 9: Mejor coste = 2580
# Generación 10: Mejor coste = 2580
# Generación 11: Mejor coste = 2580
# Generación 12: Mejor coste = 2580
# Generación 13: Mejor coste = 2580
# Generación 14: Mejor coste = 2580
# Generación 15: Mejor coste = 2580
# Generación 16: Mejor coste = 2580
# Generación 17: Mejor coste = 2580
# Generación 18: Mejor coste = 2580
# Generación 19: Mejor coste = 2580
# Generación 20: Mejor coste = 2580
# Generación 21: Mejor coste = 2580
# Generación 22: Mejor coste = 2580
# Generación 23: Mejor coste = 2580
# Generación 24: Mejor coste = 2580
# Terminando en la generación 24 por falta de mejora.
# Generación 1: Mejor coste = 2706
# Generación 2: Mejor coste = 2636
# Generación 3: Mejor coste = 2614
# Generación 4: Mejor coste = 2598
# Generación 5: Mejor coste = 2590
# Generación 6: Mejor coste = 2582
# Generación 7: Mejor coste = 2582
# Generación 8: Mejor coste = 2582
# Generación 9: Mejor coste = 2578
# Generación 10: Mejor coste = 2578
# Generación 11: Mejor coste = 2570
# Generación 12: Mejor coste = 2570
# Generación 13: Mejor coste = 2570
# Generación 14: Mejor coste = 2570
# Generación 15: Mejor coste = 2570
# Generación 16: Mejor coste = 2570
# Generación 17: Mejor coste = 2570
# Generación 18: Mejor coste = 2570
# Generación 19: Mejor coste = 2570
# Generación 20: Mejor coste = 2570
# Generación 21: Mejor coste = 2570
# Generación 22: Mejor coste = 2570
# Generación 23: Mejor coste = 2570
# Generación 24: Mejor coste = 2570
# Generación 25: Mejor coste = 2570
# Generación 26: Mejor coste = 2570
# Terminando en la generación 26 por falta de mejora.
# Procesando archivo: nug18.dat
# Generación 1: Mejor coste = 2184
# Generación 2: Mejor coste = 2146
# Generación 3: Mejor coste = 2184
# Generación 4: Mejor coste = 2174
# Generación 5: Mejor coste = 2168
# Generación 6: Mejor coste = 2166
# Generación 7: Mejor coste = 2166
# Generación 8: Mejor coste = 2100
# Generación 9: Mejor coste = 2100
# Generación 10: Mejor coste = 2100
# Generación 11: Mejor coste = 2100
# Generación 12: Mejor coste = 2100
# Generación 13: Mejor coste = 2058
# Generación 14: Mejor coste = 2030
# Generación 15: Mejor coste = 2058
# Generación 16: Mejor coste = 2058
# Generación 17: Mejor coste = 2040
# Generación 18: Mejor coste = 2040
# Generación 19: Mejor coste = 1996
# Generación 20: Mejor coste = 1996
# Generación 21: Mejor coste = 1996
# Generación 22: Mejor coste = 1996
# Generación 23: Mejor coste = 1996
# Generación 24: Mejor coste = 1990
# Generación 25: Mejor coste = 1990
# Generación 26: Mejor coste = 1990
# Generación 27: Mejor coste = 1990
# Generación 28: Mejor coste = 1990
# Generación 29: Mejor coste = 1990
# Generación 30: Mejor coste = 1990
# Generación 31: Mejor coste = 1990
# Generación 32: Mejor coste = 1990
# Generación 33: Mejor coste = 1990
# Generación 34: Mejor coste = 1990
# Generación 35: Mejor coste = 1990
# Generación 36: Mejor coste = 1990
# Generación 37: Mejor coste = 1990
# Generación 38: Mejor coste = 1990
# Generación 39: Mejor coste = 1990
# Terminando en la generación 39 por falta de mejora.
# Generación 1: Mejor coste = 2218
# Generación 2: Mejor coste = 2038
# Generación 3: Mejor coste = 2000
# Generación 4: Mejor coste = 1986
# Generación 5: Mejor coste = 1974
# Generación 6: Mejor coste = 1974
# Generación 7: Mejor coste = 1930
# Generación 8: Mejor coste = 1930
# Generación 9: Mejor coste = 1930
# Generación 10: Mejor coste = 1930
# Generación 11: Mejor coste = 1930
# Generación 12: Mejor coste = 1930
# Generación 13: Mejor coste = 1930
# Generación 14: Mejor coste = 1930
# Generación 15: Mejor coste = 1930
# Generación 16: Mejor coste = 1930
# Generación 17: Mejor coste = 1930
# Generación 18: Mejor coste = 1930
# Generación 19: Mejor coste = 1930
# Generación 20: Mejor coste = 1930
# Generación 21: Mejor coste = 1930
# Generación 22: Mejor coste = 1930
# Terminando en la generación 22 por falta de mejora.
# Generación 1: Mejor coste = 2010
# Generación 2: Mejor coste = 1960
# Generación 3: Mejor coste = 1936
# Generación 4: Mejor coste = 1930
# Generación 5: Mejor coste = 1930
# Generación 6: Mejor coste = 1930
# Generación 7: Mejor coste = 1930
# Generación 8: Mejor coste = 1930
# Generación 9: Mejor coste = 1930
# Generación 10: Mejor coste = 1930
# Generación 11: Mejor coste = 1930
# Generación 12: Mejor coste = 1930
# Generación 13: Mejor coste = 1930
# Generación 14: Mejor coste = 1930
# Generación 15: Mejor coste = 1930
# Generación 16: Mejor coste = 1930
# Generación 17: Mejor coste = 1930
# Generación 18: Mejor coste = 1930
# Generación 19: Mejor coste = 1930
# Terminando en la generación 19 por falta de mejora.
# Procesando archivo: nug22.dat
# Generación 1: Mejor coste = 4390
# Generación 2: Mejor coste = 4366
# Generación 3: Mejor coste = 4138
# Generación 4: Mejor coste = 4138
# Generación 5: Mejor coste = 4238
# Generación 6: Mejor coste = 4182
# Generación 7: Mejor coste = 4182
# Generación 8: Mejor coste = 4164
# Generación 9: Mejor coste = 4044
# Generación 10: Mejor coste = 4122
# Generación 11: Mejor coste = 4122
# Generación 12: Mejor coste = 4076
# Generación 13: Mejor coste = 4002
# Generación 14: Mejor coste = 4076
# Generación 15: Mejor coste = 4058
# Generación 16: Mejor coste = 4058
# Generación 17: Mejor coste = 4036
# Generación 18: Mejor coste = 3990
# Generación 19: Mejor coste = 3960
# Generación 20: Mejor coste = 3868
# Generación 21: Mejor coste = 3862
# Generación 22: Mejor coste = 3808
# Generación 23: Mejor coste = 3834
# Generación 24: Mejor coste = 3800
# Generación 25: Mejor coste = 3828
# Generación 26: Mejor coste = 3776
# Generación 27: Mejor coste = 3776
# Generación 28: Mejor coste = 3776
# Generación 29: Mejor coste = 3772
# Generación 30: Mejor coste = 3772
# Generación 31: Mejor coste = 3764
# Generación 32: Mejor coste = 3764
# Generación 33: Mejor coste = 3752
# Generación 34: Mejor coste = 3740
# Generación 35: Mejor coste = 3732
# Generación 36: Mejor coste = 3732
# Generación 37: Mejor coste = 3732
# Generación 38: Mejor coste = 3724
# Generación 39: Mejor coste = 3720
# Generación 40: Mejor coste = 3716
# Generación 41: Mejor coste = 3716
# Generación 42: Mejor coste = 3716
# Generación 43: Mejor coste = 3716
# Generación 44: Mejor coste = 3692
# Generación 45: Mejor coste = 3712
# Generación 46: Mejor coste = 3704
# Generación 47: Mejor coste = 3692
# Generación 48: Mejor coste = 3692
# Generación 49: Mejor coste = 3692
# Generación 50: Mejor coste = 3692
# Generación 51: Mejor coste = 3692
# Generación 52: Mejor coste = 3692
# Generación 53: Mejor coste = 3692
# Generación 54: Mejor coste = 3682
# Generación 55: Mejor coste = 3682
# Generación 56: Mejor coste = 3682
# Generación 57: Mejor coste = 3682
# Generación 58: Mejor coste = 3682
# Generación 59: Mejor coste = 3682
# Generación 60: Mejor coste = 3682
# Generación 61: Mejor coste = 3682
# Generación 62: Mejor coste = 3682
# Generación 63: Mejor coste = 3682
# Generación 64: Mejor coste = 3682
# Generación 65: Mejor coste = 3682
# Generación 66: Mejor coste = 3682
# Generación 67: Mejor coste = 3682
# Generación 68: Mejor coste = 3682
# Generación 69: Mejor coste = 3682
# Terminando en la generación 69 por falta de mejora.
# Generación 1: Mejor coste = 4530
# Generación 2: Mejor coste = 3782
# Generación 3: Mejor coste = 3742
# Generación 4: Mejor coste = 3700
# Generación 5: Mejor coste = 3672
# Generación 6: Mejor coste = 3660
# Generación 7: Mejor coste = 3644
# Generación 8: Mejor coste = 3636
# Generación 9: Mejor coste = 3636
# Generación 10: Mejor coste = 3634
# Generación 11: Mejor coste = 3634
# Generación 12: Mejor coste = 3620
# Generación 13: Mejor coste = 3620
# Generación 14: Mejor coste = 3612
# Generación 15: Mejor coste = 3612
# Generación 16: Mejor coste = 3600
# Generación 17: Mejor coste = 3600
# Generación 18: Mejor coste = 3596
# Generación 19: Mejor coste = 3596
# Generación 20: Mejor coste = 3596
# Generación 21: Mejor coste = 3596
# Generación 22: Mejor coste = 3596
# Generación 23: Mejor coste = 3596
# Generación 24: Mejor coste = 3596
# Generación 25: Mejor coste = 3596
# Generación 26: Mejor coste = 3596
# Generación 27: Mejor coste = 3596
# Generación 28: Mejor coste = 3596
# Generación 29: Mejor coste = 3596
# Generación 30: Mejor coste = 3596
# Generación 31: Mejor coste = 3596
# Generación 32: Mejor coste = 3596
# Generación 33: Mejor coste = 3596
# Terminando en la generación 33 por falta de mejora.
# Generación 1: Mejor coste = 3760
# Generación 2: Mejor coste = 3678
# Generación 3: Mejor coste = 3660
# Generación 4: Mejor coste = 3646
# Generación 5: Mejor coste = 3630
# Generación 6: Mejor coste = 3606
# Generación 7: Mejor coste = 3606
# Generación 8: Mejor coste = 3606
# Generación 9: Mejor coste = 3606
# Generación 10: Mejor coste = 3606
# Generación 11: Mejor coste = 3602
# Generación 12: Mejor coste = 3602
# Generación 13: Mejor coste = 3602
# Generación 14: Mejor coste = 3602
# Generación 15: Mejor coste = 3602
# Generación 16: Mejor coste = 3602
# Generación 17: Mejor coste = 3602
# Generación 18: Mejor coste = 3602
# Generación 19: Mejor coste = 3602
# Generación 20: Mejor coste = 3602
# Generación 21: Mejor coste = 3602
# Generación 22: Mejor coste = 3602
# Generación 23: Mejor coste = 3602
# Generación 24: Mejor coste = 3602
# Generación 25: Mejor coste = 3602
# Generación 26: Mejor coste = 3602
# Terminando en la generación 26 por falta de mejora.

# %%
results_part1 = load_results('results_part1.pkl')
run_experiments_part(data_folder, len(files)//2, len(files), 'results_part2.pkl')

# Combinar resultados
results_part2 = load_results('results_part2.pkl')
results = {**results_part1, **results_part2}

# Visualizar todos los resultados juntos
visualize_results(results)
# Out:
# Streaming output truncated to the last 5000 lines.
# Generación 2: Mejor coste = 2022136
# Generación 3: Mejor coste = 2018684
# Generación 4: Mejor coste = 2018684
# Generación 5: Mejor coste = 1969432
# Generación 6: Mejor coste = 2012858
# Generación 7: Mejor coste = 1988130
# Generación 8: Mejor coste = 1988130
# Generación 9: Mejor coste = 1976224
# Generación 10: Mejor coste = 1988858
# Generación 11: Mejor coste = 1941626
# Generación 12: Mejor coste = 1923470
# Generación 13: Mejor coste = 1961978
# Generación 14: Mejor coste = 1971424
# Generación 15: Mejor coste = 1966574
# Generación 16: Mejor coste = 1880212
# Generación 17: Mejor coste = 1880212
# Generación 18: Mejor coste = 1880212
# Generación 19: Mejor coste = 1880212
# Generación 20: Mejor coste = 1880212
# Generación 21: Mejor coste = 1889740
# Generación 22: Mejor coste = 1889740
# Generación 23: Mejor coste = 1889740
# Generación 24: Mejor coste = 1889740
# Generación 25: Mejor coste = 1889740
# Generación 26: Mejor coste = 1889740
# Generación 27: Mejor coste = 1889740
# Generación 28: Mejor coste = 1889740
# Generación 29: Mejor coste = 1889740
# Generación 30: Mejor coste = 1876864
# Generación 31: Mejor coste = 1876864
# Generación 32: Mejor coste = 1876864
# Generación 33: Mejor coste = 1876864
# Generación 34: Mejor coste = 1876864
# Generación 35: Mejor coste = 1876864
# Generación 36: Mejor coste = 1876864
# Generación 37: Mejor coste = 1876864
# Generación 38: Mejor coste = 1876864
# Generación 39: Mejor coste = 1864238
# Generación 40: Mejor coste = 1864238
# Generación 41: Mejor coste = 1864238
# Generación 42: Mejor coste = 1864238
# Generación 43: Mejor coste = 1864238
# Generación 44: Mejor coste = 1864238
# Generación 45: Mejor coste = 1864238
# Generación 46: Mejor coste = 1864238
# Generación 47: Mejor coste = 1864238
# Generación 48: Mejor coste = 1864238
# Generación 49: Mejor coste = 1864238
# Generación 50: Mejor coste = 1864238
# Generación 51: Mejor coste = 1864238
# Generación 52: Mejor coste = 1864238
# Generación 53: Mejor coste = 1864238
# Generación 54: Mejor coste = 1864238
# Terminando en la generación 54 por falta de mejora.
# Generación 1: Mejor coste = 2218460
# Generación 2: Mejor coste = 1886178
# Generación 3: Mejor coste = 1886178
# Generación 4: Mejor coste = 1886178
# Generación 5: Mejor coste = 1886178
# Generación 6: Mejor coste = 1872572
# Generación 7: Mejor coste = 1865994
# Generación 8: Mejor coste = 1865994
# Generación 9: Mejor coste = 1861812
# Generación 10: Mejor coste = 1861812
# Generación 11: Mejor coste = 1861812
# Generación 12: Mejor coste = 1861812
# Generación 13: Mejor coste = 1861812
# Generación 14: Mejor coste = 1861812
# Generación 15: Mejor coste = 1861812
# Generación 16: Mejor coste = 1861812
# Generación 17: Mejor coste = 1861812
# Generación 18: Mejor coste = 1861812
# Generación 19: Mejor coste = 1860348
# Generación 20: Mejor coste = 1856396
# Generación 21: Mejor coste = 1856396
# Generación 22: Mejor coste = 1856396
# Generación 23: Mejor coste = 1856396
# Generación 24: Mejor coste = 1856396
# Generación 25: Mejor coste = 1856396
# Generación 26: Mejor coste = 1856396
# Generación 27: Mejor coste = 1856396
# Generación 28: Mejor coste = 1856396
# Generación 29: Mejor coste = 1856396
# Generación 30: Mejor coste = 1856396
# Generación 31: Mejor coste = 1856396
# Generación 32: Mejor coste = 1855928
# Generación 33: Mejor coste = 1855928
# Generación 34: Mejor coste = 1855928
# Generación 35: Mejor coste = 1855928
# Generación 36: Mejor coste = 1855928
# Generación 37: Mejor coste = 1855928
# Generación 38: Mejor coste = 1855928
# Generación 39: Mejor coste = 1855928
# Generación 40: Mejor coste = 1855928
# Generación 41: Mejor coste = 1855928
# Generación 42: Mejor coste = 1855928
# Generación 43: Mejor coste = 1855928
# Generación 44: Mejor coste = 1855928
# Generación 45: Mejor coste = 1855928
# Generación 46: Mejor coste = 1855928
# Generación 47: Mejor coste = 1855928
# Terminando en la generación 47 por falta de mejora.
# Generación 1: Mejor coste = 1917830
# Generación 2: Mejor coste = 1891758
# Generación 3: Mejor coste = 1866720
# Generación 4: Mejor coste = 1866720
# Generación 5: Mejor coste = 1864238
# Generación 6: Mejor coste = 1862590
# Generación 7: Mejor coste = 1862590
# Generación 8: Mejor coste = 1858710
# Generación 9: Mejor coste = 1858710
# Generación 10: Mejor coste = 1858710
# Generación 11: Mejor coste = 1857646
# Generación 12: Mejor coste = 1857646
# Generación 13: Mejor coste = 1857646
# Generación 14: Mejor coste = 1857646
# Generación 15: Mejor coste = 1855928
# Generación 16: Mejor coste = 1855928
# Generación 17: Mejor coste = 1855928
# Generación 18: Mejor coste = 1855928
# Generación 19: Mejor coste = 1855928
# Generación 20: Mejor coste = 1855928
# Generación 21: Mejor coste = 1855928
# Generación 22: Mejor coste = 1855928
# Generación 23: Mejor coste = 1855928
# Generación 24: Mejor coste = 1855928
# Generación 25: Mejor coste = 1855928
# Generación 26: Mejor coste = 1855928
# Generación 27: Mejor coste = 1855928
# Generación 28: Mejor coste = 1855928
# Generación 29: Mejor coste = 1855928
# Generación 30: Mejor coste = 1855928
# Terminando en la generación 30 por falta de mejora.
# Procesando archivo: tai60b.dat
# Generación 1: Mejor coste = 875009721
# Generación 2: Mejor coste = 866687687
# Generación 3: Mejor coste = 817531349
# Generación 4: Mejor coste = 855167423
# Generación 5: Mejor coste = 833025591
# Generación 6: Mejor coste = 828692222
# Generación 7: Mejor coste = 815643523
# Generación 8: Mejor coste = 815643523
# Generación 9: Mejor coste = 790974450
# Generación 10: Mejor coste = 810137122
# Generación 11: Mejor coste = 799196678
# Generación 12: Mejor coste = 799196678
# Generación 13: Mejor coste = 799196678
# Generación 14: Mejor coste = 787380895
# Generación 15: Mejor coste = 777702691
# Generación 16: Mejor coste = 777702691
# Generación 17: Mejor coste = 763783913
# Generación 18: Mejor coste = 765760535
# Generación 19: Mejor coste = 755714505
# Generación 20: Mejor coste = 757290554
# Generación 21: Mejor coste = 742682582
# Generación 22: Mejor coste = 743064923
# Generación 23: Mejor coste = 735810856
# Generación 24: Mejor coste = 731120740
# Generación 25: Mejor coste = 720674151
# Generación 26: Mejor coste = 720119481
# Generación 27: Mejor coste = 715571864
# Generación 28: Mejor coste = 715551067
# Generación 29: Mejor coste = 707809185
# Generación 30: Mejor coste = 702729766
# Generación 31: Mejor coste = 701296694
# Generación 32: Mejor coste = 697284829
# Generación 33: Mejor coste = 692715269
# Generación 34: Mejor coste = 689576676
# Generación 35: Mejor coste = 690395190
# Generación 36: Mejor coste = 683764379
# Generación 37: Mejor coste = 687304954
# Generación 38: Mejor coste = 681345216
# Generación 39: Mejor coste = 681434178
# Generación 40: Mejor coste = 681419417
# Generación 41: Mejor coste = 680084843
# Generación 42: Mejor coste = 679234199
# Generación 43: Mejor coste = 675841033
# Generación 44: Mejor coste = 675643848
# Generación 45: Mejor coste = 673298712
# Generación 46: Mejor coste = 673298712
# Generación 47: Mejor coste = 670010897
# Generación 48: Mejor coste = 668497372
# Generación 49: Mejor coste = 662734208
# Generación 50: Mejor coste = 662331377
# Generación 51: Mejor coste = 659816385
# Generación 52: Mejor coste = 659145492
# Generación 53: Mejor coste = 657833857
# Generación 54: Mejor coste = 657818148
# Generación 55: Mejor coste = 657570696
# Generación 56: Mejor coste = 657212601
# Generación 57: Mejor coste = 656674752
# Generación 58: Mejor coste = 655240823
# Generación 59: Mejor coste = 654086143
# Generación 60: Mejor coste = 653746851
# Generación 61: Mejor coste = 653755972
# Generación 62: Mejor coste = 651190339
# Generación 63: Mejor coste = 650397788
# Generación 64: Mejor coste = 650206883
# Generación 65: Mejor coste = 650112566
# Generación 66: Mejor coste = 648735817
# Generación 67: Mejor coste = 648417781
# Generación 68: Mejor coste = 647122070
# Generación 69: Mejor coste = 647117147
# Generación 70: Mejor coste = 646889495
# Generación 71: Mejor coste = 646342210
# Generación 72: Mejor coste = 645265051
# Generación 73: Mejor coste = 644854435
# Generación 74: Mejor coste = 644663891
# Generación 75: Mejor coste = 644441719
# Generación 76: Mejor coste = 643836084
# Generación 77: Mejor coste = 643726775
# Generación 78: Mejor coste = 643001727
# Generación 79: Mejor coste = 643001727
# Generación 80: Mejor coste = 642851984
# Generación 81: Mejor coste = 642342270
# Generación 82: Mejor coste = 642342270
# Generación 83: Mejor coste = 641506091
# Generación 84: Mejor coste = 641413705
# Generación 85: Mejor coste = 640906062
# Generación 86: Mejor coste = 640906062
# Generación 87: Mejor coste = 640848125
# Generación 88: Mejor coste = 640842295
# Generación 89: Mejor coste = 640791561
# Generación 90: Mejor coste = 640624468
# Generación 91: Mejor coste = 640624468
# Generación 92: Mejor coste = 640624468
# Generación 93: Mejor coste = 633605371
# Generación 94: Mejor coste = 633605371
# Generación 95: Mejor coste = 633599524
# Generación 96: Mejor coste = 633599524
# Generación 97: Mejor coste = 633104591
# Generación 98: Mejor coste = 633104591
# Generación 99: Mejor coste = 633064073
# Generación 100: Mejor coste = 633042864
# Generación 101: Mejor coste = 630425966
# Generación 102: Mejor coste = 630425966
# Generación 103: Mejor coste = 630366416
# Generación 104: Mejor coste = 630366416
# Generación 105: Mejor coste = 630207274
# Generación 106: Mejor coste = 630207274
# Generación 107: Mejor coste = 630000816
# Generación 108: Mejor coste = 630000816
# Generación 109: Mejor coste = 629848185
# Generación 110: Mejor coste = 629790869
# Generación 111: Mejor coste = 629790869
# Generación 112: Mejor coste = 629768311
# Generación 113: Mejor coste = 629702541
# Generación 114: Mejor coste = 629702541
# Generación 115: Mejor coste = 629624315
# Generación 116: Mejor coste = 629624315
# Generación 117: Mejor coste = 629558421
# Generación 118: Mejor coste = 629205346
# Generación 119: Mejor coste = 629205346
# Generación 120: Mejor coste = 629052439
# Generación 121: Mejor coste = 629052439
# Generación 122: Mejor coste = 628815940
# Generación 123: Mejor coste = 628600625
# Generación 124: Mejor coste = 628600625
# Generación 125: Mejor coste = 628076790
# Generación 126: Mejor coste = 627823966
# Generación 127: Mejor coste = 627823966
# Generación 128: Mejor coste = 626659873
# Generación 129: Mejor coste = 626659873
# Generación 130: Mejor coste = 626384254
# Generación 131: Mejor coste = 626313778
# Generación 132: Mejor coste = 626098072
# Generación 133: Mejor coste = 625815728
# Generación 134: Mejor coste = 624461605
# Generación 135: Mejor coste = 623989523
# Generación 136: Mejor coste = 623989523
# Generación 137: Mejor coste = 623920621
# Generación 138: Mejor coste = 623572216
# Generación 139: Mejor coste = 623572216
# Generación 140: Mejor coste = 623451923
# Generación 141: Mejor coste = 623087133
# Generación 142: Mejor coste = 622784912
# Generación 143: Mejor coste = 622784912
# Generación 144: Mejor coste = 622784912
# Generación 145: Mejor coste = 622410703
# Generación 146: Mejor coste = 622410703
# Generación 147: Mejor coste = 622092149
# Generación 148: Mejor coste = 621795419
# Generación 149: Mejor coste = 621274547
# Generación 150: Mejor coste = 621261313
# Generación 151: Mejor coste = 621218511
# Generación 152: Mejor coste = 621218511
# Generación 153: Mejor coste = 621218511
# Generación 154: Mejor coste = 621217299
# Generación 155: Mejor coste = 621217299
# Generación 156: Mejor coste = 621031905
# Generación 157: Mejor coste = 621030693
# Generación 158: Mejor coste = 620997159
# Generación 159: Mejor coste = 620997159
# Generación 160: Mejor coste = 620980148
# Generación 161: Mejor coste = 620953673
# Generación 162: Mejor coste = 620918927
# Generación 163: Mejor coste = 620470551
# Generación 164: Mejor coste = 620470551
# Generación 165: Mejor coste = 620470551
# Generación 166: Mejor coste = 620280075
# Generación 167: Mejor coste = 620280075
# Generación 168: Mejor coste = 620212599
# Generación 169: Mejor coste = 620212599
# Generación 170: Mejor coste = 620212599
# Generación 171: Mejor coste = 620103692
# Generación 172: Mejor coste = 620097717
# Generación 173: Mejor coste = 620097717
# Generación 174: Mejor coste = 620089445
# Generación 175: Mejor coste = 619978737
# Generación 176: Mejor coste = 619974563
# Generación 177: Mejor coste = 619863855
# Generación 178: Mejor coste = 619854322
# Generación 179: Mejor coste = 619854322
# Generación 180: Mejor coste = 619837701
# Generación 181: Mejor coste = 619744077
# Generación 182: Mejor coste = 619744077
# Generación 183: Mejor coste = 619744077
# Generación 184: Mejor coste = 619711701
# Generación 185: Mejor coste = 619711701
# Generación 186: Mejor coste = 619711701
# Generación 187: Mejor coste = 619533124
# Generación 188: Mejor coste = 619533124
# Generación 189: Mejor coste = 619533124
# Generación 190: Mejor coste = 619533124
# Generación 191: Mejor coste = 619461611
# Generación 192: Mejor coste = 619461611
# Generación 193: Mejor coste = 619394038
# Generación 194: Mejor coste = 619394038
# Generación 195: Mejor coste = 619394038
# Generación 196: Mejor coste = 619394038
# Generación 197: Mejor coste = 619394038
# Generación 198: Mejor coste = 619394038
# Generación 199: Mejor coste = 619394038
# Generación 200: Mejor coste = 619394038
# Generación 201: Mejor coste = 619394038
# Generación 202: Mejor coste = 619394038
# Generación 203: Mejor coste = 619394038
# Generación 204: Mejor coste = 619394038
# Generación 205: Mejor coste = 619394038
# Generación 206: Mejor coste = 619394038
# Generación 207: Mejor coste = 619087604
# Generación 208: Mejor coste = 618399974
# Generación 209: Mejor coste = 618399974
# Generación 210: Mejor coste = 618399974
# Generación 211: Mejor coste = 618399974
# Generación 212: Mejor coste = 618093540
# Generación 213: Mejor coste = 618093540
# Generación 214: Mejor coste = 618093540
# Generación 215: Mejor coste = 618093540
# Generación 216: Mejor coste = 618093540
# Generación 217: Mejor coste = 617898650
# Generación 218: Mejor coste = 617898650
# Generación 219: Mejor coste = 617866007
# Generación 220: Mejor coste = 617866007
# Generación 221: Mejor coste = 617866007
# Generación 222: Mejor coste = 617671210
# Generación 223: Mejor coste = 617671210
# Generación 224: Mejor coste = 617632087
# Generación 225: Mejor coste = 617577553
# Generación 226: Mejor coste = 617463202
# Generación 227: Mejor coste = 617078800
# Generación 228: Mejor coste = 617078800
# Generación 229: Mejor coste = 617078800
# Generación 230: Mejor coste = 617078800
# Generación 231: Mejor coste = 617078800
# Generación 232: Mejor coste = 617078800
# Generación 233: Mejor coste = 617078800
# Generación 234: Mejor coste = 617039677
# Generación 235: Mejor coste = 617029171
# Generación 236: Mejor coste = 617029171
# Generación 237: Mejor coste = 617029171
# Generación 238: Mejor coste = 616989300
# Generación 239: Mejor coste = 616989300
# Generación 240: Mejor coste = 616773649
# Generación 241: Mejor coste = 616773649
# Generación 242: Mejor coste = 616772978
# Generación 243: Mejor coste = 616772978
# Generación 244: Mejor coste = 616772978
# Generación 245: Mejor coste = 616710740
# Generación 246: Mejor coste = 616710740
# Generación 247: Mejor coste = 616671617
# Generación 248: Mejor coste = 616671617
# Generación 249: Mejor coste = 616670946
# Generación 250: Mejor coste = 616670946
# Generación 251: Mejor coste = 616670946
# Generación 252: Mejor coste = 616663554
# Generación 253: Mejor coste = 616661744
# Generación 254: Mejor coste = 616661744
# Generación 255: Mejor coste = 616654352
# Generación 256: Mejor coste = 616651362
# Generación 257: Mejor coste = 616651362
# Generación 258: Mejor coste = 616651362
# Generación 259: Mejor coste = 616651362
# Generación 260: Mejor coste = 616651362
# Generación 261: Mejor coste = 616636109
# Generación 262: Mejor coste = 616607388
# Generación 263: Mejor coste = 616607388
# Generación 264: Mejor coste = 616592135
# Generación 265: Mejor coste = 616592135
# Generación 266: Mejor coste = 616592135
# Generación 267: Mejor coste = 616592135
# Generación 268: Mejor coste = 616592135
# Generación 269: Mejor coste = 616592135
# Generación 270: Mejor coste = 616592135
# Generación 271: Mejor coste = 616592135
# Generación 272: Mejor coste = 616592135
# Generación 273: Mejor coste = 616592135
# Generación 274: Mejor coste = 616592135
# Generación 275: Mejor coste = 616592135
# Generación 276: Mejor coste = 616580643
# Generación 277: Mejor coste = 616580643
# Generación 278: Mejor coste = 616580643
# Generación 279: Mejor coste = 616580643
# Generación 280: Mejor coste = 616580643
# Generación 281: Mejor coste = 616580643
# Generación 282: Mejor coste = 616580643
# Generación 283: Mejor coste = 616580643
# Generación 284: Mejor coste = 616580643
# Generación 285: Mejor coste = 616580643
# Generación 286: Mejor coste = 616580643
# Generación 287: Mejor coste = 616580643
# Generación 288: Mejor coste = 616580643
# Generación 289: Mejor coste = 616580643
# Generación 290: Mejor coste = 616580643
# Generación 291: Mejor coste = 616580643
# Terminando en la generación 291 por falta de mejora.
# Generación 1: Mejor coste = 890863242
# Generación 2: Mejor coste = 753803690
# Generación 3: Mejor coste = 724940540
# Generación 4: Mejor coste = 703617526
# Generación 5: Mejor coste = 690736469
# Generación 6: Mejor coste = 674462042
# Generación 7: Mejor coste = 670183960
# Generación 8: Mejor coste = 645585154
# Generación 9: Mejor coste = 641938146
# Generación 10: Mejor coste = 637290543
# Generación 11: Mejor coste = 630910138
# Generación 12: Mejor coste = 629732029
# Generación 13: Mejor coste = 627501247
# Generación 14: Mejor coste = 626664589
# Generación 15: Mejor coste = 626621225
# Generación 16: Mejor coste = 626242543
# Generación 17: Mejor coste = 626241231
# Generación 18: Mejor coste = 626206095
# Generación 19: Mejor coste = 625853993
# Generación 20: Mejor coste = 625537157
# Generación 21: Mejor coste = 622347600
# Generación 22: Mejor coste = 622347600
# Generación 23: Mejor coste = 622347600
# Generación 24: Mejor coste = 622347600
# Generación 25: Mejor coste = 622270176
# Generación 26: Mejor coste = 621558626
# Generación 27: Mejor coste = 621544709
# Generación 28: Mejor coste = 621544709
# Generación 29: Mejor coste = 621419517
# Generación 30: Mejor coste = 621315285
# Generación 31: Mejor coste = 620552651
# Generación 32: Mejor coste = 620295277
# Generación 33: Mejor coste = 620292476
# Generación 34: Mejor coste = 620273839
# Generación 35: Mejor coste = 620072505
# Generación 36: Mejor coste = 620034513
# Generación 37: Mejor coste = 620034513
# Generación 38: Mejor coste = 619373871
# Generación 39: Mejor coste = 619299966
# Generación 40: Mejor coste = 619299966
# Generación 41: Mejor coste = 618983699
# Generación 42: Mejor coste = 617305374
# Generación 43: Mejor coste = 616721135
# Generación 44: Mejor coste = 616721135
# Generación 45: Mejor coste = 616694872
# Generación 46: Mejor coste = 616694872
# Generación 47: Mejor coste = 616691191
# Generación 48: Mejor coste = 616490803
# Generación 49: Mejor coste = 616489576
# Generación 50: Mejor coste = 615789130
# Generación 51: Mejor coste = 615789130
# Generación 52: Mejor coste = 615754899
# Generación 53: Mejor coste = 615474285
# Generación 54: Mejor coste = 614978068
# Generación 55: Mejor coste = 614978068
# Generación 56: Mejor coste = 613504186
# Generación 57: Mejor coste = 613163473
# Generación 58: Mejor coste = 613108301
# Generación 59: Mejor coste = 613108301
# Generación 60: Mejor coste = 613108301
# Generación 61: Mejor coste = 613108301
# Generación 62: Mejor coste = 613108301
# Generación 63: Mejor coste = 613108301
# Generación 64: Mejor coste = 613108301
# Generación 65: Mejor coste = 613108301
# Generación 66: Mejor coste = 613108301
# Generación 67: Mejor coste = 613062170
# Generación 68: Mejor coste = 613062170
# Generación 69: Mejor coste = 613062170
# Generación 70: Mejor coste = 613062170
# Generación 71: Mejor coste = 612964392
# Generación 72: Mejor coste = 612964392
# Generación 73: Mejor coste = 612709431
# Generación 74: Mejor coste = 612709431
# Generación 75: Mejor coste = 612709431
# Generación 76: Mejor coste = 612529760
# Generación 77: Mejor coste = 612529760
# Generación 78: Mejor coste = 612519817
# Generación 79: Mejor coste = 612519817
# Generación 80: Mejor coste = 612519817
# Generación 81: Mejor coste = 612363922
# Generación 82: Mejor coste = 612363922
# Generación 83: Mejor coste = 612344649
# Generación 84: Mejor coste = 612344649
# Generación 85: Mejor coste = 612344649
# Generación 86: Mejor coste = 612319665
# Generación 87: Mejor coste = 612319665
# Generación 88: Mejor coste = 612123437
# Generación 89: Mejor coste = 612123437
# Generación 90: Mejor coste = 612123437
# Generación 91: Mejor coste = 612123437
# Generación 92: Mejor coste = 612123437
# Generación 93: Mejor coste = 612123437
# Generación 94: Mejor coste = 612123437
# Generación 95: Mejor coste = 612122844
# Generación 96: Mejor coste = 612122844
# Generación 97: Mejor coste = 612122844
# Generación 98: Mejor coste = 612122844
# Generación 99: Mejor coste = 611987953
# Generación 100: Mejor coste = 611987953
# Generación 101: Mejor coste = 611987953
# Generación 102: Mejor coste = 611965361
# Generación 103: Mejor coste = 611965361
# Generación 104: Mejor coste = 611940340
# Generación 105: Mejor coste = 611940340
# Generación 106: Mejor coste = 611940340
# Generación 107: Mejor coste = 611940340
# Generación 108: Mejor coste = 611940340
# Generación 109: Mejor coste = 611940340
# Generación 110: Mejor coste = 611940340
# Generación 111: Mejor coste = 611940340
# Generación 112: Mejor coste = 611933284
# Generación 113: Mejor coste = 611933284
# Generación 114: Mejor coste = 611933284
# Generación 115: Mejor coste = 611933284
# Generación 116: Mejor coste = 611933284
# Generación 117: Mejor coste = 611933284
# Generación 118: Mejor coste = 611933284
# Generación 119: Mejor coste = 611933284
# Generación 120: Mejor coste = 611933284
# Generación 121: Mejor coste = 611933284
# Generación 122: Mejor coste = 611933284
# Generación 123: Mejor coste = 611933284
# Generación 124: Mejor coste = 611933284
# Generación 125: Mejor coste = 611933284
# Generación 126: Mejor coste = 611904972
# Generación 127: Mejor coste = 611898067
# Generación 128: Mejor coste = 611898067
# Generación 129: Mejor coste = 611898067
# Generación 130: Mejor coste = 611898067
# Generación 131: Mejor coste = 611898067
# Generación 132: Mejor coste = 611898067
# Generación 133: Mejor coste = 611898067
# Generación 134: Mejor coste = 611898067
# Generación 135: Mejor coste = 611898067
# Generación 136: Mejor coste = 611898067
# Generación 137: Mejor coste = 611898067
# Generación 138: Mejor coste = 611898067
# Generación 139: Mejor coste = 611898067
# Generación 140: Mejor coste = 611898067
# Generación 141: Mejor coste = 611898067
# Generación 142: Mejor coste = 611898067
# Terminando en la generación 142 por falta de mejora.
# Generación 1: Mejor coste = 761844976
# Generación 2: Mejor coste = 712245048
# Generación 3: Mejor coste = 692622872
# Generación 4: Mejor coste = 661684086
# Generación 5: Mejor coste = 658401521
# Generación 6: Mejor coste = 652343856
# Generación 7: Mejor coste = 648476692
# Generación 8: Mejor coste = 637714143
# Generación 9: Mejor coste = 636634136
# Generación 10: Mejor coste = 633129016
# Generación 11: Mejor coste = 631950913
# Generación 12: Mejor coste = 630901620
# Generación 13: Mejor coste = 630700516
# Generación 14: Mejor coste = 630361742
# Generación 15: Mejor coste = 628631415
# Generación 16: Mejor coste = 628244936
# Generación 17: Mejor coste = 627739780
# Generación 18: Mejor coste = 627615664
# Generación 19: Mejor coste = 626610791
# Generación 20: Mejor coste = 625068736
# Generación 21: Mejor coste = 624249284
# Generación 22: Mejor coste = 622484414
# Generación 23: Mejor coste = 622378531
# Generación 24: Mejor coste = 622378531
# Generación 25: Mejor coste = 621319862
# Generación 26: Mejor coste = 621226909
# Generación 27: Mejor coste = 621193945
# Generación 28: Mejor coste = 621024654
# Generación 29: Mejor coste = 620843861
# Generación 30: Mejor coste = 620843861
# Generación 31: Mejor coste = 620759985
# Generación 32: Mejor coste = 620722411
# Generación 33: Mejor coste = 620133667
# Generación 34: Mejor coste = 618935918
# Generación 35: Mejor coste = 618441280
# Generación 36: Mejor coste = 618441280
# Generación 37: Mejor coste = 618180391
# Generación 38: Mejor coste = 617806039
# Generación 39: Mejor coste = 617368941
# Generación 40: Mejor coste = 617368941
# Generación 41: Mejor coste = 617368941
# Generación 42: Mejor coste = 617296650
# Generación 43: Mejor coste = 617296650
# Generación 44: Mejor coste = 617296650
# Generación 45: Mejor coste = 617263543
# Generación 46: Mejor coste = 617263543
# Generación 47: Mejor coste = 617263543
# Generación 48: Mejor coste = 616894432
# Generación 49: Mejor coste = 616894432
# Generación 50: Mejor coste = 616894432
# Generación 51: Mejor coste = 616547530
# Generación 52: Mejor coste = 614955423
# Generación 53: Mejor coste = 614897210
# Generación 54: Mejor coste = 614487804
# Generación 55: Mejor coste = 614487804
# Generación 56: Mejor coste = 614487804
# Generación 57: Mejor coste = 614487804
# Generación 58: Mejor coste = 614198607
# Generación 59: Mejor coste = 614172167
# Generación 60: Mejor coste = 614172167
# Generación 61: Mejor coste = 614172167
# Generación 62: Mejor coste = 614172167
# Generación 63: Mejor coste = 614172167
# Generación 64: Mejor coste = 614079625
# Generación 65: Mejor coste = 614079625
# Generación 66: Mejor coste = 613848338
# Generación 67: Mejor coste = 613848338
# Generación 68: Mejor coste = 613848338
# Generación 69: Mejor coste = 613809019
# Generación 70: Mejor coste = 613809019
# Generación 71: Mejor coste = 613809019
# Generación 72: Mejor coste = 612513710
# Generación 73: Mejor coste = 612513710
# Generación 74: Mejor coste = 612473940
# Generación 75: Mejor coste = 612473940
# Generación 76: Mejor coste = 612471804
# Generación 77: Mejor coste = 612471804
# Generación 78: Mejor coste = 612470638
# Generación 79: Mejor coste = 612470638
# Generación 80: Mejor coste = 612467151
# Generación 81: Mejor coste = 612421304
# Generación 82: Mejor coste = 612421304
# Generación 83: Mejor coste = 612421304
# Generación 84: Mejor coste = 612421304
# Generación 85: Mejor coste = 612421304
# Generación 86: Mejor coste = 612421304
# Generación 87: Mejor coste = 612320344
# Generación 88: Mejor coste = 612320344
# Generación 89: Mejor coste = 612319973
# Generación 90: Mejor coste = 612235299
# Generación 91: Mejor coste = 612235299
# Generación 92: Mejor coste = 612235299
# Generación 93: Mejor coste = 612235299
# Generación 94: Mejor coste = 612144044
# Generación 95: Mejor coste = 612144044
# Generación 96: Mejor coste = 612144044
# Generación 97: Mejor coste = 612144044
# Generación 98: Mejor coste = 612144044
# Generación 99: Mejor coste = 612144044
# Generación 100: Mejor coste = 612144044
# Generación 101: Mejor coste = 612141676
# Generación 102: Mejor coste = 612141676
# Generación 103: Mejor coste = 612141676
# Generación 104: Mejor coste = 612141676
# Generación 105: Mejor coste = 612141676
# Generación 106: Mejor coste = 612141227
# Generación 107: Mejor coste = 612141227
# Generación 108: Mejor coste = 612141227
# Generación 109: Mejor coste = 612141227
# Generación 110: Mejor coste = 612141227
# Generación 111: Mejor coste = 612138626
# Generación 112: Mejor coste = 612138626
# Generación 113: Mejor coste = 612138626
# Generación 114: Mejor coste = 612029305
# Generación 115: Mejor coste = 612029305
# Generación 116: Mejor coste = 612029305
# Generación 117: Mejor coste = 612029305
# Generación 118: Mejor coste = 612029305
# Generación 119: Mejor coste = 612029305
# Generación 120: Mejor coste = 612029305
# Generación 121: Mejor coste = 612029305
# Generación 122: Mejor coste = 612029305
# Generación 123: Mejor coste = 612029305
# Generación 124: Mejor coste = 612029305
# Generación 125: Mejor coste = 612029305
# Generación 126: Mejor coste = 612029305
# Generación 127: Mejor coste = 612029305
# Generación 128: Mejor coste = 612029305
# Generación 129: Mejor coste = 612029305
# Terminando en la generación 129 por falta de mejora.
# Procesando archivo: lipa20a.dat
# Generación 1: Mejor coste = 3865
# Generación 2: Mejor coste = 3842
# Generación 3: Mejor coste = 3838
# Generación 4: Mejor coste = 3837
# Generación 5: Mejor coste = 3839
# Generación 6: Mejor coste = 3836
# Generación 7: Mejor coste = 3842
# Generación 8: Mejor coste = 3830
# Generación 9: Mejor coste = 3836
# Generación 10: Mejor coste = 3834
# Generación 11: Mejor coste = 3834
# Generación 12: Mejor coste = 3813
# Generación 13: Mejor coste = 3813
# Generación 14: Mejor coste = 3813
# Generación 15: Mejor coste = 3813
# Generación 16: Mejor coste = 3807
# Generación 17: Mejor coste = 3807
# Generación 18: Mejor coste = 3800
# Generación 19: Mejor coste = 3800
# Generación 20: Mejor coste = 3800
# Generación 21: Mejor coste = 3792
# Generación 22: Mejor coste = 3799
# Generación 23: Mejor coste = 3792
# Generación 24: Mejor coste = 3792
# Generación 25: Mejor coste = 3787
# Generación 26: Mejor coste = 3787
# Generación 27: Mejor coste = 3787
# Generación 28: Mejor coste = 3787
# Generación 29: Mejor coste = 3787
# Generación 30: Mejor coste = 3780
# Generación 31: Mejor coste = 3778
# Generación 32: Mejor coste = 3778
# Generación 33: Mejor coste = 3778
# Generación 34: Mejor coste = 3774
# Generación 35: Mejor coste = 3772
# Generación 36: Mejor coste = 3769
# Generación 37: Mejor coste = 3769
# Generación 38: Mejor coste = 3764
# Generación 39: Mejor coste = 3764
# Generación 40: Mejor coste = 3764
# Generación 41: Mejor coste = 3764
# Generación 42: Mejor coste = 3764
# Generación 43: Mejor coste = 3757
# Generación 44: Mejor coste = 3757
# Generación 45: Mejor coste = 3757
# Generación 46: Mejor coste = 3757
# Generación 47: Mejor coste = 3757
# Generación 48: Mejor coste = 3757
# Generación 49: Mejor coste = 3757
# Generación 50: Mejor coste = 3757
# Generación 51: Mejor coste = 3757
# Generación 52: Mejor coste = 3757
# Generación 53: Mejor coste = 3757
# Generación 54: Mejor coste = 3757
# Generación 55: Mejor coste = 3757
# Generación 56: Mejor coste = 3757
# Generación 57: Mejor coste = 3757
# Generación 58: Mejor coste = 3757
# Terminando en la generación 58 por falta de mejora.
# Generación 1: Mejor coste = 3864
# Generación 2: Mejor coste = 3789
# Generación 3: Mejor coste = 3780
# Generación 4: Mejor coste = 3771
# Generación 5: Mejor coste = 3769
# Generación 6: Mejor coste = 3761
# Generación 7: Mejor coste = 3761
# Generación 8: Mejor coste = 3761
# Generación 9: Mejor coste = 3761
# Generación 10: Mejor coste = 3761
# Generación 11: Mejor coste = 3761
# Generación 12: Mejor coste = 3761
# Generación 13: Mejor coste = 3756
# Generación 14: Mejor coste = 3753
# Generación 15: Mejor coste = 3753
# Generación 16: Mejor coste = 3741
# Generación 17: Mejor coste = 3726
# Generación 18: Mejor coste = 3726
# Generación 19: Mejor coste = 3726
# Generación 20: Mejor coste = 3726
# Generación 21: Mejor coste = 3726
# Generación 22: Mejor coste = 3726
# Generación 23: Mejor coste = 3726
# Generación 24: Mejor coste = 3726
# Generación 25: Mejor coste = 3726
# Generación 26: Mejor coste = 3726
# Generación 27: Mejor coste = 3726
# Generación 28: Mejor coste = 3726
# Generación 29: Mejor coste = 3726
# Generación 30: Mejor coste = 3726
# Generación 31: Mejor coste = 3726
# Generación 32: Mejor coste = 3726
# Terminando en la generación 32 por falta de mejora.
# Generación 1: Mejor coste = 3780
# Generación 2: Mejor coste = 3753
# Generación 3: Mejor coste = 3743
# Generación 4: Mejor coste = 3721
# Generación 5: Mejor coste = 3718
# Generación 6: Mejor coste = 3716
# Generación 7: Mejor coste = 3709
# Generación 8: Mejor coste = 3683
# Generación 9: Mejor coste = 3683
# Generación 10: Mejor coste = 3683
# Generación 11: Mejor coste = 3683
# Generación 12: Mejor coste = 3683
# Generación 13: Mejor coste = 3683
# Generación 14: Mejor coste = 3683
# Generación 15: Mejor coste = 3683
# Generación 16: Mejor coste = 3683
# Generación 17: Mejor coste = 3683
# Generación 18: Mejor coste = 3683
# Generación 19: Mejor coste = 3683
# Generación 20: Mejor coste = 3683
# Generación 21: Mejor coste = 3683
# Generación 22: Mejor coste = 3683
# Generación 23: Mejor coste = 3683
# Terminando en la generación 23 por falta de mejora.
# Procesando archivo: lipa20b.dat
# Generación 1: Mejor coste = 31907
# Generación 2: Mejor coste = 31907
# Generación 3: Mejor coste = 32415
# Generación 4: Mejor coste = 32415
# Generación 5: Mejor coste = 32415
# Generación 6: Mejor coste = 32415
# Generación 7: Mejor coste = 32415
# Generación 8: Mejor coste = 31907
# Generación 9: Mejor coste = 31907
# Generación 10: Mejor coste = 31907
# Generación 11: Mejor coste = 31907
# Generación 12: Mejor coste = 31267
# Generación 13: Mejor coste = 31267
# Generación 14: Mejor coste = 31267
# Generación 15: Mejor coste = 31267
# Generación 16: Mejor coste = 31267
# Generación 17: Mejor coste = 31267
# Generación 18: Mejor coste = 31267
# Generación 19: Mejor coste = 31267
# Generación 20: Mejor coste = 31267
# Generación 21: Mejor coste = 31267
# Generación 22: Mejor coste = 31267
# Generación 23: Mejor coste = 31267
# Generación 24: Mejor coste = 31267
# Generación 25: Mejor coste = 31267
# Generación 26: Mejor coste = 31267
# Generación 27: Mejor coste = 31267
# Terminando en la generación 27 por falta de mejora.
# Generación 1: Mejor coste = 33819
# Generación 2: Mejor coste = 31390
# Generación 3: Mejor coste = 31010
# Generación 4: Mejor coste = 30977
# Generación 5: Mejor coste = 30090
# Generación 6: Mejor coste = 30090
# Generación 7: Mejor coste = 29277
# Generación 8: Mejor coste = 27076
# Generación 9: Mejor coste = 27076
# Generación 10: Mejor coste = 27076
# Generación 11: Mejor coste = 27076
# Generación 12: Mejor coste = 27076
# Generación 13: Mejor coste = 27076
# Generación 14: Mejor coste = 27076
# Generación 15: Mejor coste = 27076
# Generación 16: Mejor coste = 27076
# Generación 17: Mejor coste = 27076
# Generación 18: Mejor coste = 27076
# Generación 19: Mejor coste = 27076
# Generación 20: Mejor coste = 27076
# Generación 21: Mejor coste = 27076
# Generación 22: Mejor coste = 27076
# Generación 23: Mejor coste = 27076
# Terminando en la generación 23 por falta de mejora.
# Generación 1: Mejor coste = 30847
# Generación 2: Mejor coste = 28263
# Generación 3: Mejor coste = 28263
# Generación 4: Mejor coste = 27076
# Generación 5: Mejor coste = 27076
# Generación 6: Mejor coste = 27076
# Generación 7: Mejor coste = 27076
# Generación 8: Mejor coste = 27076
# Generación 9: Mejor coste = 27076
# Generación 10: Mejor coste = 27076
# Generación 11: Mejor coste = 27076
# Generación 12: Mejor coste = 27076
# Generación 13: Mejor coste = 27076
# Generación 14: Mejor coste = 27076
# Generación 15: Mejor coste = 27076
# Generación 16: Mejor coste = 27076
# Generación 17: Mejor coste = 27076
# Generación 18: Mejor coste = 27076
# Generación 19: Mejor coste = 27076
# Terminando en la generación 19 por falta de mejora.
# Procesando archivo: lipa30b.dat
# Generación 1: Mejor coste = 185095
# Generación 2: Mejor coste = 188412
# Generación 3: Mejor coste = 188595
# Generación 4: Mejor coste = 188374
# Generación 5: Mejor coste = 186796
# Generación 6: Mejor coste = 186796
# Generación 7: Mejor coste = 186954
# Generación 8: Mejor coste = 186954
# Generación 9: Mejor coste = 187003
# Generación 10: Mejor coste = 186873
# Generación 11: Mejor coste = 186873
# Generación 12: Mejor coste = 186442
# Generación 13: Mejor coste = 186442
# Generación 14: Mejor coste = 186790
# Generación 15: Mejor coste = 186790
# Generación 16: Mejor coste = 186671
# Terminando en la generación 16 por falta de mejora.
# Generación 1: Mejor coste = 189081
# Generación 2: Mejor coste = 180557
# Generación 3: Mejor coste = 179914
# Generación 4: Mejor coste = 178749
# Generación 5: Mejor coste = 177344
# Generación 6: Mejor coste = 177344
# Generación 7: Mejor coste = 176706
# Generación 8: Mejor coste = 176706
# Generación 9: Mejor coste = 176706
# Generación 10: Mejor coste = 176624
# Generación 11: Mejor coste = 176389
# Generación 12: Mejor coste = 176183
# Generación 13: Mejor coste = 176180
# Generación 14: Mejor coste = 175391
# Generación 15: Mejor coste = 173729
# Generación 16: Mejor coste = 172413
# Generación 17: Mejor coste = 171457
# Generación 18: Mejor coste = 167943
# Generación 19: Mejor coste = 167943
# Generación 20: Mejor coste = 166654
# Generación 21: Mejor coste = 165158
# Generación 22: Mejor coste = 165158
# Generación 23: Mejor coste = 163089
# Generación 24: Mejor coste = 162524
# Generación 25: Mejor coste = 162524
# Generación 26: Mejor coste = 162017
# Generación 27: Mejor coste = 162017
# Generación 28: Mejor coste = 162017
# Generación 29: Mejor coste = 159377
# Generación 30: Mejor coste = 159377
# Generación 31: Mejor coste = 156950
# Generación 32: Mejor coste = 151426
# Generación 33: Mejor coste = 151426
# Generación 34: Mejor coste = 151426
# Generación 35: Mejor coste = 151426
# Generación 36: Mejor coste = 151426
# Generación 37: Mejor coste = 151426
# Generación 38: Mejor coste = 151426
# Generación 39: Mejor coste = 151426
# Generación 40: Mejor coste = 151426
# Generación 41: Mejor coste = 151426
# Generación 42: Mejor coste = 151426
# Generación 43: Mejor coste = 151426
# Generación 44: Mejor coste = 151426
# Generación 45: Mejor coste = 151426
# Generación 46: Mejor coste = 151426
# Generación 47: Mejor coste = 151426
# Terminando en la generación 47 por falta de mejora.
# Generación 1: Mejor coste = 179796
# Generación 2: Mejor coste = 178906
# Generación 3: Mejor coste = 177534
# Generación 4: Mejor coste = 176403
# Generación 5: Mejor coste = 175085
# Generación 6: Mejor coste = 174617
# Generación 7: Mejor coste = 173843
# Generación 8: Mejor coste = 173131
# Generación 9: Mejor coste = 169830
# Generación 10: Mejor coste = 166670
# Generación 11: Mejor coste = 165262
# Generación 12: Mejor coste = 164352
# Generación 13: Mejor coste = 164352
# Generación 14: Mejor coste = 164352
# Generación 15: Mejor coste = 164352
# Generación 16: Mejor coste = 164352
# Generación 17: Mejor coste = 156446
# Generación 18: Mejor coste = 156446
# Generación 19: Mejor coste = 156446
# Generación 20: Mejor coste = 155540
# Generación 21: Mejor coste = 155540
# Generación 22: Mejor coste = 151426
# Generación 23: Mejor coste = 151426
# Generación 24: Mejor coste = 151426
# Generación 25: Mejor coste = 151426
# Generación 26: Mejor coste = 151426
# Generación 27: Mejor coste = 151426
# Generación 28: Mejor coste = 151426
# Generación 29: Mejor coste = 151426
# Generación 30: Mejor coste = 151426
# Generación 31: Mejor coste = 151426
# Generación 32: Mejor coste = 151426
# Generación 33: Mejor coste = 151426
# Generación 34: Mejor coste = 151426
# Generación 35: Mejor coste = 151426
# Generación 36: Mejor coste = 151426
# Generación 37: Mejor coste = 151426
# Terminando en la generación 37 por falta de mejora.
# Procesando archivo: lipa30a.dat
# Generación 1: Mejor coste = 13672
# Generación 2: Mejor coste = 13672
# Generación 3: Mejor coste = 13662
# Generación 4: Mejor coste = 13668
# Generación 5: Mejor coste = 13661
# Generación 6: Mejor coste = 13638
# Generación 7: Mejor coste = 13649
# Generación 8: Mejor coste = 13657
# Generación 9: Mejor coste = 13658
# Generación 10: Mejor coste = 13638
# Generación 11: Mejor coste = 13638
# Generación 12: Mejor coste = 13626
# Generación 13: Mejor coste = 13632
# Generación 14: Mejor coste = 13632
# Generación 15: Mejor coste = 13626
# Generación 16: Mejor coste = 13584
# Generación 17: Mejor coste = 13584
# Generación 18: Mejor coste = 13584
# Generación 19: Mejor coste = 13584
# Generación 20: Mejor coste = 13584
# Generación 21: Mejor coste = 13584
# Generación 22: Mejor coste = 13585
# Generación 23: Mejor coste = 13584
# Generación 24: Mejor coste = 13584
# Generación 25: Mejor coste = 13584
# Generación 26: Mejor coste = 13584
# Generación 27: Mejor coste = 13584
# Generación 28: Mejor coste = 13584
# Generación 29: Mejor coste = 13575
# Generación 30: Mejor coste = 13560
# Generación 31: Mejor coste = 13560
# Generación 32: Mejor coste = 13560
# Generación 33: Mejor coste = 13560
# Generación 34: Mejor coste = 13547
# Generación 35: Mejor coste = 13547
# Generación 36: Mejor coste = 13537
# Generación 37: Mejor coste = 13537
# Generación 38: Mejor coste = 13529
# Generación 39: Mejor coste = 13529
# Generación 40: Mejor coste = 13520
# Generación 41: Mejor coste = 13520
# Generación 42: Mejor coste = 13520
# Generación 43: Mejor coste = 13520
# Generación 44: Mejor coste = 13520
# Generación 45: Mejor coste = 13520
# Generación 46: Mejor coste = 13520
# Generación 47: Mejor coste = 13517
# Generación 48: Mejor coste = 13517
# Generación 49: Mejor coste = 13514
# Generación 50: Mejor coste = 13514
# Generación 51: Mejor coste = 13511
# Generación 52: Mejor coste = 13511
# Generación 53: Mejor coste = 13511
# Generación 54: Mejor coste = 13506
# Generación 55: Mejor coste = 13506
# Generación 56: Mejor coste = 13506
# Generación 57: Mejor coste = 13506
# Generación 58: Mejor coste = 13506
# Generación 59: Mejor coste = 13497
# Generación 60: Mejor coste = 13493
# Generación 61: Mejor coste = 13493
# Generación 62: Mejor coste = 13493
# Generación 63: Mejor coste = 13493
# Generación 64: Mejor coste = 13492
# Generación 65: Mejor coste = 13492
# Generación 66: Mejor coste = 13492
# Generación 67: Mejor coste = 13488
# Generación 68: Mejor coste = 13488
# Generación 69: Mejor coste = 13482
# Generación 70: Mejor coste = 13482
# Generación 71: Mejor coste = 13482
# Generación 72: Mejor coste = 13477
# Generación 73: Mejor coste = 13477
# Generación 74: Mejor coste = 13477
# Generación 75: Mejor coste = 13477
# Generación 76: Mejor coste = 13477
# Generación 77: Mejor coste = 13477
# Generación 78: Mejor coste = 13477
# Generación 79: Mejor coste = 13467
# Generación 80: Mejor coste = 13467
# Generación 81: Mejor coste = 13467
# Generación 82: Mejor coste = 13467
# Generación 83: Mejor coste = 13467
# Generación 84: Mejor coste = 13467
# Generación 85: Mejor coste = 13459
# Generación 86: Mejor coste = 13459
# Generación 87: Mejor coste = 13459
# Generación 88: Mejor coste = 13459
# Generación 89: Mejor coste = 13459
# Generación 90: Mejor coste = 13452
# Generación 91: Mejor coste = 13452
# Generación 92: Mejor coste = 13452
# Generación 93: Mejor coste = 13452
# Generación 94: Mejor coste = 13452
# Generación 95: Mejor coste = 13452
# Generación 96: Mejor coste = 13452
# Generación 97: Mejor coste = 13452
# Generación 98: Mejor coste = 13452
# Generación 99: Mejor coste = 13452
# Generación 100: Mejor coste = 13452
# Generación 101: Mejor coste = 13452
# Generación 102: Mejor coste = 13452
# Generación 103: Mejor coste = 13452
# Generación 104: Mejor coste = 13452
# Generación 105: Mejor coste = 13452
# Terminando en la generación 105 por falta de mejora.
# Generación 1: Mejor coste = 13675
# Generación 2: Mejor coste = 13517
# Generación 3: Mejor coste = 13484
# Generación 4: Mejor coste = 13457
# Generación 5: Mejor coste = 13451
# Generación 6: Mejor coste = 13445
# Generación 7: Mejor coste = 13407
# Generación 8: Mejor coste = 13407
# Generación 9: Mejor coste = 13390
# Generación 10: Mejor coste = 13390
# Generación 11: Mejor coste = 13390
# Generación 12: Mejor coste = 13390
# Generación 13: Mejor coste = 13390
# Generación 14: Mejor coste = 13390
# Generación 15: Mejor coste = 13390
# Generación 16: Mejor coste = 13390
# Generación 17: Mejor coste = 13390
# Generación 18: Mejor coste = 13390
# Generación 19: Mejor coste = 13390
# Generación 20: Mejor coste = 13390
# Generación 21: Mejor coste = 13380
# Generación 22: Mejor coste = 13380
# Generación 23: Mejor coste = 13380
# Generación 24: Mejor coste = 13380
# Generación 25: Mejor coste = 13380
# Generación 26: Mejor coste = 13380
# Generación 27: Mejor coste = 13380
# Generación 28: Mejor coste = 13378
# Generación 29: Mejor coste = 13378
# Generación 30: Mejor coste = 13378
# Generación 31: Mejor coste = 13378
# Generación 32: Mejor coste = 13378
# Generación 33: Mejor coste = 13378
# Generación 34: Mejor coste = 13378
# Generación 35: Mejor coste = 13378
# Generación 36: Mejor coste = 13378
# Generación 37: Mejor coste = 13378
# Generación 38: Mejor coste = 13378
# Generación 39: Mejor coste = 13378
# Generación 40: Mejor coste = 13378
# Generación 41: Mejor coste = 13378
# Generación 42: Mejor coste = 13378
# Generación 43: Mejor coste = 13378
# Terminando en la generación 43 por falta de mejora.
# Generación 1: Mejor coste = 13499
# Generación 2: Mejor coste = 13473
# Generación 3: Mejor coste = 13433
# Generación 4: Mejor coste = 13430
# Generación 5: Mejor coste = 13430
# Generación 6: Mejor coste = 13416
# Generación 7: Mejor coste = 13398
# Generación 8: Mejor coste = 13398
# Generación 9: Mejor coste = 13398
# Generación 10: Mejor coste = 13397
# Generación 11: Mejor coste = 13397
# Generación 12: Mejor coste = 13397
# Generación 13: Mejor coste = 13390
# Generación 14: Mejor coste = 13390
# Generación 15: Mejor coste = 13390
# Generación 16: Mejor coste = 13390
# Generación 17: Mejor coste = 13390
# Generación 18: Mejor coste = 13390
# Generación 19: Mejor coste = 13390
# Generación 20: Mejor coste = 13387
# Generación 21: Mejor coste = 13387
# Generación 22: Mejor coste = 13387
# Generación 23: Mejor coste = 13387
# Generación 24: Mejor coste = 13387
# Generación 25: Mejor coste = 13387
# Generación 26: Mejor coste = 13387
# Generación 27: Mejor coste = 13387
# Generación 28: Mejor coste = 13387
# Generación 29: Mejor coste = 13387
# Generación 30: Mejor coste = 13387
# Generación 31: Mejor coste = 13387
# Generación 32: Mejor coste = 13387
# Generación 33: Mejor coste = 13387
# Generación 34: Mejor coste = 13387
# Generación 35: Mejor coste = 13387
# Terminando en la generación 35 por falta de mejora.
# Procesando archivo: lipa40a.dat
# Generación 1: Mejor coste = 32486
# Generación 2: Mejor coste = 32469
# Generación 3: Mejor coste = 32447
# Generación 4: Mejor coste = 32436
# Generación 5: Mejor coste = 32463
# Generación 6: Mejor coste = 32465
# Generación 7: Mejor coste = 32448
# Generación 8: Mejor coste = 32448
# Generación 9: Mejor coste = 32448
# Generación 10: Mejor coste = 32472
# Generación 11: Mejor coste = 32423
# Generación 12: Mejor coste = 32423
# Generación 13: Mejor coste = 32423
# Generación 14: Mejor coste = 32462
# Generación 15: Mejor coste = 32460
# Generación 16: Mejor coste = 32411
# Generación 17: Mejor coste = 32411
# Generación 18: Mejor coste = 32411
# Generación 19: Mejor coste = 32411
# Generación 20: Mejor coste = 32439
# Generación 21: Mejor coste = 32442
# Generación 22: Mejor coste = 32406
# Generación 23: Mejor coste = 32406
# Generación 24: Mejor coste = 32424
# Generación 25: Mejor coste = 32424
# Generación 26: Mejor coste = 32382
# Generación 27: Mejor coste = 32422
# Generación 28: Mejor coste = 32424
# Generación 29: Mejor coste = 32368
# Generación 30: Mejor coste = 32368
# Generación 31: Mejor coste = 32360
# Generación 32: Mejor coste = 32360
# Generación 33: Mejor coste = 32366
# Generación 34: Mejor coste = 32366
# Generación 35: Mejor coste = 32366
# Generación 36: Mejor coste = 32366
# Generación 37: Mejor coste = 32366
# Generación 38: Mejor coste = 32366
# Generación 39: Mejor coste = 32350
# Generación 40: Mejor coste = 32366
# Generación 41: Mejor coste = 32332
# Generación 42: Mejor coste = 32314
# Generación 43: Mejor coste = 32314
# Generación 44: Mejor coste = 32291
# Generación 45: Mejor coste = 32304
# Generación 46: Mejor coste = 32297
# Generación 47: Mejor coste = 32301
# Generación 48: Mejor coste = 32304
# Generación 49: Mejor coste = 32290
# Generación 50: Mejor coste = 32287
# Generación 51: Mejor coste = 32287
# Generación 52: Mejor coste = 32256
# Generación 53: Mejor coste = 32256
# Generación 54: Mejor coste = 32256
# Generación 55: Mejor coste = 32226
# Generación 56: Mejor coste = 32226
# Generación 57: Mejor coste = 32226
# Generación 58: Mejor coste = 32226
# Generación 59: Mejor coste = 32226
# Generación 60: Mejor coste = 32223
# Generación 61: Mejor coste = 32206
# Generación 62: Mejor coste = 32206
# Generación 63: Mejor coste = 32172
# Generación 64: Mejor coste = 32172
# Generación 65: Mejor coste = 32172
# Generación 66: Mejor coste = 32172
# Generación 67: Mejor coste = 32172
# Generación 68: Mejor coste = 32158
# Generación 69: Mejor coste = 32158
# Generación 70: Mejor coste = 32158
# Generación 71: Mejor coste = 32145
# Generación 72: Mejor coste = 32145
# Generación 73: Mejor coste = 32145
# Generación 74: Mejor coste = 32145
# Generación 75: Mejor coste = 32145
# Generación 76: Mejor coste = 32144
# Generación 77: Mejor coste = 32144
# Generación 78: Mejor coste = 32131
# Generación 79: Mejor coste = 32131
# Generación 80: Mejor coste = 32118
# Generación 81: Mejor coste = 32118
# Generación 82: Mejor coste = 32118
# Generación 83: Mejor coste = 32118
# Generación 84: Mejor coste = 32118
# Generación 85: Mejor coste = 32110
# Generación 86: Mejor coste = 32110
# Generación 87: Mejor coste = 32110
# Generación 88: Mejor coste = 32110
# Generación 89: Mejor coste = 32110
# Generación 90: Mejor coste = 32110
# Generación 91: Mejor coste = 32110
# Generación 92: Mejor coste = 32110
# Generación 93: Mejor coste = 32109
# Generación 94: Mejor coste = 32109
# Generación 95: Mejor coste = 32101
# Generación 96: Mejor coste = 32101
# Generación 97: Mejor coste = 32101
# Generación 98: Mejor coste = 32090
# Generación 99: Mejor coste = 32090
# Generación 100: Mejor coste = 32090
# Generación 101: Mejor coste = 32082
# Generación 102: Mejor coste = 32082
# Generación 103: Mejor coste = 32082
# Generación 104: Mejor coste = 32082
# Generación 105: Mejor coste = 32082
# Generación 106: Mejor coste = 32073
# ...
# Generación 30: Mejor coste = 9501276
# Generación 31: Mejor coste = 9501276
# Generación 32: Mejor coste = 9498092
# Generación 33: Mejor coste = 9498092
# Generación 34: Mejor coste = 9498092
# Generación 35: Mejor coste = 9498092
# Generación 36: Mejor coste = 9498092
# Generación 37: Mejor coste = 9498092
# Generación 38: Mejor coste = 9489478
# Generación 39: Mejor coste = 9489478
# Generación 40: Mejor coste = 9489478
# Generación 41: Mejor coste = 9489478
# Generación 42: Mejor coste = 9489478
# Generación 43: Mejor coste = 9479055
# Generación 44: Mejor coste = 9479055
# Generación 45: Mejor coste = 9479055
# Generación 46: Mejor coste = 9479055
# Generación 47: Mejor coste = 9479055
# Generación 48: Mejor coste = 9479055
# Generación 49: Mejor coste = 9477257
# Generación 50: Mejor coste = 9476764
# Generación 51: Mejor coste = 9471904
# Generación 52: Mejor coste = 9471904
# Generación 53: Mejor coste = 9457385
# Generación 54: Mejor coste = 9457385
# Generación 55: Mejor coste = 9455405
# Generación 56: Mejor coste = 9455405
# Generación 57: Mejor coste = 9453706
# Generación 58: Mejor coste = 9453706
# Generación 59: Mejor coste = 9452204
# Generación 60: Mejor coste = 9452204
# Generación 61: Mejor coste = 9452204
# Generación 62: Mejor coste = 9452204
# Generación 63: Mejor coste = 9452204
# Generación 64: Mejor coste = 9452204
# Generación 65: Mejor coste = 9452204
# Generación 66: Mejor coste = 9449190
# Generación 67: Mejor coste = 9449190
# Generación 68: Mejor coste = 9449190
# Generación 69: Mejor coste = 9446871
# Generación 70: Mejor coste = 9446871
# Generación 71: Mejor coste = 9446871
# Generación 72: Mejor coste = 9446871
# Generación 73: Mejor coste = 9446871
# Generación 74: Mejor coste = 9446871
# Generación 75: Mejor coste = 9446871
# Generación 76: Mejor coste = 9446871
# Generación 77: Mejor coste = 9446871
# Generación 78: Mejor coste = 9446871
# Generación 79: Mejor coste = 9439610
# Generación 80: Mejor coste = 9439610
# Generación 81: Mejor coste = 9439610
# Generación 82: Mejor coste = 9439610
# Generación 83: Mejor coste = 9439610
# Generación 84: Mejor coste = 9439610
# Generación 85: Mejor coste = 9438799
# Generación 86: Mejor coste = 9438799
# Generación 87: Mejor coste = 9437548
# Generación 88: Mejor coste = 9437548
# Generación 89: Mejor coste = 9437548
# Generación 90: Mejor coste = 9437548
# Generación 91: Mejor coste = 9437548
# Generación 92: Mejor coste = 9437548
# Generación 93: Mejor coste = 9437548
# Generación 94: Mejor coste = 9437548
# Generación 95: Mejor coste = 9437548
# Generación 96: Mejor coste = 9437548
# Generación 97: Mejor coste = 9437548
# Generación 98: Mejor coste = 9437548
# Generación 99: Mejor coste = 9437548
# Generación 100: Mejor coste = 9437548
# Generación 101: Mejor coste = 9437548
# Generación 102: Mejor coste = 9437548
# Terminando en la generación 102 por falta de mejora.
# Generación 1: Mejor coste = 9801359
# Generación 2: Mejor coste = 9740636
# Generación 3: Mejor coste = 9695032
# Generación 4: Mejor coste = 9657136
# Generación 5: Mejor coste = 9639381
# Generación 6: Mejor coste = 9614874
# Generación 7: Mejor coste = 9601607
# Generación 8: Mejor coste = 9586265
# Generación 9: Mejor coste = 9579820
# Generación 10: Mejor coste = 9571295
# Generación 11: Mejor coste = 9554288
# Generación 12: Mejor coste = 9552323
# Generación 13: Mejor coste = 9552323
# Generación 14: Mejor coste = 9545332
# Generación 15: Mejor coste = 9539384
# Generación 16: Mejor coste = 9531688
# Generación 17: Mejor coste = 9531688
# Generación 18: Mejor coste = 9527177
# Generación 19: Mejor coste = 9511402
# Generación 20: Mejor coste = 9506131
# Generación 21: Mejor coste = 9506131
# Generación 22: Mejor coste = 9503689
# Generación 23: Mejor coste = 9496748
# Generación 24: Mejor coste = 9496748
# Generación 25: Mejor coste = 9479728
# Generación 26: Mejor coste = 9479087
# Generación 27: Mejor coste = 9479087
# Generación 28: Mejor coste = 9474459
# Generación 29: Mejor coste = 9457536
# Generación 30: Mejor coste = 9457536
# Generación 31: Mejor coste = 9457536
# Generación 32: Mejor coste = 9457536
# Generación 33: Mejor coste = 9457536
# Generación 34: Mejor coste = 9457536
# Generación 35: Mejor coste = 9457536
# Generación 36: Mejor coste = 9451866
# Generación 37: Mejor coste = 9451866
# Generación 38: Mejor coste = 9451866
# Generación 39: Mejor coste = 9451866
# Generación 40: Mejor coste = 9451866
# Generación 41: Mejor coste = 9451866
# Generación 42: Mejor coste = 9451866
# Generación 43: Mejor coste = 9451866
# Generación 44: Mejor coste = 9451866
# Generación 45: Mejor coste = 9451866
# Generación 46: Mejor coste = 9451866
# Generación 47: Mejor coste = 9451866
# Generación 48: Mejor coste = 9450343
# Generación 49: Mejor coste = 9450343
# Generación 50: Mejor coste = 9450343
# Generación 51: Mejor coste = 9450343
# Generación 52: Mejor coste = 9450343
# Generación 53: Mejor coste = 9450343
# Generación 54: Mejor coste = 9448341
# Generación 55: Mejor coste = 9448341
# Generación 56: Mejor coste = 9448341
# Generación 57: Mejor coste = 9448341
# Generación 58: Mejor coste = 9448341
# Generación 59: Mejor coste = 9448341
# Generación 60: Mejor coste = 9448341
# Generación 61: Mejor coste = 9448341
# Generación 62: Mejor coste = 9448341
# Generación 63: Mejor coste = 9445032
# Generación 64: Mejor coste = 9439571
# Generación 65: Mejor coste = 9439571
# Generación 66: Mejor coste = 9439571
# Generación 67: Mejor coste = 9439571
# Generación 68: Mejor coste = 9439571
# Generación 69: Mejor coste = 9439571
# Generación 70: Mejor coste = 9439571
# Generación 71: Mejor coste = 9438588
# Generación 72: Mejor coste = 9438588
# Generación 73: Mejor coste = 9438018
# Generación 74: Mejor coste = 9438018
# Generación 75: Mejor coste = 9435938
# Generación 76: Mejor coste = 9435938
# Generación 77: Mejor coste = 9435938
# Generación 78: Mejor coste = 9432370
# Generación 79: Mejor coste = 9431442
# Generación 80: Mejor coste = 9431442
# Generación 81: Mejor coste = 9430239
# Generación 82: Mejor coste = 9430239
# Generación 83: Mejor coste = 9430239
# Generación 84: Mejor coste = 9430095
# Generación 85: Mejor coste = 9428731
# Generación 86: Mejor coste = 9428731
# Generación 87: Mejor coste = 9428731
# Generación 88: Mejor coste = 9428731
# Generación 89: Mejor coste = 9428731
# Generación 90: Mejor coste = 9428731
# Generación 91: Mejor coste = 9419424
# Generación 92: Mejor coste = 9419424
# Generación 93: Mejor coste = 9419424
# Generación 94: Mejor coste = 9411180
# Generación 95: Mejor coste = 9411180
# Generación 96: Mejor coste = 9411180
# Generación 97: Mejor coste = 9411180
# Generación 98: Mejor coste = 9411180
# Generación 99: Mejor coste = 9411180
# Generación 100: Mejor coste = 9411180
# Generación 101: Mejor coste = 9411180
# Generación 102: Mejor coste = 9411180
# Generación 103: Mejor coste = 9411180
# Generación 104: Mejor coste = 9411180
# Generación 105: Mejor coste = 9411180
# Generación 106: Mejor coste = 9411180
# Generación 107: Mejor coste = 9411180
# Generación 108: Mejor coste = 9411180
# Generación 109: Mejor coste = 9411180
# Terminando en la generación 109 por falta de mejora.
# Procesando archivo: lipa90b.dat
# Generación 1: Mejor coste = 16111983
# Generación 2: Mejor coste = 16076944
# Generación 3: Mejor coste = 16086380
# Generación 4: Mejor coste = 16084328
# Generación 5: Mejor coste = 16097377
# Generación 6: Mejor coste = 16088322
# Generación 7: Mejor coste = 16070990
# Generación 8: Mejor coste = 16070990
# Generación 9: Mejor coste = 16070990
# Generación 10: Mejor coste = 16031294
# Generación 11: Mejor coste = 15979219
# Generación 12: Mejor coste = 16064394
# Generación 13: Mejor coste = 16064394
# Generación 14: Mejor coste = 16032773
# Generación 15: Mejor coste = 16056149
# Generación 16: Mejor coste = 16056149
# Generación 17: Mejor coste = 16017501
# Generación 18: Mejor coste = 16031101
# Generación 19: Mejor coste = 16062519
# Generación 20: Mejor coste = 16064860
# Generación 21: Mejor coste = 16051865
# Generación 22: Mejor coste = 16072465
# Generación 23: Mejor coste = 16001789
# Generación 24: Mejor coste = 16037914
# Generación 25: Mejor coste = 16003617
# Generación 26: Mejor coste = 16008469
# Terminando en la generación 26 por falta de mejora.
# Generación 1: Mejor coste = 16106384
# Generación 2: Mejor coste = 15837572
# Generación 3: Mejor coste = 15664148
# Generación 4: Mejor coste = 15583219
# Generación 5: Mejor coste = 15576277
# Generación 6: Mejor coste = 15540589
# Generación 7: Mejor coste = 15527194
# Generación 8: Mejor coste = 15500762
# Generación 9: Mejor coste = 15500762
# Generación 10: Mejor coste = 15484079
# Generación 11: Mejor coste = 15476812
# Generación 12: Mejor coste = 15454607
# Generación 13: Mejor coste = 15452675
# Generación 14: Mejor coste = 15441224
# Generación 15: Mejor coste = 15427409
# Generación 16: Mejor coste = 15413434
# Generación 17: Mejor coste = 15411059
# Generación 18: Mejor coste = 15397827
# Generación 19: Mejor coste = 15386318
# Generación 20: Mejor coste = 15376131
# Generación 21: Mejor coste = 15376131
# Generación 22: Mejor coste = 15376131
# Generación 23: Mejor coste = 15376131
# Generación 24: Mejor coste = 15376131
# Generación 25: Mejor coste = 15376131
# Generación 26: Mejor coste = 15373783
# Generación 27: Mejor coste = 15373783
# Generación 28: Mejor coste = 15368377
# Generación 29: Mejor coste = 15365148
# Generación 30: Mejor coste = 15355067
# Generación 31: Mejor coste = 15349416
# Generación 32: Mejor coste = 15342530
# Generación 33: Mejor coste = 15342530
# Generación 34: Mejor coste = 15337814
# Generación 35: Mejor coste = 15337814
# Generación 36: Mejor coste = 15329471
# Generación 37: Mejor coste = 15323278
# Generación 38: Mejor coste = 15323278
# Generación 39: Mejor coste = 15311976
# Generación 40: Mejor coste = 15311976
# Generación 41: Mejor coste = 15309954
# Generación 42: Mejor coste = 15309954
# Generación 43: Mejor coste = 15309954
# Generación 44: Mejor coste = 15304629
# Generación 45: Mejor coste = 15303583
# Generación 46: Mejor coste = 15299994
# Generación 47: Mejor coste = 15294570
# Generación 48: Mejor coste = 15294570
# Generación 49: Mejor coste = 15290083
# Generación 50: Mejor coste = 15290083
# Generación 51: Mejor coste = 15290083
# Generación 52: Mejor coste = 15285437
# Generación 53: Mejor coste = 15281519
# Generación 54: Mejor coste = 15277982
# Generación 55: Mejor coste = 15276501
# Generación 56: Mejor coste = 15276501
# Generación 57: Mejor coste = 15267890
# Generación 58: Mejor coste = 15264843
# Generación 59: Mejor coste = 15263441
# Generación 60: Mejor coste = 15261537
# Generación 61: Mejor coste = 15261537
# Generación 62: Mejor coste = 15261537
# Generación 63: Mejor coste = 15261537
# Generación 64: Mejor coste = 15261537
# Generación 65: Mejor coste = 15261537
# Generación 66: Mejor coste = 15261537
# Generación 67: Mejor coste = 15261537
# Generación 68: Mejor coste = 15261537
# Generación 69: Mejor coste = 15261537
# Generación 70: Mejor coste = 15261537
# Generación 71: Mejor coste = 15257063
# Generación 72: Mejor coste = 15257063
# Generación 73: Mejor coste = 15245261
# Generación 74: Mejor coste = 15245261
# Generación 75: Mejor coste = 15245261
# Generación 76: Mejor coste = 15245261
# Generación 77: Mejor coste = 15245261
# Generación 78: Mejor coste = 15245261
# Generación 79: Mejor coste = 15245261
# Generación 80: Mejor coste = 15245261
# Generación 81: Mejor coste = 15245261
# Generación 82: Mejor coste = 15245261
# Generación 83: Mejor coste = 15242271
# Generación 84: Mejor coste = 15242271
# Generación 85: Mejor coste = 15242271
# Generación 86: Mejor coste = 15242271
# Generación 87: Mejor coste = 15242271
# Generación 88: Mejor coste = 15242271
# Generación 89: Mejor coste = 15242271
# Generación 90: Mejor coste = 15242271
# Generación 91: Mejor coste = 15242271
# Generación 92: Mejor coste = 15242271
# Generación 93: Mejor coste = 15242271
# Generación 94: Mejor coste = 15242271
# Generación 95: Mejor coste = 15242271
# Generación 96: Mejor coste = 15242271
# Generación 97: Mejor coste = 15242271
# Generación 98: Mejor coste = 15242271
# Terminando en la generación 98 por falta de mejora.
# Generación 1: Mejor coste = 15821821
# Generación 2: Mejor coste = 15703529
# Generación 3: Mejor coste = 15637417
# Generación 4: Mejor coste = 15590865
# Generación 5: Mejor coste = 15579862
# Generación 6: Mejor coste = 15545760
# Generación 7: Mejor coste = 15509035
# Generación 8: Mejor coste = 15495488
# Generación 9: Mejor coste = 15471632
# Generación 10: Mejor coste = 15471632
# Generación 11: Mejor coste = 15456217
# Generación 12: Mejor coste = 15440036
# Generación 13: Mejor coste = 15430242
# Generación 14: Mejor coste = 15405613
# Generación 15: Mejor coste = 15385418
# Generación 16: Mejor coste = 15374824
# Generación 17: Mejor coste = 15372367
# Generación 18: Mejor coste = 15372367
# Generación 19: Mejor coste = 15372367
# Generación 20: Mejor coste = 15368351
# Generación 21: Mejor coste = 15368351
# Generación 22: Mejor coste = 15337413
# Generación 23: Mejor coste = 15329637
# Generación 24: Mejor coste = 15329637
# Generación 25: Mejor coste = 15329215
# Generación 26: Mejor coste = 15329215
# Generación 27: Mejor coste = 15329215
# Generación 28: Mejor coste = 15320737
# Generación 29: Mejor coste = 15312129
# Generación 30: Mejor coste = 15312129
# Generación 31: Mejor coste = 15305272
# Generación 32: Mejor coste = 15301284
# Generación 33: Mejor coste = 15292414
# Generación 34: Mejor coste = 15292414
# Generación 35: Mejor coste = 15292414
# Generación 36: Mejor coste = 15292414
# Generación 37: Mejor coste = 15291584
# Generación 38: Mejor coste = 15276214
# Generación 39: Mejor coste = 15272718
# Generación 40: Mejor coste = 15272718
# Generación 41: Mejor coste = 15272302
# Generación 42: Mejor coste = 15268043
# Generación 43: Mejor coste = 15260497
# Generación 44: Mejor coste = 15260497
# Generación 45: Mejor coste = 15251056
# Generación 46: Mejor coste = 15251056
# Generación 47: Mejor coste = 15238889
# Generación 48: Mejor coste = 15231782
# Generación 49: Mejor coste = 15231782
# Generación 50: Mejor coste = 15231782
# Generación 51: Mejor coste = 15231782
# Generación 52: Mejor coste = 15231782
# Generación 53: Mejor coste = 15231782
# Generación 54: Mejor coste = 15231782
# Generación 55: Mejor coste = 15231782
# Generación 56: Mejor coste = 15231782
# Generación 57: Mejor coste = 15220766
# Generación 58: Mejor coste = 15220766
# Generación 59: Mejor coste = 15220766
# Generación 60: Mejor coste = 15220766
# Generación 61: Mejor coste = 15220766
# Generación 62: Mejor coste = 15220766
# Generación 63: Mejor coste = 15220766
# Generación 64: Mejor coste = 15220766
# Generación 65: Mejor coste = 15220766
# Generación 66: Mejor coste = 15220766
# Generación 67: Mejor coste = 15220766
# Generación 68: Mejor coste = 15220766
# Generación 69: Mejor coste = 15220766
# Generación 70: Mejor coste = 15220766
# Generación 71: Mejor coste = 15211208
# Generación 72: Mejor coste = 15210977
# Generación 73: Mejor coste = 15210977
# Generación 74: Mejor coste = 15210977
# Generación 75: Mejor coste = 15210977
# Generación 76: Mejor coste = 15210896
# Generación 77: Mejor coste = 15210896
# Generación 78: Mejor coste = 15210255
# Generación 79: Mejor coste = 15210255
# Generación 80: Mejor coste = 15209146
# Generación 81: Mejor coste = 15203902
# Generación 82: Mejor coste = 15203902
# Generación 83: Mejor coste = 15203902
# Generación 84: Mejor coste = 15203902
# Generación 85: Mejor coste = 15203902
# Generación 86: Mejor coste = 15203902
# Generación 87: Mejor coste = 15203902
# Generación 88: Mejor coste = 15196371
# Generación 89: Mejor coste = 15196371
# Generación 90: Mejor coste = 15196371
# Generación 91: Mejor coste = 15196371
# Generación 92: Mejor coste = 15196371
# Generación 93: Mejor coste = 15196371
# Generación 94: Mejor coste = 15196371
# Generación 95: Mejor coste = 15196371
# Generación 96: Mejor coste = 15196371
# Generación 97: Mejor coste = 15196371
# Generación 98: Mejor coste = 15196371
# Generación 99: Mejor coste = 15196371
# Generación 100: Mejor coste = 15196371
# Generación 101: Mejor coste = 15196371
# Generación 102: Mejor coste = 15196371
# Generación 103: Mejor coste = 15196371
# Terminando en la generación 103 por falta de mejora.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-a91b52264254> in <cell line: 0>()
#       7
#       8 # Visualizar todos los resultados juntos
# ----> 9 visualize_results(results)
#
# NameError: name 'visualize_results' is not defined

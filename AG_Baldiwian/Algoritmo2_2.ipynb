# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
import numpy as np
import random
from multiprocessing import Pool

# Lectura de datos
data = np.loadtxt('/content/drive/MyDrive/MÁSTER/IC/P2/data/tai256c.dat', skiprows=1)
flow = np.int32(data[:256])
distances = np.int32(data[256:])

seed = 2024
random.seed(seed)
np.random.seed(seed)

# %%
# Generación de la población inicial
def generate_population(population_size, n=256):
    return np.array([np.random.permutation(np.arange(n)) for _ in range(population_size)])

def fitness_pop(population, flow, distances):
    return np.sum(flow[np.newaxis, :, :] * distances[population[:, :, np.newaxis], population[:, np.newaxis, :]],
                  axis=(1, 2))

# %%
# Función de selección por torneo
def tournament_selection(population, fitness_vals, tournament_size=5):
    selected = []
    for _ in range(len(population)):
        tournament = random.sample(range(len(population)), tournament_size)
        winner = tournament[np.argmin([fitness_vals[i] for i in tournament])]
        selected.append(population[winner])
    return np.array(selected)

# %%
# Operador de cruce por orden (OX)
def ox_crossover(parent1, parent2):
    size = len(parent1)
    start, end = sorted(np.random.choice(range(size), 2, replace=False))
    child = -np.ones(size, dtype=int)
    child[start:end+1] = parent1[start:end+1]
    idx = 0
    for i in range(size):
        if child[i] == -1:
            while parent2[idx] in child:
                idx += 1
            child[i] = parent2[idx]
    return child

# %%
# Mutación por intercambio (Swap)
def swap_mutation(individual, mutation_prob=0.05):
    if random.random() < mutation_prob:
        i, j = np.random.choice(range(len(individual)), 2, replace=False)
        individual[i], individual[j] = individual[j], individual[i]
    return individual

# %%
def hill_climbing_optimized(individual, flow, distances, max_iterations=100):
    current = individual.copy()
    current_fitness = fitness_pop(np.array([current]), flow, distances)[0]
    for _ in range(max_iterations):
        i, j = np.random.choice(range(len(current)), 2, replace=False)
        neighbor = current.copy()
        neighbor[i], neighbor[j] = neighbor[j], neighbor[i]
        # Cálculo delta:
        delta_fitness = calculate_fitness_delta(current, i, j, flow, distances)
        if current_fitness + delta_fitness < current_fitness:
            current = neighbor
            current_fitness += delta_fitness
    return current, current_fitness

def calculate_fitness_delta(individual, i, j, flow, distances):
    n = len(individual)
    delta = 0
    for k in range(n):
        if k != i and k != j:
            delta += (flow[i, k] - flow[j, k]) * (distances[individual[j], individual[k]] - distances[individual[i], individual[k]])
            delta += (flow[k, i] - flow[k, j]) * (distances[individual[k], individual[j]] - distances[individual[k], individual[i]])
    return delta

# %%
# Algoritmo genético con variante baldwiniana
def baldwinian_genetic_algorithm(flow, distances, population_size=1000, generations=500, crossover_prob=0.9, mutation_prob=0.05, tournament_size=5):
    population = generate_population(population_size)
    pool = Pool()  # Crear un pool de procesos para paralelizar

    best_fitness = float('inf')
    generations_without_improvement = 0
    max_generations_without_improvement = 25

    for generation in range(generations):
        # Aplicar hill climbing a los mejores individuos
        top_k = int(0.1 * population_size)
        fitness_vals = fitness_pop(population, flow, distances)
        top_individuals = population[np.argsort(fitness_vals)[:top_k]]
        results = pool.starmap(hill_climbing_optimized, [(ind, flow, distances) for ind in top_individuals])
        hill_climbed_population = np.array([res[0] for res in results])
        hill_climbed_fitness = np.array([res[1] for res in results])

        # Combinar con el resto de la población
        remaining_population = population[top_k:]
        fitness_vals[top_k:] = fitness_pop(remaining_population, flow, distances)

        # Selección
        population = tournament_selection(np.vstack((hill_climbed_population, remaining_population)), fitness_vals, tournament_size)

        # Cruzamiento
        offspring = []
        for i in range(0, population_size, 2):
            if random.random() < crossover_prob:
                child1 = ox_crossover(population[i], population[i+1])
                child2 = ox_crossover(population[i+1], population[i])
            else:
                child1, child2 = population[i], population[i+1]
            offspring.append(child1)
            offspring.append(child2)
        population = np.array([swap_mutation(ind, mutation_prob) for ind in offspring])

        # Imprimir mejor costo
        best_idx = np.argmin(fitness_vals)
        print(f"Generación {generation+1}: Mejor coste = {fitness_vals[best_idx]}")

        #Finalizar si no hay mejora
        if generations_without_improvement >= max_generations_without_improvement:
           print(f"Terminando en la generación {generation+1} debido a la falta de mejora.")
           break

    best_idx = np.argmin(fitness_vals)
    return population[best_idx], fitness_vals[best_idx]

# %%
# Ejecución del algoritmo
best_solution_baldwin, best_cost_baldwin = baldwinian_genetic_algorithm(flow, distances)

print("\nMejor solución encontrada (Baldwiniano):", best_solution_baldwin)
print("Coste asociado a la mejor solución (Baldwiniano):", best_cost_baldwin)
# Out:
# Generación 1: Mejor coste = 49640646
# Generación 2: Mejor coste = 49213330
# Generación 3: Mejor coste = 48351654
# Generación 4: Mejor coste = 48133662
# Generación 5: Mejor coste = 47973696
# Generación 6: Mejor coste = 47797634
# Generación 7: Mejor coste = 47798554
# Generación 8: Mejor coste = 47570356
# Generación 9: Mejor coste = 47083684
# Generación 10: Mejor coste = 47327920
# Generación 11: Mejor coste = 47356492
# Generación 12: Mejor coste = 47286926
# Generación 13: Mejor coste = 46960938
# Generación 14: Mejor coste = 46960938
# Generación 15: Mejor coste = 47028606
# Generación 16: Mejor coste = 46816684
# Generación 17: Mejor coste = 46737462
# Generación 18: Mejor coste = 46668744
# Generación 19: Mejor coste = 46635982
# Generación 20: Mejor coste = 46498414
# Generación 21: Mejor coste = 46301458
# Generación 22: Mejor coste = 46301458
# Generación 23: Mejor coste = 46294526
# Generación 24: Mejor coste = 46238342
# Generación 25: Mejor coste = 46187076
# Generación 26: Mejor coste = 46098244
# Generación 27: Mejor coste = 45992464
# Generación 28: Mejor coste = 45992464
# Generación 29: Mejor coste = 45911776
# Generación 30: Mejor coste = 45822620
# Generación 31: Mejor coste = 45806802
# Generación 32: Mejor coste = 45769338
# Generación 33: Mejor coste = 45769338
# Generación 34: Mejor coste = 45704790
# Generación 35: Mejor coste = 45704790
# Generación 36: Mejor coste = 45637048
# Generación 37: Mejor coste = 45637048
# Generación 38: Mejor coste = 45637048
# Generación 39: Mejor coste = 45607574
# Generación 40: Mejor coste = 45511524
# Generación 41: Mejor coste = 45533504
# Generación 42: Mejor coste = 45463714
# Generación 43: Mejor coste = 45462486
# Generación 44: Mejor coste = 45417388
# Generación 45: Mejor coste = 45417388
# Generación 46: Mejor coste = 45370022
# Generación 47: Mejor coste = 45365766
# Generación 48: Mejor coste = 45350276
# Generación 49: Mejor coste = 45350276
# Generación 50: Mejor coste = 45308474
# Generación 51: Mejor coste = 45302542
# Generación 52: Mejor coste = 45302542
# Generación 53: Mejor coste = 45240570
# Generación 54: Mejor coste = 45238366
# Generación 55: Mejor coste = 45216436
# Generación 56: Mejor coste = 45203880
# Generación 57: Mejor coste = 45157342
# Generación 58: Mejor coste = 45157342
# Generación 59: Mejor coste = 45147272
# Generación 60: Mejor coste = 45118210
# Generación 61: Mejor coste = 45118210
# Generación 62: Mejor coste = 45118210
# Generación 63: Mejor coste = 45096554
# Generación 64: Mejor coste = 45096554
# Generación 65: Mejor coste = 45077508
# Generación 66: Mejor coste = 45077508
# Generación 67: Mejor coste = 45077508
# Generación 68: Mejor coste = 45068622
# Generación 69: Mejor coste = 45068622
# Generación 70: Mejor coste = 45068622
# Generación 71: Mejor coste = 45062036
# Generación 72: Mejor coste = 45062036
# Generación 73: Mejor coste = 45050198
# Generación 74: Mejor coste = 45045580
# Generación 75: Mejor coste = 45045580
# Generación 76: Mejor coste = 45029784
# Generación 77: Mejor coste = 45029784
# Generación 78: Mejor coste = 45024776
# Generación 79: Mejor coste = 45021084
# Generación 80: Mejor coste = 45021084
# Generación 81: Mejor coste = 45017048
# Generación 82: Mejor coste = 45017048
# Generación 83: Mejor coste = 45008298
# Generación 84: Mejor coste = 45008298
# Generación 85: Mejor coste = 45005842
# Generación 86: Mejor coste = 45004322
# Generación 87: Mejor coste = 44969848
# Generación 88: Mejor coste = 44969848
# Generación 89: Mejor coste = 44969848
# Generación 90: Mejor coste = 44967712
# Generación 91: Mejor coste = 44966282
# Generación 92: Mejor coste = 44964574
# Generación 93: Mejor coste = 44964574
# Generación 94: Mejor coste = 44964574
# Generación 95: Mejor coste = 44961828
# Generación 96: Mejor coste = 44959158
# Generación 97: Mejor coste = 44959158
# Generación 98: Mejor coste = 44959158
# Generación 99: Mejor coste = 44956918
# Generación 100: Mejor coste = 44955608
# Generación 101: Mejor coste = 44954428
# Generación 102: Mejor coste = 44954428
# Generación 103: Mejor coste = 44954428
# Generación 104: Mejor coste = 44952966
# Generación 105: Mejor coste = 44952966
# Generación 106: Mejor coste = 44952966
# Generación 107: Mejor coste = 44952966
# Generación 108: Mejor coste = 44952966
# Generación 109: Mejor coste = 44952966
# Generación 110: Mejor coste = 44952966
# Generación 111: Mejor coste = 44952966
# Generación 112: Mejor coste = 44952966
# Generación 113: Mejor coste = 44952966
# Generación 114: Mejor coste = 44952966
# Generación 115: Mejor coste = 44952966
# Generación 116: Mejor coste = 44952966
# Generación 117: Mejor coste = 44952966
# Generación 118: Mejor coste = 44952966
# Generación 119: Mejor coste = 44952966
# Generación 120: Mejor coste = 44952966
# Generación 121: Mejor coste = 44952966
# Generación 122: Mejor coste = 44952966
# Generación 123: Mejor coste = 44952966
# Generación 124: Mejor coste = 44952966
# Generación 125: Mejor coste = 44952966
# Generación 126: Mejor coste = 44952966
# Generación 127: Mejor coste = 44952966
# Generación 128: Mejor coste = 44952966
# Generación 129: Mejor coste = 44952966
# Generación 130: Mejor coste = 44952966
# Generación 131: Mejor coste = 44952966
# Generación 132: Mejor coste = 44952966
# Generación 133: Mejor coste = 44952966
# Generación 134: Mejor coste = 44952966
# Generación 135: Mejor coste = 44952966
# Generación 136: Mejor coste = 44952966
# Generación 137: Mejor coste = 44952966
# Generación 138: Mejor coste = 44952966
# Generación 139: Mejor coste = 44952966
# Generación 140: Mejor coste = 44952966
# Generación 141: Mejor coste = 44952966
# Generación 142: Mejor coste = 44952966
# Generación 143: Mejor coste = 44952966
# Generación 144: Mejor coste = 44952966
# Generación 145: Mejor coste = 44952966
# Generación 146: Mejor coste = 44952966
# Generación 147: Mejor coste = 44952966
# Generación 148: Mejor coste = 44952966
# Generación 149: Mejor coste = 44952966
# Generación 150: Mejor coste = 44952966
# Generación 151: Mejor coste = 44952966
# Generación 152: Mejor coste = 44952966
# Generación 153: Mejor coste = 44952966
# Generación 154: Mejor coste = 44952966
# Generación 155: Mejor coste = 44952966
# Generación 156: Mejor coste = 44952966
# Generación 157: Mejor coste = 44952966
# Generación 158: Mejor coste = 44952966
# Generación 159: Mejor coste = 44952966
# Generación 160: Mejor coste = 44952966
# Generación 161: Mejor coste = 44952966
# Generación 162: Mejor coste = 44952966
# Generación 163: Mejor coste = 44952966
# Generación 164: Mejor coste = 44952966
# Generación 165: Mejor coste = 44952966
# Generación 166: Mejor coste = 44952966
# Generación 167: Mejor coste = 44952966
# Generación 168: Mejor coste = 44952966
# Generación 169: Mejor coste = 44952966
# Generación 170: Mejor coste = 44952966
# Generación 171: Mejor coste = 44952966
# Generación 172: Mejor coste = 44952966
# Generación 173: Mejor coste = 44952966
# Generación 174: Mejor coste = 44952966
# Generación 175: Mejor coste = 44952966
# Generación 176: Mejor coste = 44952966
# Generación 177: Mejor coste = 44952966
# Generación 178: Mejor coste = 44952966
# Generación 179: Mejor coste = 44952966
# Generación 180: Mejor coste = 44952966
# Generación 181: Mejor coste = 44952966
# Generación 182: Mejor coste = 44952966
# Generación 183: Mejor coste = 44952966
# Generación 184: Mejor coste = 44952966
# Generación 185: Mejor coste = 44952966
# Generación 186: Mejor coste = 44952966
# Generación 187: Mejor coste = 44952966
# Generación 188: Mejor coste = 44952966
# Generación 189: Mejor coste = 44952966
# Generación 190: Mejor coste = 44952966
# Generación 191: Mejor coste = 44952966
# Generación 192: Mejor coste = 44952966
# Generación 193: Mejor coste = 44952966
# Generación 194: Mejor coste = 44952966
# Generación 195: Mejor coste = 44952966
# Generación 196: Mejor coste = 44952966
# Generación 197: Mejor coste = 44952966
# Generación 198: Mejor coste = 44952966
# Generación 199: Mejor coste = 44952966
# Generación 200: Mejor coste = 44952966
# Generación 201: Mejor coste = 44952966
# Generación 202: Mejor coste = 44952966
# Generación 203: Mejor coste = 44952966
# Generación 204: Mejor coste = 44952966
# Generación 205: Mejor coste = 44952966
# Generación 206: Mejor coste = 44952966
# Generación 207: Mejor coste = 44952966
# Generación 208: Mejor coste = 44952966
# Generación 209: Mejor coste = 44952966
# Generación 210: Mejor coste = 44952966
# Generación 211: Mejor coste = 44952966
# Generación 212: Mejor coste = 44952966
# Generación 213: Mejor coste = 44952966
# Generación 214: Mejor coste = 44952966
# Generación 215: Mejor coste = 44952966
# Generación 216: Mejor coste = 44952966
# Generación 217: Mejor coste = 44952966
# Generación 218: Mejor coste = 44952966
# Generación 219: Mejor coste = 44952966
# Generación 220: Mejor coste = 44952966
# Generación 221: Mejor coste = 44952966
# Generación 222: Mejor coste = 44952966
# Generación 223: Mejor coste = 44952966
# Generación 224: Mejor coste = 44952966
# Generación 225: Mejor coste = 44952966
# Generación 226: Mejor coste = 44952966
# Generación 227: Mejor coste = 44952966
# Generación 228: Mejor coste = 44952966
# Generación 229: Mejor coste = 44952966
# Generación 230: Mejor coste = 44952966
# Generación 231: Mejor coste = 44952966
# Generación 232: Mejor coste = 44952966
# Generación 233: Mejor coste = 44952966
# Generación 234: Mejor coste = 44952966
# Generación 235: Mejor coste = 44952966
# Generación 236: Mejor coste = 44952966
# Generación 237: Mejor coste = 44952966
# Generación 238: Mejor coste = 44952966
# Generación 239: Mejor coste = 44952966
# Generación 240: Mejor coste = 44952966
# Generación 241: Mejor coste = 44952966
# Generación 242: Mejor coste = 44952966
# Generación 243: Mejor coste = 44952966
# Generación 244: Mejor coste = 44952966
# Generación 245: Mejor coste = 44952966
# Generación 246: Mejor coste = 44952966
# Generación 247: Mejor coste = 44952966
# Generación 248: Mejor coste = 44952966
# Generación 249: Mejor coste = 44952966
# Generación 250: Mejor coste = 44952966
# Generación 251: Mejor coste = 44952966
# Generación 252: Mejor coste = 44952966
# Generación 253: Mejor coste = 44952966
# Generación 254: Mejor coste = 44952966
# Generación 255: Mejor coste = 44952966
# Generación 256: Mejor coste = 44952966
# Generación 257: Mejor coste = 44952966
# Generación 258: Mejor coste = 44952966
# Generación 259: Mejor coste = 44952966
# Generación 260: Mejor coste = 44952966
# Generación 261: Mejor coste = 44952966
# Generación 262: Mejor coste = 44952966
# Generación 263: Mejor coste = 44952966
# Generación 264: Mejor coste = 44952966
# Generación 265: Mejor coste = 44952966
# Generación 266: Mejor coste = 44952966
# Generación 267: Mejor coste = 44952966
# Generación 268: Mejor coste = 44952966
# Generación 269: Mejor coste = 44952966
# Generación 270: Mejor coste = 44952966
# Generación 271: Mejor coste = 44952966
# Generación 272: Mejor coste = 44952966
# Generación 273: Mejor coste = 44952966
# Generación 274: Mejor coste = 44952966
# Generación 275: Mejor coste = 44952966
# Generación 276: Mejor coste = 44952966
# Generación 277: Mejor coste = 44952966
# Generación 278: Mejor coste = 44952966
# Generación 279: Mejor coste = 44952966
# Generación 280: Mejor coste = 44952966
# Generación 281: Mejor coste = 44952966
# Generación 282: Mejor coste = 44952966
# Generación 283: Mejor coste = 44952966
# Generación 284: Mejor coste = 44952966
# Generación 285: Mejor coste = 44952966
# Generación 286: Mejor coste = 44952966
# Generación 287: Mejor coste = 44952966
# Generación 288: Mejor coste = 44952966
# Generación 289: Mejor coste = 44952966
# Generación 290: Mejor coste = 44952966
# Generación 291: Mejor coste = 44952966
# Generación 292: Mejor coste = 44952966
# Generación 293: Mejor coste = 44952966
# Generación 294: Mejor coste = 44952966
# Generación 295: Mejor coste = 44952966
# Generación 296: Mejor coste = 44952966
# Generación 297: Mejor coste = 44952966
# Generación 298: Mejor coste = 44952966
# Generación 299: Mejor coste = 44952966
# Generación 300: Mejor coste = 44952966
# Generación 301: Mejor coste = 44952966
# Generación 302: Mejor coste = 44952966
# Generación 303: Mejor coste = 44952966
# Generación 304: Mejor coste = 44952966
# Generación 305: Mejor coste = 44952966
# Generación 306: Mejor coste = 44952966
# Generación 307: Mejor coste = 44952966
# Generación 308: Mejor coste = 44952966
# Generación 309: Mejor coste = 44952966
# Generación 310: Mejor coste = 44952966
# Generación 311: Mejor coste = 44952966
# Generación 312: Mejor coste = 44952966
# Generación 313: Mejor coste = 44952966
# Generación 314: Mejor coste = 44952966
# Generación 315: Mejor coste = 44952966
# Generación 316: Mejor coste = 44952966
# Generación 317: Mejor coste = 44952966
# Generación 318: Mejor coste = 44952966
# Generación 319: Mejor coste = 44952966
# Generación 320: Mejor coste = 44952966
# Generación 321: Mejor coste = 44952966
# Generación 322: Mejor coste = 44952966
# Generación 323: Mejor coste = 44952966
# Generación 324: Mejor coste = 44952966
# Generación 325: Mejor coste = 44952966
# Generación 326: Mejor coste = 44952966
# Generación 327: Mejor coste = 44952966
# Generación 328: Mejor coste = 44952966
# Generación 329: Mejor coste = 44952966
# Generación 330: Mejor coste = 44952966
# Generación 331: Mejor coste = 44952966
# Generación 332: Mejor coste = 44952966
# Generación 333: Mejor coste = 44952966
# Generación 334: Mejor coste = 44952966
# Generación 335: Mejor coste = 44952966
# Generación 336: Mejor coste = 44952966
# Generación 337: Mejor coste = 44952966
# Generación 338: Mejor coste = 44952966
# Generación 339: Mejor coste = 44952966
# Generación 340: Mejor coste = 44952966
# Generación 341: Mejor coste = 44952966
# Generación 342: Mejor coste = 44952966
# Generación 343: Mejor coste = 44952966
# Generación 344: Mejor coste = 44952966
# Generación 345: Mejor coste = 44952966
# Generación 346: Mejor coste = 44952966
# Generación 347: Mejor coste = 44952966
# Generación 348: Mejor coste = 44952966
# Generación 349: Mejor coste = 44952966
# Generación 350: Mejor coste = 44952966
# Generación 351: Mejor coste = 44952966
# Generación 352: Mejor coste = 44952966
# Generación 353: Mejor coste = 44952966
# Generación 354: Mejor coste = 44952966
# Generación 355: Mejor coste = 44952966
# Generación 356: Mejor coste = 44952966
# Generación 357: Mejor coste = 44952966
# Generación 358: Mejor coste = 44952966
# Generación 359: Mejor coste = 44952966
# Generación 360: Mejor coste = 44952966
# Generación 361: Mejor coste = 44952966
# Generación 362: Mejor coste = 44952966
# Generación 363: Mejor coste = 44952966
# Generación 364: Mejor coste = 44952966
# Generación 365: Mejor coste = 44952966
# Generación 366: Mejor coste = 44952966
# Generación 367: Mejor coste = 44952966
# Generación 368: Mejor coste = 44952966
# Generación 369: Mejor coste = 44952966
# Generación 370: Mejor coste = 44952966
# Generación 371: Mejor coste = 44952966
# Generación 372: Mejor coste = 44952966
# Generación 373: Mejor coste = 44952966
# Generación 374: Mejor coste = 44952966
# Generación 375: Mejor coste = 44952966
# Generación 376: Mejor coste = 44952966
# Generación 377: Mejor coste = 44952966
# Generación 378: Mejor coste = 44952966
# Generación 379: Mejor coste = 44952966
# Generación 380: Mejor coste = 44952966
# Generación 381: Mejor coste = 44952966
# Generación 382: Mejor coste = 44952966
# Generación 383: Mejor coste = 44952966
# Generación 384: Mejor coste = 44952966
# Generación 385: Mejor coste = 44952966
# Generación 386: Mejor coste = 44952966
# Generación 387: Mejor coste = 44952966
# Generación 388: Mejor coste = 44952966
# Generación 389: Mejor coste = 44952966
# Generación 390: Mejor coste = 44952966
# Generación 391: Mejor coste = 44952966
# Generación 392: Mejor coste = 44952966
# Generación 393: Mejor coste = 44952966
# Generación 394: Mejor coste = 44952966
# Generación 395: Mejor coste = 44952966
# Generación 396: Mejor coste = 44952966
# Generación 397: Mejor coste = 44952966
# Generación 398: Mejor coste = 44952966
# Generación 399: Mejor coste = 44952966
# Generación 400: Mejor coste = 44952966
# Generación 401: Mejor coste = 44952966
# Generación 402: Mejor coste = 44952966
# Generación 403: Mejor coste = 44952966
# Generación 404: Mejor coste = 44952966
# Generación 405: Mejor coste = 44952966
# Generación 406: Mejor coste = 44952966
# Generación 407: Mejor coste = 44952966
# Generación 408: Mejor coste = 44952966
# Generación 409: Mejor coste = 44952966
# Generación 410: Mejor coste = 44952966
# Generación 411: Mejor coste = 44952966
# Generación 412: Mejor coste = 44952966
# Generación 413: Mejor coste = 44952966
# Generación 414: Mejor coste = 44952966
# Generación 415: Mejor coste = 44952966
# Generación 416: Mejor coste = 44952966
# Generación 417: Mejor coste = 44952966
# Generación 418: Mejor coste = 44952966
# Generación 419: Mejor coste = 44952966
# Generación 420: Mejor coste = 44952966
# Generación 421: Mejor coste = 44952966
# Generación 422: Mejor coste = 44952966
# Generación 423: Mejor coste = 44952966
# Generación 424: Mejor coste = 44952966
# Generación 425: Mejor coste = 44952966
# Generación 426: Mejor coste = 44952966
# Generación 427: Mejor coste = 44952966
# Generación 428: Mejor coste = 44952966
# Generación 429: Mejor coste = 44952966
# Generación 430: Mejor coste = 44952966
# Generación 431: Mejor coste = 44952966
# Generación 432: Mejor coste = 44952966
# Generación 433: Mejor coste = 44952966
# Generación 434: Mejor coste = 44952966
# Generación 435: Mejor coste = 44952966
# Generación 436: Mejor coste = 44952966
# Generación 437: Mejor coste = 44952966
# Generación 438: Mejor coste = 44952966
# Generación 439: Mejor coste = 44952966
# Generación 440: Mejor coste = 44952966
# Generación 441: Mejor coste = 44952966
# Generación 442: Mejor coste = 44952966
# Generación 443: Mejor coste = 44952966
# Generación 444: Mejor coste = 44952966
# Generación 445: Mejor coste = 44952966
# Generación 446: Mejor coste = 44952966
# Generación 447: Mejor coste = 44952966
# Generación 448: Mejor coste = 44952966
# Generación 449: Mejor coste = 44952966
# Generación 450: Mejor coste = 44952966
# Generación 451: Mejor coste = 44952966
# Generación 452: Mejor coste = 44952966
# Generación 453: Mejor coste = 44952966
# Generación 454: Mejor coste = 44952966
# Generación 455: Mejor coste = 44952966
# Generación 456: Mejor coste = 44952966
# Generación 457: Mejor coste = 44952966
# Generación 458: Mejor coste = 44952966
# Generación 459: Mejor coste = 44952966
# Generación 460: Mejor coste = 44952966
# Generación 461: Mejor coste = 44952966
# Generación 462: Mejor coste = 44952966
# Generación 463: Mejor coste = 44952966
# Generación 464: Mejor coste = 44952966
# Generación 465: Mejor coste = 44952966
# Generación 466: Mejor coste = 44952966
# Generación 467: Mejor coste = 44952966
# Generación 468: Mejor coste = 44952966
# Generación 469: Mejor coste = 44952966
# Generación 470: Mejor coste = 44952966
# Generación 471: Mejor coste = 44952966
# Generación 472: Mejor coste = 44952966
# Generación 473: Mejor coste = 44952966
# Generación 474: Mejor coste = 44952966
# Generación 475: Mejor coste = 44952966
# Generación 476: Mejor coste = 44952966
# Generación 477: Mejor coste = 44952966
# Generación 478: Mejor coste = 44952966
# Generación 479: Mejor coste = 44952966
# Generación 480: Mejor coste = 44952966
# Generación 481: Mejor coste = 44952966
# Generación 482: Mejor coste = 44952966
# Generación 483: Mejor coste = 44952966
# Generación 484: Mejor coste = 44952966
# Generación 485: Mejor coste = 44952966
# Generación 486: Mejor coste = 44952966
# Generación 487: Mejor coste = 44952966
# Generación 488: Mejor coste = 44952966
# Generación 489: Mejor coste = 44952966
# Generación 490: Mejor coste = 44952966
# Generación 491: Mejor coste = 44952966
# Generación 492: Mejor coste = 44952966
# Generación 493: Mejor coste = 44952966
# Generación 494: Mejor coste = 44952966
# Generación 495: Mejor coste = 44952966
# Generación 496: Mejor coste = 44952966
# Generación 497: Mejor coste = 44952966
# Generación 498: Mejor coste = 44952966
# Generación 499: Mejor coste = 44952966
# Generación 500: Mejor coste = 44952966
#
# Mejor solución encontrada (Baldwiniano): [173 171 225 242 193 156 110  20 207 178 196 201  44 203 159  96  81  76
#  251  10  87 236 249 153 190  50 213 145 125  42 142 246 115 221   5  69
#  150 147 135  29 216 244 231  27 186 183  62  54  18  93  52  48 128 208
#  198 227   0  84  22 181  56   7 160 188 253  59  73 164 105  24 107 130
#  120  33  47  98 234  39 168 255  67 132 117 139 102 122 238  90  95  35
#  210  14 177 149 180  60  74   1 127  91 228   2 254 217 241 101  86 191
#  245 113 218 224  80  75  38  45 133 175 194 167 195 184 229 112 151 197
#  247 202   3  58  89  15  94  88 106 100  53  55 222  25  34  51 121 199
#  108 146  92  17 126 166  40  65 111  82 187 119  31  41 250 233 204  97
#   36  13 215 226 152  63  26 109  28 169 235  32 140  83  71 116  16 157
#  131 158 200  66 118 252  37  49 170   9 214 176  12  72 209 230   4 123
#  220  85  57 165  23 179  99 138  78 212 104 124   8  21 237  79  77 172
#    6 192 223 240 219 185 174 163 114 148 239 205  61 189 182 206 129  43
#  161  46 134 137 155  70  30  19 248  64 136 243 103 141 162  11 144 211
#  232  68 143 154]
# Coste asociado a la mejor solución (Baldwiniano): 44952966

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
import numpy as np
import random

# Lectura de datos
data = np.loadtxt('/content/drive/MyDrive/MÁSTER/IC/P2/data/tai256c.dat', skiprows=1)
flow = np.int32(data[:256])
distances = np.int32(data[256:])

seed = 2024
random.seed(seed)
np.random.seed(seed)

# %%
# Generación de la población inicial
population = np.array([np.random.permutation(np.arange(256)) for i in range(500)])

def fitness_pop(population, flow, distances):
    return np.sum(flow[np.newaxis, :, :] * distances[population[:,:,np.newaxis], population[:, np.newaxis, :]],
                  axis=(1,2))

# %%
# Función de selección por torneo
def tournament_selection(population, fitness_vals, tournament_size=5):
    selected = []
    for _ in range(len(population)):
        tournament = random.sample(range(len(population)), tournament_size)
        tournament_fitness = [fitness_vals[i] for i in tournament]
        winner = tournament[tournament_fitness.index(min(tournament_fitness))]
        selected.append(population[winner])
    return np.array(selected)

# %%
# Operador de cruce por orden (OX)
def ox_crossover(parent1, parent2):
    size = len(parent1)
    start, end = sorted(np.random.choice(range(size), 2, replace=False))

    child = -np.ones(size, dtype=int)
    child[start:end+1] = parent1[start:end+1]

    idx = 0
    for i in range(size):
        if child[i] == -1:
            while parent2[idx] in child:
                idx += 1
            child[i] = parent2[idx]
    return child

# %%
# Mutación por intercambio (Swap)
def swap_mutation(individual, mutation_prob=0.05):
    if random.random() < mutation_prob:
        i, j = np.random.choice(range(len(individual)), 2, replace=False)
        individual[i], individual[j] = individual[j], individual[i]
    return individual

# %%
def hill_climbing(individual, flow, distances, max_iterations=100):
    current_solution = individual.copy()
    current_cost = fitness_pop(np.array([current_solution]), flow, distances)[0]

    for _ in range(max_iterations):
        i, j = np.random.choice(range(len(current_solution)), 2, replace=False)
        neighbor = current_solution.copy()
        neighbor[i], neighbor[j] = neighbor[j], neighbor[i]
        neighbor_cost = fitness_pop(np.array([neighbor]), flow, distances)[0]

        if neighbor_cost < current_cost:
            current_solution = neighbor
            current_cost = neighbor_cost
    return current_solution, current_cost

# %%
# Algoritmo genético con variante baldwiniana
def baldwinian_genetic_algorithm(flow, distances, population_size=1000, generations=50, crossover_prob=0.9, mutation_prob=0.05, tournament_size=5):
    population = np.array([np.random.permutation(np.arange(256)) for _ in range(population_size)])

    for generation in range(generations):
        # Evaluación baldwiniana (con hill climbing)
        fitness_vals = []
        for individual in population:
            _, cost = hill_climbing(individual, flow, distances)
            fitness_vals.append(cost)
        fitness_vals = np.array(fitness_vals)

        # Selección
        selected_population = tournament_selection(population, fitness_vals, tournament_size)

        # Cruzamiento
        offspring = []
        for i in range(0, population_size, 2):
            if random.random() < crossover_prob:
                child1 = ox_crossover(selected_population[i], selected_population[i+1])
                child2 = ox_crossover(selected_population[i+1], selected_population[i])
            else:
                child1, child2 = selected_population[i], selected_population[i+1]
            offspring.append(child1)
            offspring.append(child2)

        # Mutación
        population = np.array([swap_mutation(individual, mutation_prob) for individual in offspring])

        # Evaluación (para impresión)
        fitness_vals_print = fitness_pop(population, flow, distances)

        # Imprimir el mejor individuo de cada generación
        best_idx = np.argmin(fitness_vals_print)
        print(f"Generación {generation+1}: Mejor coste (con hill climbing) = {fitness_vals[best_idx]} , Mejor coste (sin hill climbing) = {fitness_vals_print[best_idx]}")

    # Resultados finales
    best_idx = np.argmin(fitness_vals)
    return population[best_idx], fitness_vals[best_idx]

# %%
# Ejecución del algoritmo
best_solution_baldwin, best_cost_baldwin = baldwinian_genetic_algorithm(flow, distances)

print("\nMejor solución encontrada (Baldwiniano) (permutación):", best_solution_baldwin)
print("Coste asociado a la mejor solución (Baldwiniano):", best_cost_baldwin)
# Out:
# Generación 1: Mejor coste (con hill climbing) = 49340714 , Mejor coste (sin hill climbing) = 50433218
# Generación 2: Mejor coste (con hill climbing) = 50342722 , Mejor coste (sin hill climbing) = 50302038
# Generación 3: Mejor coste (con hill climbing) = 49297970 , Mejor coste (sin hill climbing) = 49992488
# Generación 4: Mejor coste (con hill climbing) = 50762460 , Mejor coste (sin hill climbing) = 49992488
# Generación 5: Mejor coste (con hill climbing) = 50400336 , Mejor coste (sin hill climbing) = 49649336
# Generación 6: Mejor coste (con hill climbing) = 51128910 , Mejor coste (sin hill climbing) = 49485318
# Generación 7: Mejor coste (con hill climbing) = 49895412 , Mejor coste (sin hill climbing) = 49507972
# Generación 8: Mejor coste (con hill climbing) = 50530192 , Mejor coste (sin hill climbing) = 49420448
# Generación 9: Mejor coste (con hill climbing) = 49436778 , Mejor coste (sin hill climbing) = 49265224
# Generación 10: Mejor coste (con hill climbing) = 49078954 , Mejor coste (sin hill climbing) = 49265224
# Generación 11: Mejor coste (con hill climbing) = 49295288 , Mejor coste (sin hill climbing) = 49173214
# Generación 12: Mejor coste (con hill climbing) = 50132648 , Mejor coste (sin hill climbing) = 49138764
# Generación 13: Mejor coste (con hill climbing) = 48992172 , Mejor coste (sin hill climbing) = 49240088
# Generación 14: Mejor coste (con hill climbing) = 48968312 , Mejor coste (sin hill climbing) = 49533218
# Generación 15: Mejor coste (con hill climbing) = 50028798 , Mejor coste (sin hill climbing) = 48868676
# Generación 16: Mejor coste (con hill climbing) = 48845136 , Mejor coste (sin hill climbing) = 49155134
# Generación 17: Mejor coste (con hill climbing) = 49448282 , Mejor coste (sin hill climbing) = 49385466
# Generación 18: Mejor coste (con hill climbing) = 49461476 , Mejor coste (sin hill climbing) = 49350268
# Generación 19: Mejor coste (con hill climbing) = 48589892 , Mejor coste (sin hill climbing) = 49350268
# Generación 20: Mejor coste (con hill climbing) = 48840154 , Mejor coste (sin hill climbing) = 48794452
# Generación 21: Mejor coste (con hill climbing) = 48561442 , Mejor coste (sin hill climbing) = 48794452
# Generación 22: Mejor coste (con hill climbing) = 48375200 , Mejor coste (sin hill climbing) = 48753768
# Generación 23: Mejor coste (con hill climbing) = 48798194 , Mejor coste (sin hill climbing) = 48631528
# Generación 24: Mejor coste (con hill climbing) = 48503710 , Mejor coste (sin hill climbing) = 48228442
# Generación 25: Mejor coste (con hill climbing) = 49023282 , Mejor coste (sin hill climbing) = 48192216
# Generación 26: Mejor coste (con hill climbing) = 48180946 , Mejor coste (sin hill climbing) = 48149504
# Generación 27: Mejor coste (con hill climbing) = 48779206 , Mejor coste (sin hill climbing) = 47695124
# Generación 28: Mejor coste (con hill climbing) = 47847102 , Mejor coste (sin hill climbing) = 47986514
# Generación 29: Mejor coste (con hill climbing) = 49464472 , Mejor coste (sin hill climbing) = 47525774
# Generación 30: Mejor coste (con hill climbing) = 47601496 , Mejor coste (sin hill climbing) = 47327296
# Generación 31: Mejor coste (con hill climbing) = 47850646 , Mejor coste (sin hill climbing) = 47291506
# Generación 32: Mejor coste (con hill climbing) = 48992882 , Mejor coste (sin hill climbing) = 47327296
# Generación 33: Mejor coste (con hill climbing) = 48469080 , Mejor coste (sin hill climbing) = 47301704
# Generación 34: Mejor coste (con hill climbing) = 47407488 , Mejor coste (sin hill climbing) = 47043140
# Generación 35: Mejor coste (con hill climbing) = 47076574 , Mejor coste (sin hill climbing) = 47043140
# Generación 36: Mejor coste (con hill climbing) = 47934464 , Mejor coste (sin hill climbing) = 46978496
# Generación 37: Mejor coste (con hill climbing) = 47038732 , Mejor coste (sin hill climbing) = 46808634
# Generación 38: Mejor coste (con hill climbing) = 47561606 , Mejor coste (sin hill climbing) = 46808634
# Generación 39: Mejor coste (con hill climbing) = 47361086 , Mejor coste (sin hill climbing) = 46529722
# Generación 40: Mejor coste (con hill climbing) = 47044158 , Mejor coste (sin hill climbing) = 46529722
# Generación 41: Mejor coste (con hill climbing) = 47272904 , Mejor coste (sin hill climbing) = 46529722
# Generación 42: Mejor coste (con hill climbing) = 47445706 , Mejor coste (sin hill climbing) = 46529722
# Generación 43: Mejor coste (con hill climbing) = 46517740 , Mejor coste (sin hill climbing) = 46437762
# Generación 44: Mejor coste (con hill climbing) = 47025138 , Mejor coste (sin hill climbing) = 46415904
# Generación 45: Mejor coste (con hill climbing) = 46843652 , Mejor coste (sin hill climbing) = 46307124
# Generación 46: Mejor coste (con hill climbing) = 46799622 , Mejor coste (sin hill climbing) = 46307124
# Generación 47: Mejor coste (con hill climbing) = 46565484 , Mejor coste (sin hill climbing) = 46307124
# Generación 48: Mejor coste (con hill climbing) = 46534898 , Mejor coste (sin hill climbing) = 46303298
# Generación 49: Mejor coste (con hill climbing) = 46777812 , Mejor coste (sin hill climbing) = 46257434
# Generación 50: Mejor coste (con hill climbing) = 46696016 , Mejor coste (sin hill climbing) = 46244020
#
# Mejor solución encontrada (Baldwiniano) (permutación): [238  98  13 109 169 152  25 232 120  62 184  40  94 246  15  18  10 164
#  172 196 193  66 217  88 176   5  91 221 116   7 133 166 141 146 206  71
#   83  69  44  34  20  92 118 224  80 106  86 194  49 122 201 131 139 252
#   32 187  23 197 144 219 226  37 223 244  63 124 129 174  54  73 182 243
#  143 251  84 137   1 163  81 253 215  30 150  42 248  57 154 157 103 234
#   60 189  72 255 112 138 104 247  95  59 190 211  38 117  28  19  24 199
#   21  11 212 186 161  33   4 165  29 180 167 114   3  56 179  75 250 134
#  236  26 229  99 102 237 205  22 241  55  17 160 227  53 130 181 135  77
#   90 127 200 191 151  52  67  68 155  36  43 213  93 159  35 235   8 188
#   45 168 245 147 209  48 100  27 115 175  51 222  89 148 140 132   6  31
#  231 162 208  79  61 125  64 110  39  76 220 101  96  70  82   0 216 156
#   14 183 126 198 149  46 145  58 107  74 111 203 142  85 233  41   9 123
#  254 239 242  47 153 214 192 158  16 225 105 113 202 119   2 108  50 136
#  185 121 170 210 171 128 177  97 207 218  65  78 230 249 178  87 228 173
#   12 204 195 240]
# Coste asociado a la mejor solución (Baldwiniano): 46104902
